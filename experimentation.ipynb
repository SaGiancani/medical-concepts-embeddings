# %%
import datetime, measures, mmi_txt_to_cui, umls_tables_processing
import os

from gensim.models import KeyedVectors, Word2Vec
from gensim.test.utils import datapath

# %% [markdown]
# ### Constants

# %%
PATH_EMBEDDINGS = './Embeddings'

# %% [markdown]
# ### Extracting all the labels for each CUI of the UMLS vocabulary

# %%
dict_conso = umls_tables_processing.cui_strings()
# Out:
# 0:00:53

# %%
len(dict_conso)
# Out:
# 3772450

# %%
dict_conso['C1963065']
# Out:
# ['Apnea, CTCAE', 'Apnea']

# %% [markdown]
# ### Extracting all the CUIs related to COPD (only one hop)

# %%
copd_cuis = umls_tables_processing.related_cuis_concept()
# Out:
# 256
# 0:03:32

# %%
len(copd_cuis)
# Out:
# 256

# %% [markdown]
# ## Building  ***seed_rel***

# %%
seed_rel, _ = umls_tables_processing.extracting_strings(copd_cuis, dict_conso)
# Out:
# 0:00:00

# %% [markdown]
# ## Building ***seed_paper***

# %%
paper_cuis = mmi_txt_to_cui.mmi_to_cui()
# Out:
# 0:00:00

# %%
seed_paper, _ = umls_tables_processing.extracting_strings(paper_cuis, dict_conso)
# Out:
# 0:00:00

# %% [markdown]
# ## Building ***seed_paper_lite***

# %%
paper_lite_cuis, oov_lite = mmi_txt_to_cui.mmi_lite_freetext()
# Out:
# 0:02:37

# %%
paper_lite_cuis = list(set(paper_lite_cuis))

# %%
oov_lite
# Out:
# ['[84–88].\n', '[92, 93]. \n']

# %%
seed_paper_lite, _ = umls_tables_processing.extracting_strings(paper_lite_cuis, dict_conso)
# Out:
# 0:00:00

# %% [markdown]
# ## Loading Models

# %%
cuis = ('/cuis/', [f.name for f in os.scandir(PATH_EMBEDDINGS+'/cuis') if f.is_file()])
words = ('/words/', [f.name for f in os.scandir(PATH_EMBEDDINGS+'/words') if f.is_file()])
embeddings = [cuis, words]
embeddings
# Out:
# [('/cuis/',
#   ['claims_cuis_hs_300.txt.gz',
#    'stanford_cuis_svd_300.txt.gz',
#    'cui2vec_pretrained.txt',
#    'DeVine_etal_200.txt']),
#  ('/words/',
#   ['PMC-w2v.bin',
#    'Health_2.5mreviews.s200.w10.n5.v15.cbow.bin',
#    'PubMed-and-PMC-w2v.bin',
#    'GoogleNews-vectors-negative300.bin',
#    'PubMed-w2v.bin',
#    'tweetsvec.txt',
#    'wikipedia-pubmed-and-PMC-w2v.bin'])]

# %%
ks = [5, 10, 20, 30, 40]

# %%
seeds = [('seed_rel', seed_rel), ('seed_paper', seed_paper), ('seed_paper_lite', seed_paper_lite)]

# %%
a = datetime.datetime.now().replace(microsecond=0)
big_g = {}

for k in ks:
    big_g[k] = {}
    for type_emb in embeddings:
        for emb in type_emb[1]:
            model = KeyedVectors.load_word2vec_format(PATH_EMBEDDINGS+type_emb[0]+emb, binary=emb.endswith('.bin'))
            name = os.path.splitext(emb)[0]
            big_g[k][name] = {}
            for seed in seeds:
                if type_emb[0]=='/cuis/':
                    d = measures.occurred_concept(model, seed[1].keys(), k_most_similar=k)
                elif type_emb[0]=='/words/':
                    d = measures.occurred_labels(model, seed[1], k_most_similar=k)
                big_g[k][name][seed[0]] = [measures.pos_dcg(d), measures.neg_dcg(d), measures.percentage_dcg(d), measures.oov(d)]
print(datetime.datetime.now().replace(microsecond=0)-a)
# Out:
# 256
# 399
# 157
# 256
# 399
# 157
# /home/salvatore/venv/lib/python3.8/site-packages/gensim/models/keyedvectors.py:2389: RuntimeWarning: invalid value encountered in true_divide
#   return (m / dist).astype(REAL)
# 256
# 399
# 157
# 256
# 399
# 157
# 0:00:51
# 0:01:57
# 0:00:36
# 0:00:01
# 0:00:02
# 0:00:00
# 0:01:30
# 0:03:18
# 0:00:58
# 0:01:10
# 0:03:14
# 0:01:03
# 0:00:48
# 0:01:46
# 0:00:32
# 0:00:01
# 0:00:00
# 0:00:00
# 0:02:06
# 0:04:50
# 0:01:28
# 256
# 399
# 157
# 256
# 399
# 157
# 256
# 399
# 157
# 256
# 399
# 157
# 0:00:50
# 0:02:00
# 0:00:38
# 0:00:01
# 0:00:02
# 0:00:00
# 0:01:33
# 0:03:24
# 0:01:03
# 0:01:11
# 0:03:21
# 0:01:03
# 0:00:50
# 0:01:54
# 0:00:35
# 0:00:01
# 0:00:00
# 0:00:00
# 0:02:13
# 0:04:52
# 0:01:31
# 256
# 399
# 157
# 256
# 399
# 157
# 256
# 399
# 157
# 256
# 399
# 157
# 0:00:54
# 0:02:05
# 0:00:39
# 0:00:01
# 0:00:02
# 0:00:01
# 0:01:33
# 0:03:19
# 0:01:01
# 0:01:09
# 0:03:15
# 0:01:02
# 0:00:52
# 0:02:00
# 0:00:39
# 0:00:01
# 0:00:01
# 0:00:00
# 0:02:13
# 0:04:55
# 0:01:30
# 256
# 399
# 157
# 256
# 399
# 157
# 256
# 399
# 157
# 256
# 399
# 157
# 0:00:56
# 0:02:04
# 0:00:39
# 0:00:02
# 0:00:03
# 0:00:00
# 0:01:34
# 0:03:31
# 0:01:04
# 0:01:18
# 0:03:29
# 0:01:06
# 0:00:50
# 0:01:56
# 0:00:35
# 0:00:00
# 0:00:01
# 0:00:00
# 0:02:09
# 0:04:57
# 0:01:32
# 256
# 399
# 157
# 256
# 399
# 157
# 256
# 399
# 157
# 256
# 399
# 157
# 0:00:51
# 0:02:05
# 0:00:39
# 0:00:01
# 0:00:03
# 0:00:00
# 0:01:32
# 0:03:28
# 0:01:02
# 0:01:17
# 0:03:27
# 0:01:05
# 0:00:49
# 0:01:56
# 0:00:34
# 0:00:00
# 0:00:01
# 0:00:00
# 0:02:11
# 0:04:58
# 0:01:32
# 3:00:32

# %%
big_g
# Out:
# {5: {'claims_cuis_hs_300.txt': {'seed_rel': [14.501806801297391,
#     740.3037276318257,
#     0.015625,
#     209],
#    'seed_paper': [0, 1176.4351884328785, 0.0, 389],
#    'seed_paper_lite': [0.5, 462.4080816640675, 0.0012738853503184713, 154]},
#   'stanford_cuis_svd_300.txt': {'seed_rel': [0, 754.8055344331227, 0.0, 256],
#    'seed_paper': [0, 1176.4351884328785, 0.0, 399],
#    'seed_paper_lite': [0, 462.9080816640675, 0.0, 157]},
#   'cui2vec_pretrained': {'seed_rel': [33.8234912681452,
#     720.9820431649783,
#     0.040625,
#     120],
#    'seed_paper': [65.16045246531382,
#     1111.2747359675607,
#     0.05463659147869674,
#     214],
#    'seed_paper_lite': [7.214447603066719,
#     455.69363406100064,
#     0.016560509554140127,
#     102]},
#   'DeVine_etal_200': {'seed_rel': [32.88509757979005,
#     721.9204368533334,
#     0.040625,
#     136],
#    'seed_paper': [62.47924848325011,
#     1113.9559399496247,
#     0.0481203007518797,
#     226],
#    'seed_paper_lite': [9.279642067948915,
#     453.6284395961184,
#     0.014012738853503185,
#     106]},
#   'PMC-w2v': {'seed_rel': [77.77721528608812,
#     677.0283191470365,
#     0.0859375,
#     179],
#    'seed_paper': [324.0683165758454,
#     852.3668718570284,
#     0.24461152882205514,
#     124],
#    'seed_paper_lite': [90.19315458737168,
#     372.7149270766944,
#     0.16687898089171974,
#     64]},
#   'Health_2.5mreviews.s200.w10.n5.v15.cbow': {'seed_rel': [31.091287228767946,
#     723.7142472043555,
#     0.03984375,
#     220],
#    'seed_paper': [105.14166663037994,
#     1071.2935218024925,
#     0.08320802005012531,
#     291],
#    'seed_paper_lite': [27.04152769958729,
#     435.86655396447975,
#     0.049681528662420385,
#     128]},
#   'PubMed-and-PMC-w2v': {'seed_rel': [92.82697481526874,
#     661.9785596178563,
#     0.1046875,
#     169],
#    'seed_paper': [343.41183488219554,
#     833.0233535506792,
#     0.2536340852130326,
#     120],
#    'seed_paper_lite': [94.88210317448868,
#     368.02597848957714,
#     0.17197452229299362,
#     58]},
#   'GoogleNews-vectors-negative300': {'seed_rel': [64.36969011886003,
#     690.4358443142645,
#     0.0703125,
#     193],
#    'seed_paper': [330.99858304072075,
#     845.436605392153,
#     0.24160401002506265,
#     138],
#    'seed_paper_lite': [103.09492763099615,
#     359.81315403306974,
#     0.1910828025477707,
#     66]},
#   'PubMed-w2v': {'seed_rel': [87.28026194038037,
#     667.5252724927448,
#     0.09296875,
#     171],
#    'seed_paper': [344.00487666327, 832.4303117696052, 0.256140350877193, 109],
#    'seed_paper_lite': [114.4300565775099,
#     348.4780250865558,
#     0.19745222929936307,
#     51]},
#   'tweetsvec': {'seed_rel': [15.886878931730008,
#     738.9186555013932,
#     0.01875,
#     243],
#    'seed_paper': [41.26064577864352,
#     1135.1745426542325,
#     0.03007518796992481,
#     343],
#    'seed_paper_lite': [6.385072130432616,
#     456.5230095336348,
#     0.012738853503184714,
#     145]},
#   'wikipedia-pubmed-and-PMC-w2v': {'seed_rel': [86.1393190052756,
#     668.6662154278494,
#     0.09453125,
#     170],
#    'seed_paper': [323.49243748314564,
#     852.9427509497287,
#     0.23107769423558897,
#     127],
#    'seed_paper_lite': [96.38997648473712,
#     366.5181051793289,
#     0.17452229299363056,
#     53]}},
#  10: {'claims_cuis_hs_300.txt': {'seed_rel': [16.412371897292076,
#     1146.7388186533267,
#     0.01015625,
#     209],
#    'seed_paper': [0, 1812.8801758972706, 0.0, 389],
#    'seed_paper_lite': [0.5, 712.8388160798685, 0.0006369426751592356, 154]},
#   'stanford_cuis_svd_300.txt': {'seed_rel': [0, 1163.1511905506193, 0.0, 256],
#    'seed_paper': [0, 1812.8801758972706, 0.0, 399],
#    'seed_paper_lite': [0, 713.3388160798685, 0.0, 157]},
#   'cui2vec_pretrained': {'seed_rel': [46.53861128794321,
#     1116.6125792626744,
#     0.0359375,
#     120],
#    'seed_paper': [87.22147844702614,
#     1725.6586974502416,
#     0.04461152882205514,
#     214],
#    'seed_paper_lite': [9.157316036730753,
#     704.1815000431376,
#     0.012101910828025478,
#     102]},
#   'DeVine_etal_200': {'seed_rel': [42.85017868069842,
#     1120.3010118699194,
#     0.032421875,
#     136],
#    'seed_paper': [72.6018306168821,
#     1740.2783452803867,
#     0.03208020050125313,
#     226],
#    'seed_paper_lite': [11.211601817184356,
#     702.127214262684,
#     0.010828025477707006,
#     106]},
#   'PMC-w2v': {'seed_rel': [98.21678436844044,
#     1064.9344061821764,
#     0.06953125,
#     163],
#    'seed_paper': [391.25433473100384,
#     1421.6258411662564,
#     0.17719298245614035,
#     96],
#    'seed_paper_lite': [104.78509275170782,
#     608.5537233281597,
#     0.11146496815286625,
#     60]},
#   'Health_2.5mreviews.s200.w10.n5.v15.cbow': {'seed_rel': [37.32783981515157,
#     1125.8233507354666,
#     0.027734375,
#     213],
#    'seed_paper': [130.58895661233913,
#     1682.2912192849283,
#     0.06190476190476191,
#     266],
#    'seed_paper_lite': [33.162438871464,
#     680.1763772084045,
#     0.038853503184713374,
#     122]},
#   'PubMed-and-PMC-w2v': {'seed_rel': [108.88802874575687,
#     1054.263161804859,
#     0.07421875,
#     166],
#    'seed_paper': [396.8499616836767,
#     1416.030214213584,
#     0.17017543859649123,
#     98],
#    'seed_paper_lite': [106.14640524689969,
#     607.1924108329679,
#     0.10828025477707007,
#     52]},
#   'GoogleNews-vectors-negative300': {'seed_rel': [74.06511103611535,
#     1089.0860795145024,
#     0.046484375,
#     188],
#    'seed_paper': [377.75393734429855,
#     1435.1262385529621,
#     0.1573934837092732,
#     125],
#    'seed_paper_lite': [117.85803089869876,
#     595.4807851811687,
#     0.12484076433121019,
#     56]},
#   'PubMed-w2v': {'seed_rel': [103.36898076941087,
#     1059.7822097812054,
#     0.068359375,
#     169],
#    'seed_paper': [394.03469361615, 1418.8454822811102, 0.168671679197995, 97],
#    'seed_paper_lite': [127.39387043986275,
#     585.9449456400043,
#     0.12484076433121019,
#     46]},
#   'tweetsvec': {'seed_rel': [21.563397028270014,
#     1141.5877935223482,
#     0.01640625,
#     233],
#    'seed_paper': [56.78860511660545,
#     1756.0915707806635,
#     0.02731829573934837,
#     321],
#    'seed_paper_lite': [8.223555442085855,
#     705.1152606377826,
#     0.01019108280254777,
#     139]},
#   'wikipedia-pubmed-and-PMC-w2v': {'seed_rel': [102.9526691447564,
#     1060.1985214058595,
#     0.06953125,
#     164],
#    'seed_paper': [383.0350941945691,
#     1429.8450817026899,
#     0.1644110275689223,
#     107],
#    'seed_paper_lite': [112.15376034010178,
#     601.1850557397656,
#     0.1197452229299363,
#     46]}},
#  20: {'claims_cuis_hs_300.txt': {'seed_rel': [20.578366645964174,
#     1781.7303391264832,
#     0.0083984375,
#     209],
#    'seed_paper': [0.4796249331362629,
#     2808.5874594543156,
#     0.0002506265664160401,
#     389],
#    'seed_paper_lite': [0.5, 1104.8221359620086, 0.0003184713375796178, 154]},
#   'stanford_cuis_svd_300.txt': {'seed_rel': [0, 1802.3087057724472, 0.0, 256],
#    'seed_paper': [0, 2809.0670843874514, 0.0, 399],
#    'seed_paper_lite': [0, 1105.3221359620084, 0.0, 157]},
#   'cui2vec_pretrained': {'seed_rel': [63.114477119995776,
#     1739.1942286524509,
#     0.030859375,
#     120],
#    'seed_paper': [109.58731567745392,
#     2699.479768710008,
#     0.033458646616541354,
#     214],
#    'seed_paper_lite': [10.86070075553526,
#     1094.4614352064732,
#     0.008280254777070064,
#     102]},
#   'DeVine_etal_200': {'seed_rel': [61.7279363392295,
#     1740.580769433218,
#     0.030859375,
#     136],
#    'seed_paper': [89.7960295519958,
#     2719.271054835462,
#     0.02468671679197995,
#     226],
#    'seed_paper_lite': [12.257725193832952,
#     1093.0644107681762,
#     0.006687898089171975,
#     106]},
#   'PMC-w2v': {'seed_rel': [118.43253414907099,
#     1683.876171623375,
#     0.051953125,
#     159],
#    'seed_paper': [474.8834609354954,
#     2334.1836234519947,
#     0.13220551378446116,
#     83],
#    'seed_paper_lite': [129.93997685946766,
#     975.3821591025396,
#     0.0875796178343949,
#     50]},
#   'Health_2.5mreviews.s200.w10.n5.v15.cbow': {'seed_rel': [46.878444429096504,
#     1755.4302613433508,
#     0.021484375,
#     205],
#    'seed_paper': [159.43993534196568,
#     2649.6271490454974,
#     0.04649122807017544,
#     249],
#    'seed_paper_lite': [38.89992454908094,
#     1066.422211412928,
#     0.027070063694267517,
#     114]},
#   'PubMed-and-PMC-w2v': {'seed_rel': [127.93124810288181,
#     1674.3774576695641,
#     0.05234375,
#     160],
#    'seed_paper': [466.2372633604269,
#     2342.829821027063,
#     0.12130325814536341,
#     90],
#    'seed_paper_lite': [125.0352438020315,
#     980.2868921599757,
#     0.0786624203821656,
#     43]},
#   'GoogleNews-vectors-negative300': {'seed_rel': [83.34835297754375,
#     1718.9603527949037,
#     0.0314453125,
#     185],
#    'seed_paper': [423.92463795441864,
#     2385.142446433066,
#     0.1031328320802005,
#     116],
#    'seed_paper_lite': [126.34733820565425,
#     978.9747977563538,
#     0.07420382165605095,
#     47]},
#   'PubMed-w2v': {'seed_rel': [119.52538725266689,
#     1682.7833185197806,
#     0.04765625,
#     164],
#    'seed_paper': [459.7651571895184,
#     2349.301927197974,
#     0.11892230576441103,
#     87],
#    'seed_paper_lite': [142.88989255105693,
#     962.4322434109497,
#     0.08184713375796178,
#     46]},
#   'tweetsvec': {'seed_rel': [30.545336935251324,
#     1771.7633688371955,
#     0.015234375,
#     225],
#    'seed_paper': [71.74419233232754,
#     2737.3228920551305,
#     0.021303258145363407,
#     301],
#    'seed_paper_lite': [10.420305147227657,
#     1094.9018308147813,
#     0.008280254777070064,
#     137]},
#   'wikipedia-pubmed-and-PMC-w2v': {'seed_rel': [119.87840058388346,
#     1682.4303051885627,
#     0.048046875,
#     162],
#    'seed_paper': [450.78604819886226,
#     2358.2810361886254,
#     0.11791979949874687,
#     90],
#    'seed_paper_lite': [123.4256712503098,
#     981.896464711698,
#     0.07452229299363057,
#     44]}},
#  30: {'claims_cuis_hs_300.txt': {'seed_rel': [24.807499895557665,
#     2320.5572468157134,
#     0.008203125,
#     209],
#    'seed_paper': [0.6977292251217945,
#     3654.773106469235,
#     0.0002506265664160401,
#     389],
#    'seed_paper_lite': [0.5, 1437.8682235690394, 0.00021231422505307856, 154]},
#   'stanford_cuis_svd_300.txt': {'seed_rel': [0, 2345.3647467112687, 0.0, 256],
#    'seed_paper': [0, 3655.4708356943574, 0.0, 399],
#    'seed_paper_lite': [0, 1438.3682235690396, 0.0, 157]},
#   'cui2vec_pretrained': {'seed_rel': [77.78600565737293,
#     2267.5787410539037,
#     0.029557291666666666,
#     120],
#    'seed_paper': [130.26776406630873,
#     3525.2030716280638,
#     0.0304093567251462,
#     214],
#    'seed_paper_lite': [13.361561970914122,
#     1425.0066615981248,
#     0.008067940552016985,
#     102]},
#   'DeVine_etal_200': {'seed_rel': [74.03020034903837,
#     2271.3345463622395,
#     0.028125,
#     136],
#    'seed_paper': [102.48679357585566,
#     3552.984042118511,
#     0.0214703425229741,
#     226],
#    'seed_paper_lite': [13.536304000798276,
#     1424.8319195682411,
#     0.005732484076433121,
#     106]},
#   'PMC-w2v': {'seed_rel': [130.4867522552566,
#     2214.877994456028,
#     0.042708333333333334,
#     156],
#    'seed_paper': [527.3507164411898,
#     3128.1201192532285,
#     0.11027568922305764,
#     72],
#    'seed_paper_lite': [136.42655371432593,
#     1301.9416698547102,
#     0.06518046709129512,
#     47]},
#   'Health_2.5mreviews.s200.w10.n5.v15.cbow': {'seed_rel': [52.989771058009914,
#     2292.374975653265,
#     0.018229166666666668,
#     200],
#    'seed_paper': [177.49861727636147,
#     3477.9722184180155,
#     0.03826232247284879,
#     240],
#    'seed_paper_lite': [41.285531612892484,
#     1397.0826919561453,
#     0.02059447983014862,
#     113]},
#   'PubMed-and-PMC-w2v': {'seed_rel': [139.37108816356493,
#     2205.9936585477208,
#     0.04205729166666667,
#     159],
#    'seed_paper': [507.7473172495594,
#     3147.723518444856,
#     0.09807852965747703,
#     84],
#    'seed_paper_lite': [133.77328458878137,
#     1304.5949389802545,
#     0.0613588110403397,
#     41]},
#   'GoogleNews-vectors-negative300': {'seed_rel': [88.53866767851855,
#     2256.8260790327604,
#     0.02421875,
#     182],
#    'seed_paper': [451.0737968588961,
#     3204.397038835508,
#     0.08028404344193818,
#     113],
#    'seed_paper_lite': [130.67336641840805,
#     1307.694857150629,
#     0.054140127388535034,
#     47]},
#   'PubMed-w2v': {'seed_rel': [127.99376657245578,
#     2217.3709801388286,
#     0.037109375,
#     163],
#    'seed_paper': [500.3106136493493,
#     3155.16022204507,
#     0.09615705931495405,
#     83],
#    'seed_paper_lite': [149.6149230373699,
#     1288.7533005316668,
#     0.06199575371549894,
#     42]},
#   'tweetsvec': {'seed_rel': [35.220567284029805,
#     2310.1441794272428,
#     0.013020833333333334,
#     219],
#    'seed_paper': [83.89028417073925,
#     3571.5805515236257,
#     0.019131161236424395,
#     284],
#    'seed_paper_lite': [11.075225529518626,
#     1427.2929980395209,
#     0.0061571125265392785,
#     134]},
#   'wikipedia-pubmed-and-PMC-w2v': {'seed_rel': [130.78912221290713,
#     2214.5756244983772,
#     0.0390625,
#     159],
#    'seed_paper': [487.7754833264265,
#     3167.6953523679867,
#     0.09473684210526316,
#     87],
#    'seed_paper_lite': [129.9755309522578,
#     1308.3926926167792,
#     0.056687898089171976,
#     42]}},
#  40: {'claims_cuis_hs_300.txt': {'seed_rel': [27.926226420769652,
#     2811.3781423864743,
#     0.00771484375,
#     209],
#    'seed_paper': [1.0846469670221408,
#     4424.237396603508,
#     0.0003132832080200501,
#     389],
#    'seed_paper_lite': [0.5, 1740.7921324326462, 0.0001592356687898089, 154]},
#   'stanford_cuis_svd_300.txt': {'seed_rel': [0, 2839.3043688072403, 0.0, 256],
#    'seed_paper': [0, 4425.32204357053, 0.0, 399],
#    'seed_paper_lite': [0, 1741.2921324326462, 0.0, 157]},
#   'cui2vec_pretrained': {'seed_rel': [90.32144456773919,
#     2748.982924239513,
#     0.028515625,
#     120],
#    'seed_paper': [142.91863324719878,
#     4282.4034103233225,
#     0.02681704260651629,
#     214],
#    'seed_paper_lite': [14.71879451949743,
#     1726.5733379131484,
#     0.007165605095541401,
#     102]},
#   'DeVine_etal_200': {'seed_rel': [83.73163170233912,
#     2755.5727371049147,
#     0.0259765625,
#     136],
#    'seed_paper': [110.62065878912242,
#     4314.701384781401,
#     0.018734335839598996,
#     226],
#    'seed_paper_lite': [14.109098099916888,
#     1727.1830343327297,
#     0.004777070063694267,
#     106]},
#   'PMC-w2v': {'seed_rel': [137.57540649520857,
#     2701.7289623120514,
#     0.035546875,
#     155],
#    'seed_paper': [573.2837761215372,
#     3852.0382674490056,
#     0.09837092731829573,
#     71],
#    'seed_paper_lite': [141.92098996304816,
#     1599.3711424695941,
#     0.0535031847133758,
#     42]},
#   'Health_2.5mreviews.s200.w10.n5.v15.cbow': {'seed_rel': [57.729294957474245,
#     2781.575073849776,
#     0.01630859375,
#     200],
#    'seed_paper': [189.37441376927677,
#     4235.94762980124,
#     0.032832080200501254,
#     231],
#    'seed_paper_lite': [43.75135200436548,
#     1697.5407804282795,
#     0.01751592356687898,
#     112]},
#   'PubMed-and-PMC-w2v': {'seed_rel': [146.78919074063944,
#     2692.5151780666233,
#     0.0353515625,
#     155],
#    'seed_paper': [539.5866079904505,
#     3885.7354355800862,
#     0.0843984962406015,
#     81],
#    'seed_paper_lite': [138.05355113098574,
#     1603.238581301656,
#     0.049522292993630576,
#     38]},
#   'GoogleNews-vectors-negative300': {'seed_rel': [91.29548469694586,
#     2748.008884110308,
#     0.01962890625,
#     180],
#    'seed_paper': [474.26700749838534,
#     3951.0550360721395,
#     0.06804511278195488,
#     104],
#    'seed_paper_lite': [133.49353218861518,
#     1607.7986002440286,
#     0.04331210191082802,
#     45]},
#   'PubMed-w2v': {'seed_rel': [135.35577749974803,
#     2703.9485913075146,
#     0.031640625,
#     162],
#    'seed_paper': [533.2243164769021,
#     3892.0977270936364,
#     0.08283208020050126,
#     79],
#    'seed_paper_lite': [156.85450874511156,
#     1584.4376236875328,
#     0.052547770700636945,
#     36]},
#   'tweetsvec': {'seed_rel': [40.230859631071894,
#     2799.0735091761753,
#     0.0123046875,
#     215],
#    'seed_paper': [93.77950057613056,
#     4331.5425429943925,
#     0.017543859649122806,
#     276],
#    'seed_paper_lite': [13.028318464713127,
#     1728.2638139679327,
#     0.006210191082802548,
#     132]},
#   'wikipedia-pubmed-and-PMC-w2v': {'seed_rel': [138.0876450258808,
#     2701.2167237813824,
#     0.03369140625,
#     156],
#    'seed_paper': [523.9426327581779,
#     3901.379410812356,
#     0.08333333333333333,
#     83],
#    'seed_paper_lite': [133.44577137193798,
#     1607.8463610607057,
#     0.04538216560509554,
#     40]}}}

# %%
import utils
utils.save_txt_dicts(big_g, 'big_g.txt')
