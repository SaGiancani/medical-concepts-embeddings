# %%
import datetime, measures, mmi_txt_to_cui, umls_tables_processing, utils
import numpy as np
import os
import pandas as pd

from gensim.models import KeyedVectors, Word2Vec
from gensim.test.utils import datapath
# Out:
# 0:07:47

# %% [markdown]
# ### Constants

# %%
PATH_EMBEDDINGS = './Embeddings'

# %% [markdown]
# ### Extracting all the labels for each CUI of the UMLS vocabulary

# %%
dict_conso = umls_tables_processing.cui_strings()
# Out:
# 0:01:36

# %%
len(dict_conso)
# Out:
# 3772450

# %%
dict_conso['C1963065']
# Out:
# ['Apnea, CTCAE', 'Apnea']

# %% [markdown]
# ## Building  ***seed_rel***

# %% [markdown]
# ### Extracting all the CUIs related to COPD (only one hop) and its relationships

# %%
copd_dict = umls_tables_processing.concepts_related_to_concept(two_way = True, extract_labels = False )
copd_cuis = list(copd_dict.keys())
# Out:
# Building seed time: 0:02:37

# %% [markdown]
# #### Check on the relationships proportions in the list: `number of CUI with particular relations / total number of found CUIs`

# %%
_ = umls_tables_processing.concepts_related_to_concept(two_way = True, polishing_rels = True, extract_labels = False )
print(str(sum([1 for i in list(_.values()) if len(i)>0]))+'/'+str(len(_)))
# Out:
# Relation '' discarded
# 101/256

# %% [markdown]
# #### Check which concepts have the empty relation

# %%
_ = umls_tables_processing.concepts_related_to_concept(two_way = True, polishing_rels = False, extract_labels = False )
print(str(sum([1 for i in list(_.values()) if '' in i]))+'/'+str(len(_)))
# Out:
# 0:01:10
# 177/256

# %% [markdown]
# ### Check the semantic types contained into the *seed_rel*

# %%
eval_rel = umls_tables_processing.extracting_stys(copd_cuis)
t = mmi_txt_to_cui.check_sty_mmi(mmi_txt_to_cui.convert_sty_stymmi(eval_rel))
print({k: j for k,j in list(t.items())[:5]})
# Out:
# 0:09:41
# {'dsyn': (105, 'Disease or Syndrome'), 'ftcn': (25, 'Functional Concept'), 'patf': (12, 'Pathologic Function'), 'hlca': (12, 'Health Care Activity'), 'topp': (11, 'Therapeutic or Preventive Procedure')}

# %%
seed_rel, _ = umls_tables_processing.extracting_strings(copd_cuis)
# Out:
# Time for extracting labels: 0:00:00

# %% [markdown]
# ## Building ***seed_paper***

# %%
paper_cuis = mmi_txt_to_cui.mmi_to_cui(sty = True)
# Out:
# 0:00:00

# %% [markdown]
# ### Check the semantic types contained into the *seed_paper*

# %%
a = mmi_txt_to_cui.check_sty_mmi(paper_cuis)
print({k: j for k,j in list(a.items())[:5]})
# Out:
# {'qlco': (49, 'Qualitative Concept'), 'fndg': (38, 'Finding'), 'inpr': (35, 'Intellectual Product'), 'qnco': (34, 'Quantitative Concept'), 'ftcn': (30, 'Functional Concept')}

# %%
seed_paper, _ = umls_tables_processing.extracting_strings([i[0] for i in paper_cuis])
# Out:
# Time for extracting labels: 0:00:00

# %%
seed_paper
# Out:
# {'C0030705': ['Patients',
#   'patients',
#   'Patient',
#   'patient',
#   'PATIENT',
#   '^Patient',
#   '*^patient',
#   'PT',
#   'Patient (person)',
#   'LAY USER/PATIENT'],
#  'C0024117': ['Chronic Obstructive Airway Disease',
#   'Chronic obstructive airway disease',
#   'Chronic obstructive airways disease NOS',
#   'Chronic Obstructive Airways Disease',
#   'Chronic airway obstruction',
#   'Chronic Obstructive Lung Disease',
#   'CHRONIC OBSTRUCTIVE LUNG DISEASE',
#   'Chronic obstructive lung disease',
#   'chronic obstructive lung disease',
#   'Chronic obstructive lung disease, NOS',
#   'Pulmonary Disease, Chronic Obstructive',
#   'CHRONIC OBSTRUCTIVE PULMONARY DISEASE',
#   'chronic obstructive pulmonary disease',
#   'Chronic obstructive pulmonary disease',
#   'PULMONARY DISEASE, CHRONIC OBSTRUCTIVE',
#   'Chronic obstructive pulmonary disease NOS',
#   'Chronic Obstructive Pulmonary Diseases',
#   'Chronic Obstructive Pulmonary Disease',
#   'COLD',
#   'COPD',
#   'COPD NOS',
#   'HYPERACTIVE AIRWAY DISEASE',
#   'Chronic airflow limitation',
#   'chronic airflow limitation',
#   'COAD - Chronic obstructive airways disease',
#   'Chronic airway disease',
#   'chronic airway disease',
#   'chronic airways disease',
#   'Chronic irreversible airway obstruction',
#   'COLD - Chronic obstructive lung disease',
#   'COLD (chronic obstructive lung disease)',
#   'COPD - Chronic obstructive pulmonary disease',
#   'Chronic Obstructive Pulmonary Disease (COPD)',
#   'Chronic Obstructive Pulmonary Disease, (COPD)',
#   'Obstructive Pulmonary Disease (COPD), Chronic',
#   'Pulmonary Disease (COPD), Chronic Obstructive',
#   'chronic obstructive pulmonary disease (COPD)',
#   'COPD, Chronic Obstructive Pulmonary Disease',
#   'CHRONIC OBSTRUCTIVE LUNG DIS',
#   'COAD',
#   'coad',
#   'CAFL - Chronic airflow limitation',
#   'CAL - Chronic airflow limitation',
#   'Chronic airway obstruction; not otherwise specified',
#   'Chronic pulmonary obstruction',
#   'Chronic obstructive airways disease NOS (disorder)',
#   'Chronic obstructive lung disease [Ambiguous]',
#   'Chronic obstructive lung disease (disorder)',
#   'Chronic obstructive pulmonary disease finding (finding)',
#   'Chronic obstructive pulmonary disease finding',
#   'Disease (COPD), Chronic Obstructive',
#   'CHRONIC OBSTRUCTIVE AIRWAY DIS',
#   'CHRONIC OBSTRUCTIVE PULM DIS',
#   'PULM DIS CHRONIC OBSTRUCTIVE'],
#  'C5202850': ['GDC Treatment Outcome Terminology', 'TO', 'treatment_outcome'],
#  'C1883351': ['To'],
#  'C0041260': ['Tryptophanase',
#   'tryptophanase',
#   'TO',
#   'Tryptophan 2,3-Dioxygenase',
#   'Tryptophan Indole-Lyase',
#   'Tryptophan Indole Lyase',
#   'Indole-Lyase, Tryptophan',
#   'Tryptophan Oxygenase',
#   'Tryptophan Pyrrolase',
#   'L-Tryptophan indole-lyase (deaminating)',
#   'L-tryptophanase',
#   'Tryptophanase (substance)',
#   'Tryptamin 2,3-Dioxygenase',
#   'TDO',
#   'TDO2',
#   'TPH2',
#   'TRPO',
#   'EC 1.13.11.11'],
#  'C0030054': ['oxygen',
#   'Oxygen',
#   'OXYGEN',
#   'Oxygen, NOS',
#   'O',
#   'Chemical oxygen',
#   'Elemental oxygen',
#   'O2',
#   'O2 - oxygen',
#   'O2 - Oxygen',
#   'O>2<',
#   'o 2',
#   'Oxygen USP',
#   'Pure oxygen',
#   'Oxygen-16',
#   'Oxygen 16',
#   'Oxygen product',
#   'Product containing oxygen (product)',
#   'Oxygen-containing product',
#   'Product containing oxygen',
#   'Product containing oxygen (medicinal product)',
#   'O element',
#   'O2 element',
#   'O<sub>2</sub>',
#   'Oxygen (substance)'],
#  'C0332257': ['Including (qualifier)',
#   'Has part',
#   'has part',
#   'Including',
#   'including',
#   'Includes',
#   'included',
#   'includes',
#   'include',
#   'Inclusive',
#   'inclusive',
#   'Including (qualifier value)'],
#  'C0037455': ['Societies', 'society', 'society [ organization]'],
#  'C2700399': ['Include (action)', 'Include'],
#  'C1552866': ['include - SetOperator', 'include'],
#  'C4086268': ['Exacerbation', 'EXACERBATION'],
#  'C0087111': ['Therapeutic procedure',
#   'Procedure - therapeutic',
#   'Therapeutic Procedure',
#   'therapeutic procedure',
#   'Therapeutic procedure, NOS',
#   'Therapeutics',
#   'therapeutics',
#   'Therapy',
#   'therapy',
#   'Therapy, NOS',
#   'therapies',
#   'Therapies',
#   'Treatment',
#   'treatment',
#   'Treatments',
#   'treatments',
#   'Therapeutic',
#   'TREAT',
#   'Therapeutic Method',
#   'therapeutic method',
#   'treatment method',
#   'methods treatment',
#   'method treatment',
#   'TX',
#   'Therapeutic Interventions',
#   'therapeutic intervention',
#   'any_therapy',
#   'any therapy',
#   'Therapeutic procedure [Ambiguous]',
#   'Therapeutic procedure (procedure)',
#   'Therapy (regime/therapy)(procedure)',
#   'Therapy (regime/therapy)',
#   'Therapeutic Technique',
#   'THER',
#   'Gestes therapeutiques',
#   'Procedura terapeutica'],
#  'C0039798': ['therapeutic aspects',
#   'therapy',
#   'treatment',
#   'disease management',
#   'TH',
#   'THER'],
#  'C1518422': ['Negation', 'No', 'Non', 'Non-', 'Not', 'Negated'],
#  'C1274040': ['Result',
#   'result',
#   'OUT',
#   'Result (navigational concept)',
#   'Outcome',
#   'outcome',
#   'Result (administrative concept)'],
#  'C0013404': ['ARNASBEHARRA, DISNEA',
#   'Andenod/dyspno',
#   'Dyspnoe/benauwdheid',
#   'Dyspnea',
#   'DYSPNEA',
#   'dyspnea',
#   'Dyspneas',
#   'DYSPNOEA',
#   'Dyspnea, NOS',
#   'Dyspnoea, NOS',
#   'Dyspnoea',
#   'dyspnoea',
#   'Breathlessness',
#   'BREATHLESSNESS',
#   'breathlessness',
#   'Breathlessness NOS',
#   'Short of breath',
#   'Shortness of Breath',
#   'Shortness of breath',
#   'SHORTNESS OF BREATH',
#   'shortness of breath',
#   'BREATH SHORTNESS',
#   'breath shortness',
#   'Breath Shortness',
#   'Abnormal breathing',
#   'SOB - Shortness of breath',
#   'shortness of breath (SOB)',
#   'SOB (SHORTNESS OF BREATH)',
#   'Difficult to breathe',
#   'BREATHING DIFFICULT',
#   'difficult breathing',
#   'Difficulty breathing',
#   'breathing difficulty',
#   'Breathing difficulty',
#   'DIFFICULTY BREATHING',
#   'Difficulty Breathing',
#   'breathing difficulties',
#   'Breathing difficulties',
#   'Breathing Difficulties',
#   'SOB',
#   'Respiration difficult',
#   '[D]Shortness of breath',
#   'Shortness of breath dyspnea',
#   '[D]Dyspnoea',
#   '[D]Dyspnea',
#   'DIB - Difficulty in breathing',
#   'Breathless',
#   'breathless',
#   '[D]Breathlessness',
#   'Breathlessnesses',
#   'Respiratory difficulties',
#   'respiratory difficulty',
#   'Breath Shortnesses',
#   'Trouble breathing',
#   'Difficulty breathing [Ambiguous]',
#   'Dyspnea (finding) [Ambiguous]',
#   '[D]Shortness of breath (context-dependent category)',
#   'Short of breath symptom',
#   'Shortness of breath symptom',
#   'Difficulty breathing (finding)',
#   '(Symptom: [SOB] or [breathlessness] or [dyspnoea]) or (breathlessness)',
#   '(Symptom: [SOB] or [breathlessness] or [dyspnea]) or (breathlessness)',
#   '[D]Breathlessness (context-dependent category)',
#   'Breathlessness NOS (finding)',
#   'Breathlessness symptom',
#   '[D]Dyspnea (context-dependent category)',
#   'Dyspnea (finding)',
#   'Dyspnoea (finding)',
#   'Dyspnoea - symptom',
#   'Dyspnea - symptom',
#   'tightness of breath',
#   '[D]Shortness of breath (situation)',
#   '[D]Breathlessness (situation)',
#   '[D]Dyspnea (situation)',
#   '[D]Dyspnoea (situation)',
#   '(Symptom: [SOB] or [breathlessness] or [dyspnoea]) or (breathlessness) (finding)',
#   'breathing shortness',
#   'HENGENAHDISTUS/DYSPNEA',
#   'Souffle court/dyspnee',
#   'Kurzatmigkeit/Dyspnoe',
#   'kotzer neshima',
#   'nehezlegzes/dyspnoe',
#   'Respiro affannoso dispnea',
#   'TUNGPUSTET/KORTPUSTET/DYSPNE',
#   'Dispneia/fadiga respiratoria',
#   'Fatiga respiratoria, disnea',
#   'ANDNOD/DYSPNE'],
#  'C0012634': ['Disease',
#   'disease',
#   'Diseases',
#   'Disease, NOS',
#   'diseases',
#   'condition',
#   'Disease (disorder)',
#   'disease/disorder',
#   'Diseases and Disorders',
#   'Clinical disease AND/OR syndrome present',
#   'Clinical disease or syndrome present, NOS',
#   'Clinical disease AND/OR syndrome',
#   'Clinical disease or syndrome, NOS',
#   'Disease AND/OR syndrome present',
#   'Disease or syndrome present, NOS',
#   'DIS',
#   'Disorder',
#   'disorder',
#   'Disorders',
#   'Disorder, NOS',
#   'disorders',
#   'Disease or Disorder, Non-Neoplastic',
#   'disease_term',
#   'disease term',
#   'Disease or Disorder',
#   'Other Disease'],
#  'C1301746': ['Documents',
#   'documents',
#   'Document',
#   'document',
#   'Doc',
#   'Documents (qualifier value)'],
#  'C0150312': ['Present',
#   'present',
#   'PRESENT',
#   'In',
#   'Presence of',
#   'of presence',
#   'Presence',
#   'Found',
#   'Present (qualifier value)'],
#  'C1547673': ['Document type',
#   'Document Type',
#   'documentation',
#   'Document',
#   'document'],
#  'C0750591': ['consider', 'considered', 'considering'],
#  'C0392747': ['Changing',
#   'changing',
#   'Changed',
#   'Change in',
#   'change in',
#   'changed',
#   'changes',
#   'change',
#   'Change',
#   'Adapt',
#   'Adapted',
#   'Altered',
#   'altered',
#   'Modified',
#   'modified',
#   'MODIFY',
#   'Altered (qualifier value)',
#   'Changing (modifier) [Ambiguous]',
#   'Changing (qualifier value)',
#   'Modification',
#   'Changing (modifier) (qualifier value)'],
#  'C0027552': ['Needs',
#   'needs',
#   'need',
#   'Needed',
#   'Need',
#   'Needed (qualifier value)'],
#  'C0686904': ['Patient need for (contextual qualifier)',
#   'Need for',
#   'need for',
#   'needed',
#   'needing',
#   'needs',
#   'need',
#   'Patient need for',
#   'need patients',
#   'needed patients',
#   'needing patient',
#   'needs patients',
#   'needs patient',
#   'patient needs',
#   'patient need',
#   'Patient needs',
#   'Patient need for (contextual qualifier) (qualifier value)',
#   'Patient dependence on (contextual qualifier)'],
#  'C1522326': ['Treating',
#   'treating',
#   'treated with',
#   'treated',
#   'Treat',
#   'Treated',
#   'Treatment'],
#  'C3541314': ['Pairing Events Domain', 'PA', 'Pairing Events'],
#  'C0443172': ['Changed status',
#   'changed status',
#   'Change in',
#   'change in',
#   'Changed',
#   'changed',
#   'changes',
#   'changing',
#   'change',
#   'Changed status (qualifier value)',
#   'State changes'],
#  'C1280500': ['Effect',
#   'effect',
#   'effects',
#   'Effects',
#   'Effect (qualifier value)'],
#  'C1527178': ['Basis - conceptual entity', 'Basis', 'Based', 'Basic'],
#  'C1561566': ['FEV1, CTCAE', 'FEV(1)', 'FEV1 Adverse Event'],
#  'C4528367': ['Forced Expiratory Volume in 0.1 Second', 'FEV_1', 'FEV 0.1s'],
#  'C0849974': ['Pulmonary Function Test/Forced Expiratory Volume 1',
#   'Forced Expiratory Volume in 1 Second',
#   'fev 1',
#   'Forced Expiratory Volume 1 Test',
#   'PFT/FEV1',
#   'FEV1%VC',
#   'FEV1'],
#  'C0199529': ['Pulmonary rehabilitation (procedure)',
#   'Pulmonary rehabilitation',
#   'rehabilitation pulmonary',
#   'Pulmonary Rehabilitation',
#   'pulmonary rehabilitation',
#   'Pulmonary rehabilitation, NOS',
#   'Pulmonary rehabilitation (regime/therapy)'],
#  'C0392756': ['Reduced',
#   'reduced',
#   'reducing',
#   'Reducing',
#   'Decrease',
#   'Decreased',
#   'DECREASED',
#   'Reduction',
#   'Reduced (qualifier value)'],
#  'C0332183': ['Frequently',
#   'frequently',
#   'Frequent',
#   'frequent',
#   'Often',
#   'often',
#   'Frequent (79-30%)',
#   'Frequent (qualifier value)'],
#  'C1705938': ['Base - General Qualifier', 'Base', 'Based'],
#  'C1963100': ['Dyspnea, CTCAE', 'Dyspnea', 'Dyspnea (shortness of breath)'],
#  'C3164735': ['Noninvasive positive pressure ventilation',
#   'Noninvasive positive pressure ventilation (procedure)'],
#  'C0441889': ['Levels (qualifier value)',
#   'Degree',
#   'Levels',
#   'levels',
#   'Level'],
#  'C1533734': ['Administration procedure',
#   'Administration (Procedure)',
#   'administration procedures',
#   'Administration (procedure)',
#   'Administration',
#   'administration',
#   'Treatment',
#   'administration (substance)',
#   'Administering'],
#  'C1705169': ['Biomaterial Treatment', 'Treatment'],
#  'C3538994': ['Treatment Epoch', 'TREATMENT'],
#  'C3887704': ['treatment - ActInformationManagementReason', 'treatment'],
#  'C0332272': ['Better',
#   'better',
#   'Improved',
#   'Better (qualifier value)',
#   'BETTER/IMPROVED/RECOVERING'],
#  'C4084203': ['Improved - answer to question',
#   'Improved',
#   'IMPROVED',
#   'Better',
#   'It improved'],
#  'C2825142': ['Experimental Result', 'Result'],
#  'C1546471': ['What subject filter - Result', 'Result'],
#  'C1999230': ['Providing (action)',
#   'Supply',
#   'Supplied',
#   'Provide',
#   'Provided'],
#  'C0429706': ['Forced expiratory volume in 1 second finding',
#   'FEV 1.0',
#   'Forced expiratory volume in 1 second',
#   'FEV1 - Forced expired volume in 1 second',
#   'Forced expired volume in 1 second',
#   'Forced expired volume in 1 second (observable entity)',
#   'Forced expired volume in 1 second (finding)'],
#  'C0018759': ['Health Status',
#   'status health',
#   'health status',
#   'Health status',
#   'Status, Health',
#   'Level of Health',
#   'Health Level',
#   'Health Levels',
#   'health levels',
#   'health level',
#   'level health',
#   'General Health Status',
#   'Health status (observable entity)'],
#  'C0442805': ['Increase',
#   'increase',
#   'Increased',
#   'increases',
#   'INCREASED',
#   'Heightened',
#   'Increase (qualifier value)'],
#  'C0231290': ['Status post',
#   'status post',
#   'After',
#   'after',
#   'Following',
#   'Condition following',
#   'SP',
#   'After (attribute)',
#   'Status post (contextual qualifier) [Ambiguous]',
#   'Status post (contextual qualifier) (qualifier value)',
#   'Status post -RETIRED-',
#   'Status post (contextual qualifier)',
#   'Status post (qualifier value)'],
#  'C0026566': ['Aspects of mortality statistics', 'mortality', 'MO', 'MORTAL'],
#  'C0026565': ['Mortality Vital Statistics',
#   'Death rate',
#   'death rate',
#   'Mortality',
#   'mortality',
#   'Mortalities',
#   'mortalities',
#   'Mortality rate',
#   'mortality rate',
#   'mortality rates',
#   'mortality rating',
#   'Mortality rate (observable entity)',
#   'MORTAL'],
#  'C1269765': ['Assisted (qualifier value)',
#   'Aid',
#   'Assistance',
#   'Assisted',
#   'assisted',
#   'Assist',
#   'Assists',
#   'Assists (attribute)',
#   'Requires assistance',
#   'Help'],
#  'C1261322': ['Evaluation procedure',
#   'Evaluation (procedure)',
#   'Evaluation',
#   'evaluation',
#   'assessment procedure',
#   'Assessment procedure',
#   'Investigations',
#   'Investigation',
#   'Assessment',
#   'assessment',
#   'assessments',
#   'Investigation Report',
#   'Clinical investigation',
#   'clinical investigation',
#   'Evaluation - action',
#   'Patient evaluation - action',
#   'Evaluation - action (qualifier value)',
#   'Investigation - action',
#   'Investigation - action (qualifier value)',
#   'Assessment procedure (procedure)',
#   'Clinical evaluatiion',
#   'Clinical investigation (procedure)',
#   'Patient evaluation procedure',
#   'Patient evaluation procedure (procedure)',
#   'Evaluation procedure (procedure)',
#   'Investigations (procedure)',
#   'Clinical evaluation'],
#  'C0332287': ['In addition to',
#   'Addition',
#   'With',
#   'Plus',
#   'With (attribute)',
#   'W',
#   'c',
#   'PL',
#   'Cum'],
#  'C0150411': ['Analysis of arterial blood gases and pH',
#   'Analysis of arterial blood gas (oxygen saturation, pO2, pCO2, CO2, pH); rest only',
#   'Blood Gas Analysis',
#   'ABG',
#   'Measurement of systemic arterial blood gases',
#   'Blood gases, arterial measurement',
#   'Arterial Blood Gas Measurement',
#   'ABGs measurement',
#   'Gases, arterial measurement',
#   'Blood Gas Measurement',
#   'ABG - Arterial blood gas analysis',
#   'Arterial blood gas analysis',
#   'analysis arterial blood gas',
#   'arterial blood gas analysis',
#   'Arterial blood gases',
#   'arterial blood gases',
#   'arterial blood gas',
#   'blood gas arterial',
#   'Analysis of arterial blood gases and pH (procedure)',
#   'Blood gases, arterial measurement (procedure)',
#   'Arterial bld gas measure',
#   'Arterial blood gas analysis (procedure)',
#   'arterial blood gase'],
#  'C0205171': ['Singular',
#   'singular',
#   'Single',
#   'SINGLE',
#   'single',
#   'singles',
#   'Solitary',
#   'solitary',
#   'Alone',
#   'Single - numerical descriptor',
#   'Singular (qualifier value)',
#   'Only'],
#  'C1524063': ['Use of', 'Using', 'Use of (attribute)', 'Using (attribute)'],
#  'C4541402': ['US Military Commissioned Officer O2',
#   'O2',
#   'United States Military Commissioned Officer O2',
#   '1st Lt',
#   '1stLt',
#   'Lieutenant Junior Grade',
#   '1LT',
#   'First Lieutenant',
#   'LTJG',
#   'United States Military Commissioned Officer O2 (qualifier value)'],
#  'C0184511': ['Improved',
#   'improved',
#   'Improves',
#   'Improved (qualifier value)'],
#  'C0740116': ['+2',
#   '+2 (qualifier value)',
#   'Integer +2 (qualifier value)',
#   'Integer +2'],
#  'C3816745': ['1+'],
#  'C2827734': ['1+ Score', '1+', '1 Plus Score'],
#  'C2981698': ['1+ Score, WHO', '1+', '1 Plus Score', '1+ Score'],
#  'C3833492': ['2+'],
#  'C2827735': ['2+ Score', '2+', '2 Plus Score'],
#  'C2981700': ['2+ Score, WHO', '2+', '2 Plus Score', '2+ Score'],
#  'C4280965': ['Greater than one', '>1', 'Greater than one (qualifier value)'],
#  'C4526661': ['PSA Level Less than Two',
#   'PSA Level Less Than Two',
#   '<2',
#   'PSA Level Less than 2',
#   'Less than Two'],
#  'C1706074': ['Data Table', 'Tables', 'table', 'Table'],
#  'C0039224': ['Table - furniture',
#   'table [furniture]',
#   'Table',
#   'table',
#   'Table, NOS',
#   'tables',
#   'Table, device (physical object)',
#   'Table, device',
#   'Table Device'],
#  'C3887511': ['Evidence'],
#  'C0013227': ['Pharmaceutical Preparations',
#   'pharmaceutical preparations',
#   'pharmaceutical preparation',
#   'Pharmaceutical Preparation',
#   'Preparation, Pharmaceutical',
#   'Preparations, Pharmaceutical',
#   'Drugs',
#   'drugs',
#   'Drug',
#   'drug',
#   'Drug, NOS',
#   'Medicine',
#   'Medicines',
#   'Medicine, NOS',
#   'Drug/agent',
#   'drug/agent',
#   'General drug type',
#   'Drug preparation',
#   'Drug preparation, NOS',
#   'Medication',
#   'medication',
#   'Medication, NOS',
#   'medications',
#   'Medications',
#   'Pharmaceutic Preparations',
#   'Preparations, Pharmaceutic',
#   'Drug, medicament or biological substance',
#   'Medicinal product (product)',
#   'Pharmaceuticals',
#   'Pharmaceutical',
#   'Pharmaceutical / biologic product',
#   'Pharmaceutical / biologic product (product)',
#   'Drug, medicament or biological substance (substance)',
#   'General drug type (product)',
#   'General drug type (substance)',
#   'Drug preparation (product)',
#   'Drug preparation (substance)',
#   'Drug Product',
#   'drug product',
#   'Drug product',
#   'Drug (substance)',
#   'Medicinal product',
#   'medicinal product',
#   'medicinal products',
#   'Drug or medicament',
#   'Drug or medicament (substance)',
#   'Pharmaceutical Products',
#   'Product, Pharmaceutical',
#   'Pharmaceutical Product',
#   'Products, Pharmaceutical',
#   'PHARM PREPARATIONS',
#   'PREPARATIONS PHARM'],
#  'C0004048': ['Inspiration function',
#   'Inspiration (function)',
#   'Inhalation',
#   'inhalation',
#   'inhalations',
#   'Inhaling',
#   'inhaling',
#   'Inhaled',
#   'inhaled',
#   'Inhale',
#   'Inspiration',
#   'inspiration',
#   'inspirations',
#   'Breathing in',
#   'in breathing',
#   'breathing in',
#   'breathing',
#   'Inspired',
#   'inspired',
#   'Inspiratory',
#   'inspiratory',
#   'breathing inspiration',
#   'inspiration (breathing)',
#   'respiratory aspiration',
#   'Inspiration, Respiratory',
#   'Respiratory Inspiration',
#   'Inspiration, function (observable entity)',
#   'Inhaling (qualifier value)',
#   'IH',
#   'Inhaling (observable entity)',
#   'Inspiration (observable entity)',
#   'inhal',
#   'inspir'],
#  'C0205246': ['Generalized',
#   'generalized',
#   'Generalised',
#   'General',
#   'general',
#   'Global',
#   'global',
#   'Generalized (qualifier value)'],
#  'C0024109': ['Lung',
#   'lung',
#   'LUNG',
#   'Lungs',
#   'Lung, NOS',
#   'lungs',
#   'pulmonary',
#   'Lung structure',
#   'lung structure',
#   'lung structures',
#   'Pulmo',
#   'Pulmones',
#   'Set of lungs',
#   'Lung structure (body structure)',
#   'Respiratory System, Lung',
#   'Pair of lungs',
#   'Lungs pair'],
#  'C0332282': ['Following',
#   'following',
#   'Followed By',
#   'as a result of',
#   'As a result of',
#   'Next',
#   'FO',
#   'Subsequent',
#   'subsequent',
#   'Following [Ambiguous]',
#   'Following (attribute)',
#   'Following (qualifier value)'],
#  'C1547282': ['Show'],
#  'C0439475': ['mmHg',
#   'mmhg',
#   'mmHG',
#   'millimeter of mercury',
#   'Millimeter of mercury',
#   'Millimeter of Mercury',
#   'millimetre of mercury',
#   'Millimetre of mercury',
#   'torr',
#   '{Torr}',
#   'Torr',
#   'Millimeter of mercury (qualifier value)',
#   'mmHg (qualifier value)',
#   'torr (qualifier value)',
#   'mm[Hg]',
#   'millimeter of mercury (mmHg)'],
#  'C0263428': ['Burnett Schwartz Berberian syndrome',
#   'Keratosis pilaris atrophicans faciei',
#   'Vermiculata atrophoderma',
#   'Honeycomb atrophy',
#   'Ulerythema of eyebrows',
#   'Ulerythema ophryogenes',
#   'ophryogenes ulerythema',
#   'ulerythema ophryogenes',
#   'Ulerythema ophryogenesis',
#   'Keratosis pilaris atrophicans',
#   'keratosis pilaris atrophicans',
#   'KERATOSIS PILARIS ATROPHICANS',
#   'KPA',
#   'Keratosis pilaris atrophicans (disorder)',
#   'Ulerythema of eyebrows (disorder)',
#   'Ulerythema ophryogenes (disorder)',
#   'Atrophodermia vermiculata',
#   'Folliculitis ulerythematosa',
#   'Keratosis Pilaris Atrophicans Facies',
#   'Ulerythema ophryogenes with multiple congenital anomalies'],
#  'C0439474': ['Kilopascal',
#   'kilopascal',
#   'kPa',
#   'kpa',
#   'Kilopascal (qualifier value)',
#   'kPa (qualifier value)',
#   'kilopascal (kPa)'],
#  'C0596070': ['Americas Ethnicity',
#   'Americas',
#   'American',
#   'americans',
#   'American Ethnicity'],
#  'C0205166': ['Long', 'long', 'LONG', 'Elongated', 'Long (qualifier value)'],
#  'C1706317': ['Long Variable', 'Long', 'Long Value', 'Long Data Type'],
#  'C0037981': ['Spirometry',
#   'spirometry',
#   'SPIROMETRY',
#   'Spirometries',
#   'spirometry test',
#   'spirometry testing',
#   'spirometry tests',
#   'Spirometry (procedure)'],
#  'C4084912': ['Importance Rating Score 0',
#   'Important',
#   'Importance 0',
#   'Importance Score 0'],
#  'C3898777': ['Important'],
#  'C4723674': ['ACTG1 wt Allele',
#   'ACT',
#   'Deafness, Autosomal Dominant 20/26 Gene',
#   'HEL-176',
#   'Actin Gamma 1 wt Allele',
#   'Actin, Cytoplasmic, 2 Gene',
#   'Actin, Gamma Gene',
#   'ACTG',
#   'Deafness, Autosomal Dominant 20 Gene',
#   'Deafness, Autosomal Dominant 26 Gene',
#   'DFNA20',
#   'DFNA26'],
#  'C1704930': ['ACTG2 wt Allele',
#   'ACT',
#   'VSCM',
#   'ACTL3',
#   'Actin, Alpha-3 Gene',
#   'ACTA3',
#   'ACTE',
#   'ACTSG',
#   'Actin, Gamma-2, Smooth Muscle, Enteric Gene',
#   'Actin, Gamma 2, Smooth Muscle, Enteric wt Allele'],
#  'C0079613': ['Adoptive Immunotherapy',
#   'adoptive immunotherapy',
#   'Adoptive Immunotherapies',
#   'Immunotherapies, Adoptive',
#   'Immunotherapy, Adoptive',
#   'ACT',
#   'Adoptive Cell Transfer',
#   'Adoptive Cellular Immunotherapy',
#   'cellular adoptive immunotherapy',
#   'adoptive cellular immunotherapy',
#   'Adoptive Cellular Immunotherapies',
#   'Cellular Immunotherapies, Adoptive',
#   'Immunotherapies, Adoptive Cellular',
#   'Cellular Immunotherapy, Adoptive',
#   'Immunotherapy, Adoptive Cellular',
#   'ACT Therapy',
#   'Adoptive Cell Transfer Immunotherapy',
#   'Adoptive Cell Transfer Therapy',
#   'Adoptive Cell Immunotherapy',
#   'adoptive cell immunotherapy',
#   'IMMUNOTHER ADOPTIVE CELLULAR',
#   'CELLULAR IMMUNOTHER ADOPTIVE',
#   'ADOPTIVE CELLULAR IMMUNOTHER',
#   'IMMUNOTHER ADOPTIVE',
#   'ADOPTIVE IMMUNOTHER',
#   'adoptive cellular therapy'],
#  'C4048375': ['Asthma Control Test Questionnaire',
#   'ACT',
#   'ACT01',
#   'Asthma control test (assessment scale)',
#   'Asthma control test',
#   'Asthma Control Test'],
#  'C5203115': ['GDC AJCC Clinical T Terminology', 'ACT', 'ajcc_clinical_t'],
#  'C1869853': ['SERPINA3 protein, human',
#   'ACT',
#   'Alpha-1-Antichymotrypsin',
#   'Growth-Inhibiting Protein 25',
#   'Cell Growth-Inhibiting Gene 24/25 Protein',
#   'Growth-Inhibiting Protein 24',
#   'serpin A3 protein, human',
#   'serpin peptidase inhibitor, clade A (alpha-1 antiproteinase, antitrypsin), member 3, human',
#   'Serpin A3'],
#  'C3890007': ['SERPINA3 wt Allele',
#   'ACT',
#   'Antichymotrypsin, Alpha-1 Gene',
#   'Cell Growth-Inhibiting Gene 24/25',
#   'Serpin Peptidase Inhibitor, Clade A (Alpha-1 Antiproteinase, Antitrypsin), Member 3 wt Allele',
#   'Serine (Or Cysteine) Proteinase Inhibitor, Clade A, Member 3 Gene',
#   'Serine Proteinase Inhibitor, Clade A, Member 3 Gene',
#   'GIG25',
#   'GIG24',
#   'Serine (Or Cysteine) Proteinase Inhibitor, Clade A (Alpha-1 Antiproteinase, Antitrypsin), Member 3 Gene',
#   'AACT'],
#  'C3838680': ['3+ Answer to Question', '3+'],
#  'C2827736': ['3+ Score', '3+', '3 Plus Score'],
#  'C2981702': ['3+ Score, WHO', '3+', '3 Plus Score', '3+ Score'],
#  'C0439086': ['<3 (qualifier value)', '<3'],
#  'C0439044': ['Living Alone',
#   'alone living',
#   'Living alone',
#   'living alone',
#   'Lives alone',
#   'Lives Alone',
#   'Alone',
#   'alone',
#   'Lives alone (finding)',
#   'home alone',
#   'Home alone',
#   'alone home'],
#  'C0679994': ['alone - group size', 'alone'],
#  'C1707101': ['CD44 wt Allele',
#   'IN',
#   'MC56',
#   'CDW44',
#   'CD44 Molecule (Indian Blood Group) wt Allele',
#   'MDU2',
#   'HUTCH-I',
#   'ECMR-III',
#   'MDU3',
#   'Pgp1',
#   'CD44 Antigen (Homing Function and Indian Blood Group System) Gene',
#   'LHR',
#   'HCELL',
#   'MIC4',
#   'CSPG8'],
#  'C0332285': ['Within',
#   'In',
#   'in',
#   'Of',
#   'Found in',
#   'Arising from',
#   'Inside',
#   'Located in',
#   'In (attribute)',
#   'Has location',
#   'Has setting'],
#  'C1457887': ['Symptoms',
#   'SYMPTOMS',
#   'Symptom, NOS',
#   'symptom',
#   'SYMPTOM',
#   'Symptom',
#   '[D]Symptoms',
#   '[D]Symptoms NOS',
#   'general manifestation of disorders',
#   '[D]Symptoms NOS (context-dependent category)',
#   '[D]Symptoms (context-dependent category)',
#   'Symptom (finding)',
#   '[D]Symptoms (situation)',
#   '[D]Symptoms NOS (situation)',
#   'Symptom (administrative concept)'],
#  'C0683368': ['Symptoms aspect', 'symptoms'],
#  'C0034866': ['Recommendation',
#   'recommendation',
#   'recommendations',
#   'Recommended',
#   'recommended',
#   'recommends',
#   'recommend'],
#  'C0332283': ['Followed by',
#   'followed by',
#   'followed',
#   'follows',
#   'follow',
#   'FB',
#   'Followed by [Ambiguous]',
#   'Followed by (attribute)',
#   'Followed by (qualifier value)'],
#  'C0015259': ['Exercise',
#   'exercise',
#   'Exercises',
#   'exercises',
#   'Exercise, Physical',
#   'physical exercise',
#   'Physical exercise',
#   'Exercises, Physical',
#   'Physical Exercises',
#   'Physical exercise, NOS',
#   'Physical exercise NOS',
#   'Physical exercises',
#   'physical exercises',
#   'Physical Exercise',
#   'Physical Activity',
#   'Physical Activities',
#   'Activities, Physical',
#   'Activity, Physical',
#   'physical conditioning',
#   'Physical exercises (procedure)',
#   'Physical exercise NOS (procedure)',
#   'Physical exercise (qualifier value)',
#   'Physical exercises (regime/therapy)',
#   'Physical exercise NOS (regime/therapy)',
#   'Exercise (qualifier value)',
#   'Exercise (observable entity)',
#   'Physical exercise (observable entity)',
#   'Exercise Type'],
#  'C5212823': ['Exercise capacity'],
#  'C0205172': ['More', 'more', 'More (qualifier value)'],
#  'C0037313': ['Sleep',
#   'sleep',
#   'Sleep, NOS',
#   'Sleeping',
#   'sleeping',
#   'sleeps',
#   'Sleep (biological function) [Ambiguous]',
#   'Sleep, function (observable entity)',
#   'Sleep (qualifier value)',
#   'Sleep, function',
#   'Sleep (biological function) (observable entity)'],
#  'C4050225': ['Often - answer to question', 'Often'],
#  'C0470187': ['Availability of',
#   'availability of',
#   'Availability',
#   'availability',
#   'Available',
#   'available',
#   'Availability of (contextual qualifier) (qualifier value)',
#   'Availability of (contextual qualifier)'],
#  'C0456079': ['Disease classification level', 'Level', 'Level (attribute)'],
#  'C1547707': ['Floor - story of building', 'Floor', 'Level', 'Story'],
#  'C1522538': ['Leading', 'Lead'],
#  'C0449295': ['Limitation',
#   'limitation',
#   'limitations',
#   'Limitation (attribute)'],
#  'C0282423': ['Guideline [Publication Type]',
#   'Guideline',
#   'guideline',
#   'guidelines',
#   'guideline [reference materials]'],
#  'C0162791': ['Guidelines',
#   'guidelines',
#   'Guideline',
#   'Guidelines as Topic',
#   'Guidelines as Topics'],
#  'C0443288': ['Restricted',
#   'restricted',
#   'restricting',
#   'restricts',
#   'restrict',
#   'Limitation',
#   'Restricted (qualifier value)',
#   'Restriction',
#   'Constraint'],
#  'C0521116': ['Current (present time)',
#   'Current',
#   'CURRENT',
#   'current',
#   'currents',
#   'Currently',
#   'currently',
#   'Current (qualifier value)'],
#  'C0205360': ['Stable status',
#   'Stable',
#   'STABLE',
#   'stable',
#   'stabling',
#   'Stable (qualifier value)',
#   'Stability',
#   'stability',
#   'stabilities'],
#  'C1254351': ['Pharmacologic Substance',
#   'Drug',
#   'drug',
#   'DRUG',
#   'Agent',
#   'Pharmaceuticals',
#   'Drug Substance',
#   'Pharmaceutical Agent',
#   'Pharmacological Substance',
#   'Pharmacologic Agent'],
#  'C1947933': ['care activity', 'Care'],
#  'C0549186': ['Obstructed', 'obstructed', 'Obstructed (qualifier value)'],
#  'C1552861': ['Help document', 'help'],
#  'C0199470': ['Mechanical ventilation',
#   'Ventilation, Mechanical',
#   'Ventilation-mechanical',
#   'Mechanical Ventilation',
#   'MECHANICAL VENTILATION',
#   'mechanical ventilation',
#   'Mechanical Ventilations',
#   'Ventilations, Mechanical',
#   'Mechanical ventilation, NOS',
#   'Mechanical ventilation NOS',
#   'Respiratory assist, mechanical',
#   'mechanical respiratory assist',
#   'Mechanically assisted breathing',
#   'Mechanically assisted ventilation',
#   'Mechanical respiratory assistance NOS',
#   'Mechanically assisted breathing (procedure)',
#   'Mechanical ventilation (procedure) [Ambiguous]',
#   'Mechanical respiratory assistance NOS (procedure)',
#   'Mechanical assistance to resp.',
#   'Mechanical ventilation (procedure)',
#   'Respiratory assist, mechanical (procedure)'],
#  'C4760388': ['Mechanical ventilation finding', 'Mechanical ventilation'],
#  'C1522704': ['Exercise Pain Management', 'Exercise'],
#  'C4281991': ['Follow',
#   'Per',
#   'Complies With',
#   'complies with',
#   'Complies',
#   'In Accordance With',
#   'In Accordance',
#   'Adhere To'],
#  'C1719822': ['Follow - dosing instruction imperative',
#   'Follow',
#   'Follow - dosing instruction imperative (qualifier value)'],
#  'C0336789': ['Combine',
#   'combine',
#   'Combine, NOS',
#   'combines',
#   'Combine, device (physical object)',
#   'Combine, device'],
#  'C0332281': ['Associated with',
#   'associated with',
#   'associated',
#   'associating',
#   'Associated',
#   'AW',
#   'Associated with (attribute)'],
#  'C0018017': ['objective (goal)',
#   'goals objectives',
#   'goal objective',
#   'Goals',
#   'goals',
#   'Goal',
#   'goal',
#   'Objective',
#   'objective',
#   'objectives',
#   'target (goal)',
#   'Goal context',
#   'Goal context (qualifier value)'],
#  'C4284286': ['C2 wt Allele',
#   'CO2',
#   'ARMD14',
#   'Complement Component 2 wt Allele'],
#  'C2347816': ['cobaltous cation',
#   'COBALTOUS CATION',
#   'Cobaltous Cation',
#   'Cobaltous cation',
#   'Co2+',
#   'Co(II)',
#   'Cobalt 2+'],
#  'C1516048': ['Assessed', 'Assess', 'Assessment', 'assessment'],
#  'C3854307': ['Presence (property)',
#   'Presence',
#   'Presence (property) (qualifier value)'],
#  'C0392148': ['Providing presence (regime/therapy)',
#   'Presence',
#   'presence',
#   'presences',
#   'Providing presence'],
#  'C0814225': ['Benefit',
#   'benefit',
#   'benefiting',
#   'benefitting',
#   'benefits',
#   'Benefits'],
#  'C2987634': ['Agonist',
#   'agonist',
#   'agonists',
#   'Substance with receptor agonist mechanism of action (substance)',
#   'Receptor agonist',
#   'Receptor Agonist',
#   'RECEPTOR AGONIST'],
#  'C1561611': ['Admission Level of Care Code - Improved', 'Improved'],
#  'C4082212': ['Adult human body', 'Body'],
#  'C0227230': ['Body of stomach',
#   'BODY OF STOMACH',
#   'body of stomach',
#   'Body of Stomach',
#   'stomach body',
#   'Gastric corpus',
#   'Corpus gastricum (ventriculare)',
#   'Gastric body',
#   'Gastric corpus structure (body structure)',
#   'Gastric corpus structure',
#   'Corpus gastricum',
#   'Corps gastrique',
#   'Corpo gastrico'],
#  'C1268086': ['Body structure',
#   'structure body',
#   'body structure',
#   'Body structures',
#   'body structures',
#   'Body',
#   'Body structure (body structure)'],
#  'C0242821': ['Human body',
#   'Body, Human',
#   'body human',
#   'Human Body',
#   'human body',
#   'Bodies, Human',
#   'Human Bodies',
#   'Human Figure',
#   'Figures, Human',
#   'Human Figures',
#   'Figure, Human',
#   'body',
#   'bodies'],
#  'C0460148': ['Human body structure',
#   'body human structure',
#   'human body structure',
#   'Human body',
#   'body structures',
#   'Body',
#   'Human body structure (body structure)'],
#  'C0444584': ['Whole body',
#   'body whole',
#   'Body, Whole',
#   'whole body',
#   'Whole Body',
#   'Body as a Whole',
#   'Body',
#   'BODY',
#   'Whole body (qualifier value)'],
#  'C0301630': ['Reduction (chemical)',
#   'chemical reduction',
#   'Reduction, Chemical',
#   'Electron gain',
#   'Reduction',
#   'reduction',
#   'reductions',
#   'Reduction (chemical), function (observable entity)',
#   'Reduction (chemical), function',
#   'Reduction (chemical) (function)'],
#  'C1293152': ['Reduction procedure',
#   'Reduction',
#   'Reduction procedure (procedure)'],
#  'C4551656': ['Surgical reduction',
#   'surgical reduction',
#   'Reduction',
#   'reduction',
#   'reductions',
#   'Reduction plasty',
#   'Reduction plasty (qualifier value)'],
#  'C1547311': ['Patient Condition Code - Stable', 'Stable'],
#  'C0424093': ['Initiative',
#   'initiative',
#   'initiatives',
#   'Initiative (observable entity)'],
#  'C0231999': ['Airflow',
#   'airflow',
#   'Airflow, NOS',
#   'Airflow, function (observable entity)',
#   'Airflow, function',
#   'Airflow (function)'],
#  'C0282111': ['Internet',
#   'internet',
#   'Web',
#   'WWW (world wide web)',
#   'World Wide Web',
#   'world wide web',
#   'Web, World Wide',
#   'Wide Web, World',
#   'WWW',
#   'www'],
#  'C1552740': ['Entity Determiner - specific',
#   'specific',
#   'EntityDeterminerSpecific'],
#  'C0205369': ['Specific qualifier value',
#   'Specific (qualifier value)',
#   'Specific',
#   'specific',
#   'Specified',
#   'specified'],
#  'C1282927': ['Shortened',
#   'shortened',
#   'shortens',
#   'shorten',
#   'short',
#   'brief',
#   'Shortened (qualifier value)'],
#  'C1705690': ['With - dosing instruction fragment',
#   'With',
#   'With - dosing instruction fragment (qualifier value)'],
#  'C0282443': ['Review [Publication Type]',
#   'Review',
#   'review',
#   'reviewed',
#   'reviewing',
#   'reviews'],
#  'C1412045': ['A1BG gene',
#   'ALPHA-1-B-GLYCOPROTEIN',
#   'alpha-1-B glycoprotein',
#   'ABG',
#   'A1B',
#   'GAB',
#   'A1BG'],
#  'C0220825': ['Evaluation',
#   'evaluation',
#   'evaluations',
#   'Investigation',
#   'effectiveness assessment',
#   'efficacy assessment',
#   'Assessment - action',
#   'Assessment - action (qualifier value)',
#   'Evaluation Procedure',
#   'Evaluate',
#   'Evaluated'],
#  'C0011900': ['Diagnosis',
#   'diagnosis',
#   'DIAGNOSIS',
#   'Diagnoses',
#   'diagnosed',
#   'diagnoses',
#   'diagnose',
#   'diagnosing',
#   'Diagnose',
#   '{Diagnosis}',
#   'Diagnosed',
#   'Diagnostic',
#   'Dx',
#   'DIAG',
#   'Diagnosis (observable entity)',
#   'diagnosis (DX)'],
#  'C0015127': ['Etiology aspects',
#   'etiology',
#   'aetiology',
#   'etiologies',
#   'causes',
#   'caused by',
#   'cause',
#   'ET',
#   'causality',
#   'ETIOL'],
#  'C1524003': ['Science of Etiology',
#   'Etiology',
#   'etiology',
#   'Cause',
#   'Causation'],
#  'C0020440': ['Hypercapnia',
#   'HYPERCAPNIA',
#   'hypercapnia',
#   'Hypercapnia, NOS',
#   'Carbon dioxide, increased level',
#   'Hypercapnemia',
#   'Hypercapnemia, NOS',
#   'Hypercapnaemia',
#   'PCO2 INCREASED ON ARTERIAL BLOOD GAS',
#   'CARBON DIOXIDE BLOOD INCREASED',
#   'BLOOD CO2 INCREASED',
#   'SERUM CARBON DIOXIDE INCREASED',
#   'carbon dioxide retention',
#   'RETENTION CARBON DIOXIDE',
#   'Hypercarbia',
#   'HYPERCARBIA',
#   'hypercarbia',
#   'Hypercarbia, NOS',
#   'High blood carbon dioxide level',
#   'hypercapnic',
#   'co2 retention',
#   'Hypercapnia (disorder)'],
#  'C3275067': ['Cardiac Lead Procedure', 'LEAD', 'Lead Procedure'],
#  'C2348269': ['Dietary Lead', 'Lead', 'Pb'],
#  'C0181586': ['Leads (device)', 'Lead Device', 'Lead', 'LEAD', 'leads'],
#  'C1442948': ['Plumbum metallicum, homeopathic preparation',
#   'lead',
#   'lead preparation',
#   'lead preparation (homeopathy)'],
#  'C0023175': ['lead',
#   'Lead',
#   'LEAD',
#   'Lead, NOS',
#   '???lead',
#   'Lead Metal',
#   'Pb - Lead',
#   'lead (Pb)',
#   'Pb',
#   'Lead analyte',
#   'Pb element',
#   'Lead analyte (substance)',
#   'Lead (substance)',
#   'Metallic Lead'],
#  'C0030685': ['Patient Discharge',
#   'Patient discharge',
#   'patient discharge',
#   'Discharges, Patient',
#   'Patient Discharges',
#   'Patient discharge, NOS',
#   'Discharge, Patient',
#   'Discharge',
#   'discharge',
#   'Discharged',
#   'Release',
#   'Discharge procedure',
#   'Patient discharge (procedure)',
#   'Discharge from Healthcare Facility'],
#  'C1274039': ['General surgery specialty',
#   'Surgery',
#   'General Surgery',
#   'surgery general',
#   'Surgery.general',
#   'general surgery',
#   'General surgery',
#   'Surgery, General',
#   'SURG',
#   'General surgery (qualifier value)'],
#  'C1363945': ['Therapy Object (animal model)', 'Therapy', 'Therapy Object'],
#  'C0184633': ['Oxygen Therapy Care',
#   'Oxygen therapy care',
#   'On oxygen',
#   'Oxygen Inhalation Therapy',
#   'oxygen inhalation therapy',
#   'Inhalation Therapies, Oxygen',
#   'Oxygen Inhalation Therapies',
#   'Therapies, Oxygen Inhalation',
#   'Inhalation Therapy, Oxygen',
#   'Therapy, Oxygen Inhalation',
#   'Oxygen therapy',
#   'Oxygen Therapy',
#   'oxygen therapy',
#   'Oxygen therapy, NOS',
#   'oxygen therapies',
#   'O2 therapy',
#   'o2 therapy',
#   'oxygen administration',
#   'oxygenation therapy',
#   'Oxygen therapy (procedure)',
#   'INHALATION THER OXYGEN',
#   'OXYGEN INHALATION THER',
#   'THER OXYGEN INHALATION',
#   'Oxygen therapy (regime/therapy)',
#   'supplemental oxygen therapy'],
#  'C2362652': ['Possible diagnosis',
#   'Possible',
#   'Possibly',
#   'PD',
#   'Possible diagnosis (contextual qualifier) (qualifier value)',
#   'Possible diagnosis (contextual qualifier)'],
#  'C0038952': ['Continuance of life',
#   'Survival',
#   'survival',
#   'survivals',
#   'Survivorship',
#   'survivorship',
#   'Survivorship Issues'],
#  'C0220921': ['survival aspects', 'survival'],
#  'C0013990': ['Pathological accumulation of air in tissues',
#   'Emphysema',
#   'EMPHYSEMA',
#   'emphysema',
#   'Emphysema NOS',
#   'Emphysema, NOS',
#   'Emphysema (morphologic abnormality)',
#   'Emphysema NOS (morphologic abnormality)',
#   'abnormal collection of air in tissues'],
#  'C0034067': ['ENFISEMA/ BRONKONEUMOPATIA KRONIKO OBSTRUKTIBOA',
#   'Emfysem/kronisk obst lungesygdom',
#   'Emfyseem/COPD',
#   'Pulmonary Emphysema',
#   'EMPHYSEMA PULMONARY',
#   'EMPHYSEMA, PULMONARY',
#   'Pulmonary emphysema',
#   'PULMONARY EMPHYSEMA',
#   'pulmonary emphysema',
#   'Emphysemas, Pulmonary',
#   'Pulmonary Emphysemas',
#   'Pulmonary emphysema, NOS',
#   'Emphysema, Pulmonary',
#   'Emphysema',
#   'EMPHYSEMA',
#   'emphysema',
#   'Emphysema of lung',
#   'Emphysema of lung, NOS',
#   'lung emphysema',
#   'Emphysema/COPD',
#   'Pulmonary emphysema (disorder)',
#   'EMPHYSEMA PULM',
#   'EMPHYSEMAS PULM',
#   'PULM EMPHYSEMAS',
#   'PULM EMPHYSEMA',
#   'Emphysema (disorder)',
#   'KEUHKOLAAJENTUMA(EMFYSEEMA)/ KROONINEN OBSTRUKTIIVINEN KEUHKOSAIRAUS',
#   'Emphyseme/BPCO/MPCO',
#   'Emphysem/chron obstrukt Lungenkr',
#   'maxalat reot xasimatit',
#   'emphysema',
#   'Enfisema/BPCO',
#   'EMFYSEM/KRON OBSTRUKTIV LUNGESYKD',
#   'Enfisema/DPCO',
#   'Enfisema/E.P.O.C.',
#   'EMFYSEM/KRONISK OBSTRUKTIV LUNGSJKD'],
#  'C0243192': ['agonists', 'AG', 'AGON'],
#  'C2348382': ['Effect, Appearance', 'Effect'],
#  'C1518681': ['Outcome of Therapy',
#   'Therapy Outcome',
#   'effect',
#   'Therapy Effect',
#   'Treatment Effect',
#   'treatment effect'],
#  'C1707455': ['Comparison', 'Compare', 'Compared'],
#  'C0027361': ['Persons',
#   'persons',
#   'Person',
#   'person',
#   'Individual',
#   'People',
#   'people',
#   'peoples',
#   'Person [dup] (person)',
#   'Person (person)'],
#  'C1279901': ['Firstly',
#   'Initial',
#   'First',
#   'First (modifier) [Ambiguous]',
#   'Firstl (qualifier value)',
#   'Firstly (qualifier value)',
#   'First (modifier) (qualifier value)'],
#  'C0543467': ['Operative Surgical Procedures',
#   'Operative Surgical Procedure',
#   'Procedure, Operative Surgical',
#   'Surgical Procedure, Operative',
#   'Procedures, Operative Surgical',
#   'Surgical Procedures, Operative',
#   'Operative Procedures',
#   'operative procedures',
#   'Operative procedures',
#   'Operative procedure',
#   'Procedure, Operative',
#   'Operative procedure, NOS',
#   'Operative Procedure',
#   'operative procedure',
#   'Procedures, Operative',
#   'Surgery',
#   'surgery',
#   'surgeries',
#   'Surgery, NOS',
#   'Surgery, Operative',
#   'operative surgery',
#   'Operation',
#   'operation',
#   'Operation, NOS',
#   'Surgical',
#   'operation (surgery)',
#   'Surgical Procedures',
#   'surgical procedures',
#   'Surgical procedures',
#   'Surgical procedure',
#   'Surgical procedure, NOS',
#   'surgical procedure',
#   'Procedure, Surgical',
#   'Surgical Procedure',
#   'Procedures, Surgical',
#   'Surg',
#   'SURG',
#   'Surgical Interventions',
#   'surgical treatment',
#   'surgical treatments',
#   'Surgery procedure',
#   'surgery procedure',
#   'Surgical procedure (procedure)',
#   'Surgery (qualifier value)',
#   'Surgical (qualifier value)',
#   'H&P.SURG PROC',
#   'OPERATIVE SURG PROCEDURES',
#   'OPERATIVE SURG PROCEDURE',
#   'PROCEDURE OPERATIVE SURG',
#   'SURG PROCEDURE OPERATIVE',
#   'PROCEDURES OPERATIVE SURG',
#   'SURG PROCEDURES OPERATIVE',
#   'Surgically'],
#  'C0038895': ['Surgical aspects',
#   'operative procedures',
#   'surgery',
#   'operations',
#   'invasive procedures',
#   'operative therapy',
#   'SURG',
#   'SU'],
#  'C0184666': ['Hospital admission',
#   'admission hospital',
#   'Hospital Admission',
#   'hospital admission',
#   'Hospital admission, NOS',
#   'admissions hospital',
#   'hospital admissions',
#   'Admission to hospital',
#   'admission to hospital',
#   'Admission',
#   'admission',
#   'admissions',
#   'Admit',
#   'admit',
#   'admits',
#   'admitted',
#   'admitting',
#   'admitted hospital',
#   'Hospital admission (procedure)',
#   'Admission to hospital (procedure)'],
#  'C0679830': ['patient assessment',
#   'assessment patients',
#   'assessments patients',
#   'assessments patient',
#   'assessment patient',
#   'client assessment',
#   'assessments client',
#   'client pre-assessment',
#   'patient pre-assessment',
#   'client evaluation',
#   'patient evaluation',
#   'evaluation patients',
#   'evaluation patient',
#   'patient work-up'],
#  'C0700292': ['Hypoxemia',
#   'HYPOXEMIA',
#   'hypoxemia',
#   'Hypoxaemia',
#   'hypoxaemia',
#   'hypoxemias',
#   'Arterial hypoxemia',
#   'arterial hypoxemia',
#   'Arterial hypoxaemia',
#   'arterial hypoxaemia',
#   '[D]Hypoxaemia',
#   '[D]Hypoxemia',
#   'Low blood oxygen level',
#   '[D]Hypoxemia (context-dependent category)',
#   'Hypoxemia (disorder)',
#   '[D]Hypoxemia (situation)'],
#  'C0439793': ['Severities',
#   'Severity',
#   'With severity',
#   'severity',
#   'SEV',
#   'Severity/Intensity',
#   'Severity (attribute)',
#   'With severity (attribute)',
#   'Severities (qualifier value)'],
#  'C0085555': ['Hospice Care',
#   'care hospice',
#   'hospice care',
#   'Hospice care',
#   'Care, Hospice',
#   'Hospice',
#   'hospice',
#   'hospices',
#   'End of Life Care',
#   'care end of life',
#   'care end-of-life',
#   'End-of-life care',
#   'end of life care',
#   'end-of-life care',
#   'Hospice care (regime/therapy)'],
#  'C0205250': ['High',
#   'high',
#   'Higher',
#   'Elevated',
#   'elevated',
#   'elevate',
#   'High (qualifier value)',
#   'Highly'],
#  'C0008976': ['Clinical Trials',
#   'CLINICAL TRIALS',
#   'Clinical trials',
#   'clinical trials',
#   'Clinical Trial',
#   'clinical trial',
#   'Clinical trial',
#   'CLINTRIAL',
#   'Clinical trial (procedure)',
#   'Clinical trials (procedure)',
#   'Clinical Trials, Unspecified',
#   'Trial',
#   'Clinical Trials as Topic',
#   'Clinical Trial as Topic'],
#  'C0445247': ['Same', 'SAME', 'same', 'Same (qualifier value)', 'Idem'],
#  'C0024115': ['Lung diseases',
#   'Diseases, Lung',
#   'Lung Diseases',
#   'lung diseases',
#   'Lung Disease',
#   'Disease, Lung',
#   'Disease of lung, NOS',
#   'Lung disease NOS',
#   'disease of lung',
#   'diseases lungs',
#   'diseases of the lung',
#   'Lungs--Diseases',
#   'Lung disease',
#   'Disease of lung',
#   'lung disease',
#   'Lung',
#   'Pulmonary Diseases',
#   'diseases pulmonary',
#   'pulmonary diseases',
#   'Disease, Pulmonary',
#   'Pulmonary Disease',
#   'PULMONARY DISEASE',
#   'pulmonary disease',
#   'Pulmonary disease, NOS',
#   'Pulmonary disease',
#   'Diseases, Pulmonary',
#   'Disorder of lung',
#   'Disorder of Lung',
#   'LUNG DISORDER',
#   'DISORDER LUNG',
#   'LUNG DISORDER (NOS)',
#   'Lung Disorders',
#   'lung disorder',
#   'Lung disorder, NOS',
#   'disorder lung',
#   'disorders lung',
#   'lung disorders',
#   'Lung disorder',
#   'Lung Disorder',
#   'Pulmonary Disorders',
#   'disorders pulmonary',
#   'pulmonary disorders',
#   'PULMONARY DISORDERS',
#   'DISORDER PULMONARY',
#   'PULMONARY DISORDER',
#   'pulmonary disorder',
#   'Pulmonary Disorder',
#   'pneumopathy',
#   'Lung disease NOS (disorder)',
#   'Disease of lung (disorder)',
#   'Disorder of lung (disorder)',
#   'LUNG DIS',
#   'DIS PULM',
#   'PULM DIS'],
#  'C2348867': ['Global'],
#  'C0557034': ['Assisting (procedure)',
#   'assisting procedure',
#   'assisting procedures',
#   'patient assistance',
#   'Patient assistance',
#   'Patient assistance, NOS',
#   'Assisting',
#   'assisting',
#   'assist',
#   'Patient assistance (procedure)'],
#  'C0205197': ['Complete',
#   'complete',
#   'COMPLETE',
#   'COMPLETED',
#   'Completed',
#   'Completely',
#   'Complete (modifier) [Ambiguous]',
#   'Complete (qualifier value)',
#   'Completion',
#   'Complete (modifier) (qualifier value)'],
#  'C0024501': ['Maintenance', 'maintenance', 'Maintenances', 'Maintain'],
#  'C0453996': ['Tobacco smoking behavior',
#   'Tobacco smoking behaviour',
#   'Smoking',
#   'Tobacco Smoking',
#   'smoking tobacco',
#   'TOBACCO SMOKING',
#   'Tobacco smoking',
#   'tobacco smoking',
#   'Smoking, Tobacco',
#   'Tobacco smoking behavior (observable entity)',
#   'Finding of tobacco smoking behavior (finding)',
#   'Tobacco smoking behavior - finding',
#   'Finding of tobacco smoking behaviour',
#   'Tobacco smoking behaviour - finding',
#   'Finding of tobacco smoking behavior'],
#  'C0332152': ['Before',
#   'before',
#   'BEFORE',
#   'Leading',
#   'Status pre-',
#   'Prior to',
#   'prior to',
#   'Prior',
#   'Condition before',
#   'Preceding',
#   'preceding',
#   'preceded',
#   'Pre',
#   'Status pre- (contextual qualifier) [Ambiguous]',
#   'Before (attribute)',
#   'Status pre- (contextual qualifier) (qualifier value)',
#   'Status pre- (contextual qualifier)'],
#  'C1542147': ['Main', 'Predominant'],
#  'C4321249': ['DIAPH3 wt Allele',
#   'Diaphanous Homolog 3 Gene',
#   'DIAP3',
#   'diap3',
#   'Diaphanous-Related Formin 3 wt Allele',
#   'mDia2',
#   'Auditory Neuropathy, Autosomal Dominant 1 Gene',
#   'Diaphanous (Drosophila, Homolog) 3 Gene',
#   'Diaphanous, Drosophila, Homolog of, 3 Gene',
#   'Diaphanous Homolog 3 (Drosophila) Gene',
#   'AN',
#   'FLJ34705',
#   'DIA2',
#   'DRF3',
#   'NSDAN',
#   'AUNA1'],
#  'C0031809': ['Physical Examination',
#   'Physical examination',
#   'physical examination',
#   'PHYSICAL EXAMINATION',
#   'Examinations, Physical',
#   'Physical Examinations',
#   'Physical examination, NOS',
#   'physical examinations',
#   'Examination, Physical',
#   'Physical Exam',
#   'EXAM PHYSICAL',
#   'physical exam',
#   'Physical exam',
#   'PHYSICAL EXAM',
#   'Exams, Physical',
#   'Physical Exams',
#   'Exam, Physical',
#   'General physical examination',
#   'Physical examination procedure',
#   'physical examination procedure',
#   'Physical',
#   'Physical assessment',
#   'assessment physical',
#   'physical assessment',
#   'Physical Assessment',
#   'Physical assessment, NOS',
#   'assessments physical',
#   'Clinical examination',
#   'clinical examination',
#   'Clinical examination, NOS',
#   'clinical examinations',
#   'Examination of patient',
#   'patient examination',
#   'Assessment',
#   'assessment',
#   'Examination - action',
#   'Examination',
#   'examination',
#   'examinations',
#   'Clinical examination - action',
#   'General Examination',
#   'Physical examination -action',
#   'Physical examination - action',
#   'Physical examination - action (qualifier value)',
#   'Examination - action (qualifier value)',
#   'Physical assessment (procedure)',
#   'Physical examination procedure (procedure)',
#   'Physical assessment (regime/therapy)',
#   'PE - Physical examination',
#   'General physical exam',
#   'examination procedure',
#   'Examination (procedure)'],
#  'C4084774': ['Have Weight Loss',
#   'Weight loss',
#   'Weight Loss',
#   'Have you lost weight'],
#  'C4084777': ['How Much Distress Weight Loss', 'Weight loss'],
#  'C4084776': ['How Often Weight Loss',
#   'Weight loss',
#   'Frequency of Weight Loss',
#   'Weight Loss Frequency'],
#  'C5203233': ['Measured weight loss (observable entity)',
#   'Weight loss',
#   'Measured weight loss'],
#  'C4084775': ['Usual Severity Weight Loss', 'Weight loss'],
#  'C2911645': ['Weight Loss, CTCAE', 'Weight Loss', 'Weight loss'],
#  'C1262477': ['PISUA GALTZEA(ESKL.T06)',
#   'Vaegttab',
#   'Gewichtsverlies',
#   'Weight decreased',
#   'decreased weight',
#   'Decreased weight',
#   'WEIGHT DECREASE',
#   'Weight decreasing',
#   'decrease weight',
#   'decreases weight',
#   'weight decrease',
#   'Weight Decrease',
#   'Abnormal loss of weight',
#   'Weight Loss',
#   'loss weight',
# ...
#   'contents',
#   'Content',
#   'content',
#   'Contents (attribute)'],
#  'C0449450': ['Presentation',
#   'presentation',
#   'presentations',
#   'Present',
#   'Presented',
#   'Presenting',
#   'Presentation (attribute)'],
#  'C0037315': ['Sleep Apnea Syndromes',
#   'Sleep apnea syndromes',
#   'sleep apnea syndromes',
#   'Sleep apnea syndrome',
#   'Apnea Syndrome, Sleep',
#   'Sleep Apnea Syndrome',
#   'sleep apnea syndrome',
#   'Sleep apnoea syndrome',
#   'sleep apnoea syndrome',
#   'SLEEP APNEA SYNDROME',
#   'Syndrome sleep apnea',
#   'Syndrome sleep apnoea',
#   'Apnea Syndromes, Sleep',
#   'Apnea, Sleep',
#   'Sleep apnea',
#   'SLEEP APNEA',
#   'sleep apnea',
#   'Apneas, Sleep',
#   'Sleep Apneas',
#   'Sleep apnea, NOS',
#   'Sleep apnoea',
#   'Sleep apnea NOS',
#   'sleep apnoea',
#   'Sleep Apnea',
#   'Sleep Hypopnea',
#   'Sleep hypopnea',
#   'Sleep hypopnoea',
#   'Hypopneas, Sleep',
#   'Sleep Hypopneas',
#   'Hypopnea, Sleep',
#   'SAS - Sleep apnea syndrome',
#   'SAS - Sleep apnoea syndrome',
#   '[D]Sleep apnoea syndrome',
#   '[D]Syndrome sleep apnoea',
#   '[D]Sleep apnea syndrome',
#   '[D]Syndrome sleep apnea',
#   'Pauses in breathing while sleeping',
#   'Unspecified sleep apnea',
#   '[D]Sleep apnea syndrome (context-dependent category)',
#   'Sleep apnea (finding)',
#   '[D]Sleep apnea syndrome (situation)',
#   'Sleep apnea (disorder)',
#   'Sleep apnoea (disorder)'],
#  'C1548802': ['Body Site Modifier - Lower', 'Lower'],
#  'C2003888': ['Lower (action)', 'Lower', 'Lowered', 'Lowering'],
#  'C0441994': ['Lower - spatial qualifier',
#   'Lower (qualifier value)',
#   'Lower',
#   'lower',
#   'LOWER',
#   'lowered',
#   'lowering',
#   'lowers'],
#  'C4319605': ['35', 'Thirty-five', '35 (qualifier value)'],
#  'C0558295': ['preference',
#   'Preference',
#   'preferences',
#   'Preferences',
#   'Preferences (qualifier value)',
#   'Preferred'],
#  'C2987476': ['Exist', 'Be', 'Being'],
#  'C1145670': ['Respiratory Failure',
#   'FAILURE RESPIRATORY',
#   'RESPIRATORY FAILURE',
#   'Respiratory failure',
#   'respiratory failure',
#   'Respiratory Failures',
#   'Respiratory failure, NOS',
#   'Respiratory failure NOS',
#   'Failure, Respiratory',
#   'respiratory insufficiency',
#   'respiratory insufficiency/failure',
#   'RESPIRATION FAILURE',
#   '[D]Respiratory failure',
#   '[D]Respiratory failure NOS',
#   '[D]Respiratory failure NOS (context-dependent category)',
#   '[D]Respiratory failure (context-dependent category)',
#   'Respiratory failure (disorder)',
#   '[D]Respiratory failure (situation)',
#   '[D]Respiratory failure NOS (situation)'],
#  'C4552651': ['Respiratory Failure, CTCAE',
#   'Respiratory Failure',
#   'Respiratory failure'],
#  'C0262926': ['Medical History',
#   'Medical history',
#   'medical history',
#   'medical history of',
#   'personal health record',
#   'History of',
#   'history of',
#   'History',
#   'history',
#   'Past Medical History',
#   'Personal History',
#   'personal history',
#   'H&P.HX',
#   'History of (contextual qualifier) (qualifier value)',
#   'Hx',
#   'Personal Medical History',
#   'personal medical history',
#   'History of (contextual qualifier)',
#   'PMH'],
#  'C3538928': ['Usual', 'usual', 'Customary', 'Typical', 'Usually'],
#  'C1707391': ['Choose (action)',
#   'Selection',
#   'Choice',
#   'Election',
#   'Choose',
#   'choosing',
#   'Chose',
#   'Chosen',
#   'Elected',
#   'Select',
#   'Selected',
#   'Pick',
#   'Picked'],
#  'C0150369': ['Preventive monitoring',
#   'preventive monitoring',
#   'Monitoring',
#   'monitoring',
#   'monitor',
#   'Preventive monitoring (procedure)',
#   'Preventive monitoring (regime/therapy)'],
#  'C2828008': ['Burden'],
#  'C2348205': ['Similarity', 'Similar'],
#  'C1549475': ['Room type - Intensive care unit', 'Intensive care unit'],
#  'C0700321': ['Small',
#   'small',
#   'SMALL',
#   'Smaller',
#   'smaller',
#   'Minor',
#   'Lesser',
#   'Little',
#   'little',
#   'littles',
#   'minute',
#   'minutes',
#   'Minor (modifier) [Ambiguous]',
#   'Small (qualifier value)',
#   'Minor (modifier) (qualifier value)',
#   'smalling'],
#  'C0018724': ['Health Personnel',
#   'health personnel',
#   'Personnel, Health',
#   'Health Care Providers',
#   'health care providers',
#   'Health Care Provider',
#   'Provider, Health Care',
#   'health care provider',
#   'Health care personnel',
#   'health care personnel',
#   'RoleClassHealthcareProvider',
#   'Medical personnel',
#   'medical personnel',
#   'Care personnel',
#   'healthcare professionals',
#   'healthcare professional',
#   'Healthcare Workers',
#   'healthcare workers',
#   'healthcare worker',
#   'Healthcare Worker',
#   'health professional',
#   'health professionals',
#   'health care professionals',
#   'health care professional',
#   'health care worker',
#   'HEALTH CARE WORKER',
#   'Healthcare Providers',
#   'healthcare providers',
#   'Healthcare Provider',
#   'Provider, Healthcare',
#   'healthcare provider',
#   'HealthcareProvider'],
#  'C0678229': ['Classification of information',
#   'classification of information',
#   'information classification',
#   'classification'],
#  'C0008903': ['Taxonomic', 'classification', 'taxonomy', 'CL', 'CLASS'],
#  'C0035648': ['risk factors',
#   'Risk Factors',
#   'Risk factors',
#   'Factor, Risk',
#   'Risk Factor',
#   'Risk factor',
#   'risk factor',
#   'factor risks',
#   'disorder predictors',
#   'risk indicators',
#   'risk indicator',
#   'risk characteristics',
#   'vulnerability factors',
#   'Risk factor (qualifier value)',
#   'Risk factor (observable entity)'],
#  'C0439234': ['year',
#   'YEAR',
#   'Year',
#   'years',
#   'YEARS',
#   'yr',
#   'a',
#   'year (qualifier value)',
#   'Annum'],
#  'C0205435': ['First (number)',
#   'First',
#   'first',
#   '1st',
#   'First (qualifier value)'],
#  'C0686907': ['Consequence of',
#   'consequence of',
#   'Consequence',
#   'consequences',
#   'consequence',
#   'Consequence of (contextual qualifier) (qualifier value)',
#   'Consequence of (contextual qualifier)'],
#  'C3812897': ['General medical service',
#   'General',
#   'General medical service (qualifier value)',
#   'General medical service (procedure)'],
#  'C3891294': ['Safety Reporting Documentation',
#   'General',
#   'Safety Reporting Communications and Tracking Subcategory',
#   'Safe Rept Comm Track'],
#  'C4521767': ['US Military Commissioned Officer O10',
#   'ADM',
#   'General',
#   'GEN',
#   'Gen',
#   'Admiral',
#   'United States Military Commissioned Officer O10 (qualifier value)',
#   'United States Military Commissioned Officer O10',
#   'O10'],
#  'C0452240': ['Physical therapy exercises',
#   'physical therapy exercises',
#   'exercise physical therapy',
#   'Exercises',
#   'exercises',
#   'Exercise Therapy',
#   'therapy exercise',
#   'Exercise therapy',
#   'exercise therapy',
#   'Exercise Therapies',
#   'Therapies, Exercise',
#   'exercises therapy',
#   'Therapy, Exercise',
#   'Rehabilitation Exercise',
#   'exercise rehabilitation',
#   'rehabilitation exercise',
#   'exercises rehabilitation',
#   'Exercises, Rehabilitation',
#   'Rehabilitation Exercises',
#   'Exercise, Rehabilitation',
#   'Therapeutic exercise',
#   'therapeutic exercise',
#   'Therapeutic exercise, NOS',
#   'therapeutic exercises',
#   'Remedial Exercise',
#   'Exercises, Remedial',
#   'Remedial Exercises',
#   'Exercise, Remedial',
#   'Exercises (procedure)',
#   'Therapeutic exercise (regime/therapy)(procedure)',
#   'Exercise therapy (procedure)',
#   'Exercises treatments and procedures',
#   'Therapeutic exercise (regime/therapy)',
#   'Exercises (regime/therapy)',
#   'Exercise therapy (regime/therapy)',
#   'THER EXERCISE',
#   'EXERCISE THER'],
#  'C0392360': ['Indication of (contextual qualifier)',
#   'Indication of',
#   'indication of',
#   'Indications',
#   'Indication for',
#   'With indication',
#   'indication for',
#   'indications',
#   'indication',
#   'Reason for',
#   'reason for',
#   'reasons',
#   'reason',
#   'Reason',
#   'Justification',
#   'justification',
#   'Indication of (contextual qualifier) [Ambiguous]',
#   'Indication of (contextual qualifier) (qualifier value)',
#   'Reason for (contextual qualifier) (qualifier value)',
#   'Indication for (attribute)',
#   'Reason for (qualifier value)',
#   'Reason for (attribute)',
#   'Rationale'],
#  'C0001617': ['Adrenal Cortex Hormones',
#   'adrenal cortex hormones',
#   'Adrenal cortex hormones',
#   'adrenal cortex hormone',
#   'Adrenal cortex hormone',
#   'Adrenal Cortex Hormone',
#   'Cortex Hormone, Adrenal',
#   'Hormone, Adrenal Cortex',
#   'Hormones, Adrenal Cortex',
#   'Corticoids',
#   'corticoids',
#   'Corticoid',
#   'corticoid',
#   'Corticosteroids',
#   'corticosteroids',
#   'corticosteroid',
#   'Corticosteroid',
#   'adrenal cortical hormone',
#   'Adrenal cortical hormone',
#   'Adrenal cortical hormone, NOS',
#   'adrenocorticosteroids',
#   'Adrenocorticosteroids',
#   'Anacal suppository',
#   'Corticoid preparation',
#   'Corticoid preparation, NOS',
#   'Corticosteroids [skin]',
#   'Corticosteroids [respiratory use]',
#   'Adrenal cortex hormone (substance)',
#   'Product containing corticosteroid (product)',
#   'Corticosteroid product',
#   'Product containing corticosteroid',
#   'Product containing corticosteroid and corticosteroid derivative (product)',
#   'Corticosteroid and corticosteroid derivative-containing product',
#   'Adrenal cortical hormone-containing product',
#   'Adrenal cortex hormone-containing product',
#   'Product containing adrenal cortex hormone (product)',
#   'adrenal corticosteroids',
#   'adrenal corticosteroid',
#   'Adrenal cortical hormone (substance)',
#   'Anacal pessary',
#   'Corticoid preparation (product)',
#   'Corticoid preparation (substance)',
#   'Corticosteroids [respiratory use] (product)',
#   'Corticosteroids [skin] (product)',
#   'Corticosteroids [respiratory use] (substance)',
#   'Corticosteroids [skin] (substance)',
#   'Therapeutic Corticosteroid',
#   'ADRENAL CORTICOSTERIODS',
#   'Anacal suppository (disorder)'],
#  'C3539185': ['Corticosteroid nasal preparations for topical use',
#   'Corticosteroids'],
#  'C3540726': ['Corticosteroid ophthalmologic and otologic preparations',
#   'Corticosteroids',
#   'CORTICOSTEROIDS'],
#  'C3540725': ['Corticosteroid otologicals',
#   'Corticosteroids',
#   'CORTICOSTEROIDS'],
#  'C3540727': ['Corticosteroids, topical for treatment of hemorrhoids and anal fissures',
#   'Corticosteroids'],
#  'C1704788': ['Definition', 'definition', 'Defined'],
#  'C0205410': ['Sufficient',
#   'sufficient',
#   'Adequate',
#   'Sufficient (qualifier value)',
#   'Satisfactory'],
#  'C4319952': ['Change -- procedure', 'Change'],
#  'C0225386': ['Breath',
#   'Breath, NOS',
#   'Breaths',
#   'Respiratory air',
#   'Respiratory air, NOS',
#   'Portion of respiratory air',
#   'Breath (substance)',
#   'Exhl gas'],
#  'C1546419': ['Ambulatory Status - Oxygen therapy', 'Oxygen therapy'],
#  'C3665674': ['Warburg Therapy', 'Oxygen Therapy'],
#  'C4522152': ['Directed Blood Product Donation', 'Directed'],
#  'C4522153': ['Reproductive Human Cells, Tissues, and Cellular and Tissue-Based Products from Known Donor to Directed Recipient',
#   'Directed',
#   'Reproductive HCT/P from Known Donor to Directed Recipient'],
#  'C5202999': ['GDC Radon Exposure Terminology', 'radon_exposure', 'RE'],
#  'C0018704': ['Health care facility',
#   'care facility health',
#   'health care facility',
#   'Health Care Facility',
#   'Health care facilities',
#   'care facilities health',
#   'Health Facilities',
#   'facilities health',
#   'Health facilities',
#   'health facilities',
#   'Facility, Health',
#   'Health Facility',
#   'health facility',
#   'HEALTH FACILITY',
#   'Facilities, Health',
#   'treatment facility',
#   'facilities treatment',
#   'treatment facilities',
#   'institution (medical)',
#   'Medical workplace',
#   'medical facility',
#   'facilities medical',
#   'facility medical',
#   'Health care facility (environment)',
#   'Institution',
#   'Healthcare facility',
#   'Healthcare Facility',
#   'Healthcare',
#   'Healthcare facility (environment)',
#   'HealthcareFacility'],
#  'C2986904': ['Respiratory Domain', 'RE', 'Respiratory System Findings'],
#  'C0556581': ['Retinol equivalents',
#   'Retinol Equivalents',
#   'retinol equivalents',
#   'retinol equivalent',
#   'Retinol Equivalent',
#   'RE',
#   '{RE}',
#   'Retinol equivalents (qualifier value)'],
#  'C1272753': ['Institution (social concept)',
#   'Institute',
#   'registering_institution',
#   'registering institution',
#   'Institution',
#   'institution',
#   'INSTITUTION',
#   'institutions'],
#  'C1880156': ['Comprehensive'],
#  'C0444930': ['End', 'end', 'ending', 'ends', 'End (qualifier value)'],
#  'C0205540': ['Approved',
#   'approved',
#   'Approve',
#   'Approved (qualifier value)',
#   'Approval'],
#  'C0205555': ['Special',
#   'special',
#   'specials',
#   'specialised',
#   'specialising',
#   'specialized',
#   'specializes',
#   'specialize',
#   'specializing',
#   'Special (qualifier value)',
#   'specialis'],
#  'C0035201': ['Resources',
#   'resources',
#   'Resource',
#   'resource',
#   'Research Resource'],
#  'C0348078': ['Qualitative form',
#   'Form',
#   'form',
#   'forms',
#   'shape',
#   'Form (attribute)'],
#  'C0168634': ['BaseLine dental cement', 'baseline', 'baselines'],
#  'C1442488': ['Baseline', 'baseline'],
#  'C0205195': ['Combined',
#   'combined',
#   'Combination',
#   'Combined (qualifier value)'],
#  'C0009488': ['Comorbidity',
#   'comorbidity',
#   'comorbidities',
#   'Intercurrent Illness',
#   'Intercurrent illness',
#   'co-morbidity'],
#  'C1273870': ['Management procedure',
#   'management procedure',
#   'management procedures',
#   'Management (procedure)',
#   'Supervision',
#   'Managing',
#   'Managed',
#   'Management',
#   'Management procedure (procedure)',
#   'Oversight'],
#  'C0542341': ['Function (attribute)',
#   'Functional',
#   'Function',
#   'FUNCTION',
#   'function',
#   'Functions',
#   'functioning',
#   'functions',
#   'Function (observable entity)',
#   'Functions (observable entity)',
#   'Functions (qualifier value)',
#   'Fcn'],
#  'C0905072': ['TFF2 protein, human',
#   'Spasmolysin',
#   'human SML1-hSP',
#   'human spasmolytic protein SML1',
#   'human spasmolytic protein hSP-SML1',
#   'SP',
#   'trefoil factor 2 protein, human',
#   'Spasmolytic Polypeptide',
#   'trefoil factor 2 (spasmolytic protein 1), human',
#   'Trefoil Factor 2',
#   'Spasmolytic Protein 1'],
#  'C3889434': ['TFF2 wt Allele',
#   'Trefoil Factor 2 wt Allele',
#   'Spasmolytic Protein 1 Gene',
#   'SP',
#   'SML1'],
#  'C0026538': ['Morbidity - disease rate',
#   'Morbidity',
#   'morbidity',
#   'Morbidities',
#   'morbidities',
#   'disease rate',
#   'disease rates',
#   'disorder incidence'],
#  'C0220880': ['morbidity aspects', 'morbidity'],
#  'C3844638': ['Either'],
#  'C0205436': ['second (number)',
#   'Secondary',
#   'Second',
#   'second',
#   'Secondly',
#   '2nd',
#   'Second - ordinal',
#   'Second Ordinal',
#   'Second (qualifier value)'],
#  'C2986411': ['Improvement'],
#  'C1704243': ['Greater',
#   'greater',
#   'Great',
#   'Bigger',
#   'bigger',
#   'Larger',
#   'larger',
#   'Greater (qualifier value)'],
#  'C0332189': ['Episode of',
#   'Episode, NOS',
#   'Episode',
#   'Episodes',
#   'episodes',
#   'episode',
#   'EPISODE',
#   'Episode of [Ambiguous]',
#   'Episode (attribute)',
#   'Episodes (qualifier value)',
#   'Episode of (qualifier value)'],
#  'C0373548': ['Arsenic measurement',
#   'Arsenic Measurement',
#   'Arsenic measurement, NOS',
#   'Arsenic',
#   'ARSENIC',
#   'As',
#   'Arsenic measurement (procedure)',
#   'arsenic level test'],
#  'C0052432': ['artesunate',
#   'ARTESUNATE',
#   'Artesunate',
#   'ART',
#   'Succinyl Dihydroartemisinin',
#   'Succinyl dihydroartemisinin',
#   'Dihydroartemisinin, Succinyl',
#   'Dihydroartemisinine-12-alpha-succinate',
#   'Dihydroartemisinine 12 alpha succinate',
#   '4-oxo-4-{[(3R,5aS,6R,8aS,9R,10S,12R,12aR)-3,6,9-trimethyldecahydro-3,12-epoxypyrano[4,3-j]-1,2-benzodioxepin-10-yl]oxy}butanoic acid',
#   'AS',
#   'Artesunatum',
#   'Artesunato',
#   'butanedioic acid, 1-[(3R,5aS,6R,8aS,9R,10S,12R,12aR)-decahydro-3,6,9-trimethyl-3,12-epoxy-12H-pyrano[4,3-j]-1,2-benzodioxepin-10-yl] ester',
#   'dihydroqinghasu hemsuccinate',
#   'Butanedioic acid, mono((5aS,6R,8aS,9R,10S,12R,12aR)-decahydro-3,6,9-trimethyl-3,12-epoxy-12H-pyrano(4,3-j)-1,2-benzodioxepin-10-yl) ester',
#   'Product containing artesunate (medicinal product)',
#   'Artesunate-containing product',
#   'Product containing artesunate',
#   'Artesunate (substance)',
#   'Artesunate product',
#   'Artesunate (product)'],
#  'C4522268': ['Pulmonary (intended site)', 'Pulmonary'],
#  'C2709248': ['Pulmonary (qualifier value)', 'Pulmonary', 'pulmonary'],
#  'C2707265': ['Pulmonary:-:Point in time:^Patient:-',
#   'Pulmonary',
#   'Pulmonary:-:Pt:^Patient:-']}

# %% [markdown]
# ### Check how many concepts are shared by the two previous seeds

# %%
print('Length seed_rel: ' + str(len(seed_rel)))
print('Length seed_paper: ' + str(len(seed_paper)))
# Out:
# Length seed_rel: 256
# Length seed_paper: 399

# %%
print('The elements shared by two seeds are: ' + str(len(set(seed_rel.keys()).intersection(set(seed_paper.keys())))))
# Out:
# The elements shared by two seeds are: 18

# %% [markdown]
# and they are the following:

# %%
umls_tables_processing.extracting_strings(list(set(seed_rel.keys()).intersection(set(seed_paper.keys()))))
# Out:
# Time for extracting labels: 0:00:00
# ({'C0013990': ['Pathological accumulation of air in tissues',
#    'Emphysema',
#    'EMPHYSEMA',
#    'emphysema',
#    'Emphysema NOS',
#    'Emphysema, NOS',
#    'Emphysema (morphologic abnormality)',
#    'Emphysema NOS (morphologic abnormality)',
#    'abnormal collection of air in tissues'],
#   'C0038895': ['Surgical aspects',
#    'operative procedures',
#    'surgery',
#    'operations',
#    'invasive procedures',
#    'operative therapy',
#    'SURG',
#    'SU'],
#   'C0010200': ['EZTULA',
#    'Hoste',
#    'Hoesten',
#    'Coughing',
#    'COUGHING',
#    'coughing',
#    'Cough',
#    'Coughs',
#    'COUGH',
#    'Cough, NOS',
#    'cough',
#    'coughs',
#    '[D]Cough',
#    'C/O - cough',
#    'cough symptom',
#    'Cough symptom',
#    'Cough symptom NOS',
#    'cough symptoms',
#    'coughing symptom',
#    'Coughing - function',
#    'Observation of cough',
#    'C/O - cough (context-dependent category)',
#    '[D]Cough (context-dependent category)',
#    'Cough (finding)',
#    'Finding of cough',
#    'Finding of cough (finding)',
#    'Cough symptom NOS (finding)',
#    'Coughing - function (qualifier value)',
#    'Coughing (observable entity)',
#    'Complaining of cough (finding)',
#    '[D]Cough (situation)',
#    'Complaining of cough',
#    'YSKA',
#    'Toux',
#    'Husten',
#    'shiul',
#    'kohoges',
#    'Tosse',
#    'HOSTE',
#    'Tosse',
#    'Tos',
#    'HOSTA'],
#   'C0015127': ['Etiology aspects',
#    'etiology',
#    'aetiology',
#    'etiologies',
#    'causes',
#    'caused by',
#    'cause',
#    'ET',
#    'causality',
#    'ETIOL'],
#   'C1704338': ['diagnosis aspect', 'diagnosis', 'DI', 'DIAG'],
#   'C0037315': ['Sleep Apnea Syndromes',
#    'Sleep apnea syndromes',
#    'sleep apnea syndromes',
#    'Sleep apnea syndrome',
#    'Apnea Syndrome, Sleep',
#    'Sleep Apnea Syndrome',
#    'sleep apnea syndrome',
#    'Sleep apnoea syndrome',
#    'sleep apnoea syndrome',
#    'SLEEP APNEA SYNDROME',
#    'Syndrome sleep apnea',
#    'Syndrome sleep apnoea',
#    'Apnea Syndromes, Sleep',
#    'Apnea, Sleep',
#    'Sleep apnea',
#    'SLEEP APNEA',
#    'sleep apnea',
#    'Apneas, Sleep',
#    'Sleep Apneas',
#    'Sleep apnea, NOS',
#    'Sleep apnoea',
#    'Sleep apnea NOS',
#    'sleep apnoea',
#    'Sleep Apnea',
#    'Sleep Hypopnea',
#    'Sleep hypopnea',
#    'Sleep hypopnoea',
#    'Hypopneas, Sleep',
#    'Sleep Hypopneas',
#    'Hypopnea, Sleep',
#    'SAS - Sleep apnea syndrome',
#    'SAS - Sleep apnoea syndrome',
#    '[D]Sleep apnoea syndrome',
#    '[D]Syndrome sleep apnoea',
#    '[D]Sleep apnea syndrome',
#    '[D]Syndrome sleep apnea',
#    'Pauses in breathing while sleeping',
#    'Unspecified sleep apnea',
#    '[D]Sleep apnea syndrome (context-dependent category)',
#    'Sleep apnea (finding)',
#    '[D]Sleep apnea syndrome (situation)',
#    'Sleep apnea (disorder)',
#    'Sleep apnoea (disorder)'],
#   'C0008903': ['Taxonomic', 'classification', 'taxonomy', 'CL', 'CLASS'],
#   'C0199529': ['Pulmonary rehabilitation (procedure)',
#    'Pulmonary rehabilitation',
#    'rehabilitation pulmonary',
#    'Pulmonary Rehabilitation',
#    'pulmonary rehabilitation',
#    'Pulmonary rehabilitation, NOS',
#    'Pulmonary rehabilitation (regime/therapy)'],
#   'C0730607': ['Severe chronic obstructive pulmonary disease',
#    'Severe chronic obstructive pulmonary disease (disorder)'],
#   'C0034067': ['ENFISEMA/ BRONKONEUMOPATIA KRONIKO OBSTRUKTIBOA',
#    'Emfysem/kronisk obst lungesygdom',
#    'Emfyseem/COPD',
#    'Pulmonary Emphysema',
#    'EMPHYSEMA PULMONARY',
#    'EMPHYSEMA, PULMONARY',
#    'Pulmonary emphysema',
#    'PULMONARY EMPHYSEMA',
#    'pulmonary emphysema',
#    'Emphysemas, Pulmonary',
#    'Pulmonary Emphysemas',
#    'Pulmonary emphysema, NOS',
#    'Emphysema, Pulmonary',
#    'Emphysema',
#    'EMPHYSEMA',
#    'emphysema',
#    'Emphysema of lung',
#    'Emphysema of lung, NOS',
#    'lung emphysema',
#    'Emphysema/COPD',
#    'Pulmonary emphysema (disorder)',
#    'EMPHYSEMA PULM',
#    'EMPHYSEMAS PULM',
#    'PULM EMPHYSEMAS',
#    'PULM EMPHYSEMA',
#    'Emphysema (disorder)',
#    'KEUHKOLAAJENTUMA(EMFYSEEMA)/ KROONINEN OBSTRUKTIIVINEN KEUHKOSAIRAUS',
#    'Emphyseme/BPCO/MPCO',
#    'Emphysem/chron obstrukt Lungenkr',
#    'maxalat reot xasimatit',
#    'emphysema',
#    'Enfisema/BPCO',
#    'EMFYSEM/KRON OBSTRUKTIV LUNGESYKD',
#    'Enfisema/DPCO',
#    'Enfisema/E.P.O.C.',
#    'EMFYSEM/KRONISK OBSTRUKTIV LUNGSJKD'],
#   'C0024115': ['Lung diseases',
#    'Diseases, Lung',
#    'Lung Diseases',
#    'lung diseases',
#    'Lung Disease',
#    'Disease, Lung',
#    'Disease of lung, NOS',
#    'Lung disease NOS',
#    'disease of lung',
#    'diseases lungs',
#    'diseases of the lung',
#    'Lungs--Diseases',
#    'Lung disease',
#    'Disease of lung',
#    'lung disease',
#    'Lung',
#    'Pulmonary Diseases',
#    'diseases pulmonary',
#    'pulmonary diseases',
#    'Disease, Pulmonary',
#    'Pulmonary Disease',
#    'PULMONARY DISEASE',
#    'pulmonary disease',
#    'Pulmonary disease, NOS',
#    'Pulmonary disease',
#    'Diseases, Pulmonary',
#    'Disorder of lung',
#    'Disorder of Lung',
#    'LUNG DISORDER',
#    'DISORDER LUNG',
#    'LUNG DISORDER (NOS)',
#    'Lung Disorders',
#    'lung disorder',
#    'Lung disorder, NOS',
#    'disorder lung',
#    'disorders lung',
#    'lung disorders',
#    'Lung disorder',
#    'Lung Disorder',
#    'Pulmonary Disorders',
#    'disorders pulmonary',
#    'pulmonary disorders',
#    'PULMONARY DISORDERS',
#    'DISORDER PULMONARY',
#    'PULMONARY DISORDER',
#    'pulmonary disorder',
#    'Pulmonary Disorder',
#    'pneumopathy',
#    'Lung disease NOS (disorder)',
#    'Disease of lung (disorder)',
#    'Disorder of lung (disorder)',
#    'LUNG DIS',
#    'DIS PULM',
#    'PULM DIS'],
#   'C0039798': ['therapeutic aspects',
#    'therapy',
#    'treatment',
#    'disease management',
#    'TH',
#    'THER'],
#   'C0024109': ['Lung',
#    'lung',
#    'LUNG',
#    'Lungs',
#    'Lung, NOS',
#    'lungs',
#    'pulmonary',
#    'Lung structure',
#    'lung structure',
#    'lung structures',
#    'Pulmo',
#    'Pulmones',
#    'Set of lungs',
#    'Lung structure (body structure)',
#    'Respiratory System, Lung',
#    'Pair of lungs',
#    'Lungs pair'],
#   'C1145670': ['Respiratory Failure',
#    'FAILURE RESPIRATORY',
#    'RESPIRATORY FAILURE',
#    'Respiratory failure',
#    'respiratory failure',
#    'Respiratory Failures',
#    'Respiratory failure, NOS',
#    'Respiratory failure NOS',
#    'Failure, Respiratory',
#    'respiratory insufficiency',
#    'respiratory insufficiency/failure',
#    'RESPIRATION FAILURE',
#    '[D]Respiratory failure',
#    '[D]Respiratory failure NOS',
#    '[D]Respiratory failure NOS (context-dependent category)',
#    '[D]Respiratory failure (context-dependent category)',
#    'Respiratory failure (disorder)',
#    '[D]Respiratory failure (situation)',
#    '[D]Respiratory failure NOS (situation)'],
#   'C0026566': ['Aspects of mortality statistics', 'mortality', 'MO', 'MORTAL'],
#   'C0184633': ['Oxygen Therapy Care',
#    'Oxygen therapy care',
#    'On oxygen',
#    'Oxygen Inhalation Therapy',
#    'oxygen inhalation therapy',
#    'Inhalation Therapies, Oxygen',
#    'Oxygen Inhalation Therapies',
#    'Therapies, Oxygen Inhalation',
#    'Inhalation Therapy, Oxygen',
#    'Therapy, Oxygen Inhalation',
#    'Oxygen therapy',
#    'Oxygen Therapy',
#    'oxygen therapy',
#    'Oxygen therapy, NOS',
#    'oxygen therapies',
#    'O2 therapy',
#    'o2 therapy',
#    'oxygen administration',
#    'oxygenation therapy',
#    'Oxygen therapy (procedure)',
#    'INHALATION THER OXYGEN',
#    'OXYGEN INHALATION THER',
#    'THER OXYGEN INHALATION',
#    'Oxygen therapy (regime/therapy)',
#    'supplemental oxygen therapy'],
#   'C0004096': ['ARNASESTUA',
#    'Astma',
#    'Astma',
#    'Asthma',
#    'ASTHMA',
#    'asthma',
#    'Asthmas',
#    'Asthma, NOS',
#    'Asthma NOS',
#    'Asthma, Bronchial',
#    'Bronchial asthma',
#    'BRONCHIAL ASTHMA',
#    'bronchial asthma',
#    'ASTHMA BRONCHIAL',
#    'ASTHMA, BRONCHIAL',
#    'Bronchial asthma, NOS',
#    'Bronchial Asthma',
#    'Airway hyperreactivity',
#    'Asthma, unspecified',
#    'Asthma unspecified',
#    'Asthmatic',
#    'asthmatic',
#    'asthmatics',
#    'br asthma',
#    'bronchitic asthma',
#    'Asthma (disorder) [Ambiguous]',
#    'Asthma (disorder)',
#    'asthma disorders',
#    'Asthma NOS (disorder)',
#    'Asthma unspecified (disorder)',
#    'ASTMA',
#    'Asthme',
#    'Asthma',
#    'astma',
#    'asthma',
#    'Asma',
#    'ASTMA',
#    'Asma',
#    'Asma',
#    'ASTMA'],
#   'C0024117': ['Chronic Obstructive Airway Disease',
#    'Chronic obstructive airway disease',
#    'Chronic obstructive airways disease NOS',
#    'Chronic Obstructive Airways Disease',
#    'Chronic airway obstruction',
#    'Chronic Obstructive Lung Disease',
#    'CHRONIC OBSTRUCTIVE LUNG DISEASE',
#    'Chronic obstructive lung disease',
#    'chronic obstructive lung disease',
#    'Chronic obstructive lung disease, NOS',
#    'Pulmonary Disease, Chronic Obstructive',
#    'CHRONIC OBSTRUCTIVE PULMONARY DISEASE',
#    'chronic obstructive pulmonary disease',
#    'Chronic obstructive pulmonary disease',
#    'PULMONARY DISEASE, CHRONIC OBSTRUCTIVE',
#    'Chronic obstructive pulmonary disease NOS',
#    'Chronic Obstructive Pulmonary Diseases',
#    'Chronic Obstructive Pulmonary Disease',
#    'COLD',
#    'COPD',
#    'COPD NOS',
#    'HYPERACTIVE AIRWAY DISEASE',
#    'Chronic airflow limitation',
#    'chronic airflow limitation',
#    'COAD - Chronic obstructive airways disease',
#    'Chronic airway disease',
#    'chronic airway disease',
#    'chronic airways disease',
#    'Chronic irreversible airway obstruction',
#    'COLD - Chronic obstructive lung disease',
#    'COLD (chronic obstructive lung disease)',
#    'COPD - Chronic obstructive pulmonary disease',
#    'Chronic Obstructive Pulmonary Disease (COPD)',
#    'Chronic Obstructive Pulmonary Disease, (COPD)',
#    'Obstructive Pulmonary Disease (COPD), Chronic',
#    'Pulmonary Disease (COPD), Chronic Obstructive',
#    'chronic obstructive pulmonary disease (COPD)',
#    'COPD, Chronic Obstructive Pulmonary Disease',
#    'CHRONIC OBSTRUCTIVE LUNG DIS',
#    'COAD',
#    'coad',
#    'CAFL - Chronic airflow limitation',
#    'CAL - Chronic airflow limitation',
#    'Chronic airway obstruction; not otherwise specified',
#    'Chronic pulmonary obstruction',
#    'Chronic obstructive airways disease NOS (disorder)',
#    'Chronic obstructive lung disease [Ambiguous]',
#    'Chronic obstructive lung disease (disorder)',
#    'Chronic obstructive pulmonary disease finding (finding)',
#    'Chronic obstructive pulmonary disease finding',
#    'Disease (COPD), Chronic Obstructive',
#    'CHRONIC OBSTRUCTIVE AIRWAY DIS',
#    'CHRONIC OBSTRUCTIVE PULM DIS',
#    'PULM DIS CHRONIC OBSTRUCTIVE']},
#  [])

# %% [markdown]
# #### Building a union of the two seeds:

# %%
seed_union = {**seed_rel, **seed_paper}

# %%
len(seed_union) == (len(seed_rel) + len(seed_paper))-18
# Out:
# True

# %% [markdown]
# ## Building ***seed_paper_lite***

# %% [markdown]
# From the implementation, the MetaMap Lite version does not work with API service anymore, and given the bad performance related to the mapping, it has not been upgraded.

# %%
paper_lite_cuis, oov_lite = mmi_txt_to_cui.mmi_lite_freetext(sty = True)

# %%
paper_lite_cuis_ = list(set([i[0] for i in paper_lite_cuis]))

# %% [markdown]
# ### Check the semantic types contained into *the seed_paper_lite*

# %%
c = mmi_txt_to_cui.check_sty_mmi(paper_lite_cuis)
print({k: j for k,j in list(c.items())[:5]})
# Out:
# {'inpr': (26, 'Intellectual Product'), 'qlco': (21, 'Qualitative Concept'), 'fndg': (20, 'Finding'), 'idcn': (16, 'Idea or Concept'), 'topp': (13, 'Therapeutic or Preventive Procedure')}

# %%
oov_lite
# Out:
# ['[84–88].\n', '[92, 93]. \n']

# %%
seed_paper_lite, _ = umls_tables_processing.extracting_strings(paper_lite_cuis_)

# %%
seed_paper_lite

# %% [markdown]
# ## Loading Models

# %% [markdown]
# ### Importing the embeddings file names

# %%
cuis = ('/cuis/', [f.name for f in os.scandir(PATH_EMBEDDINGS+'/cuis') if (f.is_file())&(f.name != 'README.md')])
words = ('/words/', [f.name for f in os.scandir(PATH_EMBEDDINGS+'/words') if (f.is_file())&(f.name != 'README.md')])
embeddings = [cuis, words]
embeddings
# Out:
# [('/cuis/',
#   ['claims_cuis_hs_300.txt.gz',
#    'stanford_cuis_svd_300.txt.gz',
#    'cui2vec_pretrained.txt',
#    'DeVine_etal_200.txt']),
#  ('/words/',
#   ['PMC-w2v.bin',
#    'Health_2.5mreviews.s200.w10.n5.v15.cbow.bin',
#    'PubMed-and-PMC-w2v.bin',
#    'GoogleNews-vectors-negative300.bin',
#    'PubMed-w2v.bin',
#    'tweetsvec.txt',
#    'wikipedia-pubmed-and-PMC-w2v.bin'])]

# %% [markdown]
# ### Creating a list of k values to test

# %%
ks = [5, 10, 20, 30, 40]
#ks = [5, 10]

# %% [markdown]
# ### Creating a list of seed tuples

# %%
seeds = [('seed_rel', seed_rel), ('seed_paper', seed_paper), ('seed_paper_lite', seed_paper_lite)]

# %% [markdown]
# ### Creating a dictionary of all the embeddings tested, over the seeds and k values.

# %%
a = datetime.datetime.now().replace(microsecond=0)
big_g = {}

for type_emb in embeddings:
    for emb in type_emb[1]:
        model = KeyedVectors.load_word2vec_format(PATH_EMBEDDINGS+type_emb[0]+emb, binary=emb.endswith('.bin'))
        name = os.path.splitext(emb)[0]
        big_g[name] = {}
        print('\n\n The name of embedding is: %s\n' % name)
        for k in ks:
            print('\n k_value: %s\n' % k)
            big_g[name][k] = {}
            for seed in seeds:
                if type_emb[0]=='/cuis/':
                    d = measures.occurred_concept(model, seed[1].keys(), k_most_similar=k)
                    big_g[name][k][seed[0]] = [measures.pos_dcg(d, normalization = True, norm_fact = measures.max_dcg(k)),
                                               measures.neg_dcg(d, normalization = True, norm_fact = measures.max_dcg(k)),
                                               measures.percentage_dcg(d, k=k),
                                               measures.oov(d),
                                               len(seed[1]), []]
                elif type_emb[0]=='/words/':
                    d, new_seed = measures.occurred_labels(model, seed[1], k_most_similar=k)
                    big_g[name][k][seed[0]] = [measures.pos_dcg(d, normalization = True, norm_fact = measures.max_dcg(k)),
                                               measures.neg_dcg(d, normalization = True, norm_fact = measures.max_dcg(k)),
                                               measures.percentage_dcg(d, k=k),
                                               measures.oov(d),
                                               len(seed[1]),
                                               new_seed]
                print('{:s}: pos_dcg: {:.4f}, neg_dcg: {:.4f}, perc_dcg: {:.4f}, oov: {:d}, #seed: {:d}\n'.
                      format(seed[0],
                             big_g[name][k][seed[0]][0],
                             big_g[name][k][seed[0]][1],
                             big_g[name][k][seed[0]][2],
                             big_g[name][k][seed[0]][3],
                             big_g[name][k][seed[0]][4]))
print(datetime.datetime.now().replace(microsecond=0)-a)
# Out:
#  The name of embedding is: claims_cuis_hs_300.txt
#
#
#  k_value: 5
#
# seed_rel: pos_dcg: 0.0192, neg_dcg: 0.9808, perc_dcg: 0.0156, oov: 209, #seed: 256
#
# seed_paper: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 389, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0011, neg_dcg: 0.9989, perc_dcg: 0.0013, oov: 154, #seed: 157
#
#
#  k_value: 10
#
# seed_rel: pos_dcg: 0.0141, neg_dcg: 0.9859, perc_dcg: 0.0102, oov: 209, #seed: 256
#
# seed_paper: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 389, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0007, neg_dcg: 0.9993, perc_dcg: 0.0006, oov: 154, #seed: 157
#
#
#  k_value: 20
#
# seed_rel: pos_dcg: 0.0114, neg_dcg: 0.9886, perc_dcg: 0.0084, oov: 209, #seed: 256
#
# seed_paper: pos_dcg: 0.0002, neg_dcg: 0.9998, perc_dcg: 0.0003, oov: 389, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0005, neg_dcg: 0.9995, perc_dcg: 0.0003, oov: 154, #seed: 157
#
#
#  k_value: 30
#
# seed_rel: pos_dcg: 0.0106, neg_dcg: 0.9894, perc_dcg: 0.0082, oov: 209, #seed: 256
#
# seed_paper: pos_dcg: 0.0002, neg_dcg: 0.9998, perc_dcg: 0.0003, oov: 389, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0003, neg_dcg: 0.9997, perc_dcg: 0.0002, oov: 154, #seed: 157
#
#
#  k_value: 40
#
# seed_rel: pos_dcg: 0.0098, neg_dcg: 0.9902, perc_dcg: 0.0077, oov: 209, #seed: 256
#
# seed_paper: pos_dcg: 0.0002, neg_dcg: 0.9998, perc_dcg: 0.0003, oov: 389, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0003, neg_dcg: 0.9997, perc_dcg: 0.0002, oov: 154, #seed: 157
#
#
#
#  The name of embedding is: stanford_cuis_svd_300.txt
#
#
#  k_value: 5
#
# seed_rel: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 256, #seed: 256
#
# seed_paper: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 399, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 157, #seed: 157
#
#
#  k_value: 10
#
# seed_rel: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 256, #seed: 256
#
# seed_paper: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 399, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 157, #seed: 157
#
#
#  k_value: 20
#
# seed_rel: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 256, #seed: 256
#
# seed_paper: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 399, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 157, #seed: 157
#
#
#  k_value: 30
#
# seed_rel: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 256, #seed: 256
#
# seed_paper: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 399, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 157, #seed: 157
#
#
#  k_value: 40
#
# seed_rel: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 256, #seed: 256
#
# seed_paper: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 399, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 157, #seed: 157
# /home/salvatore/venv/lib/python3.8/site-packages/gensim/models/keyedvectors.py:2389: RuntimeWarning: invalid value encountered in true_divide
#   return (m / dist).astype(REAL)
#  The name of embedding is: cui2vec_pretrained
#
#
#  k_value: 5
#
# seed_rel: pos_dcg: 0.0448, neg_dcg: 0.9552, perc_dcg: 0.0406, oov: 120, #seed: 256
#
# seed_paper: pos_dcg: 0.0554, neg_dcg: 0.9446, perc_dcg: 0.0546, oov: 214, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0156, neg_dcg: 0.9844, perc_dcg: 0.0166, oov: 102, #seed: 157
#
#
#  k_value: 10
#
# seed_rel: pos_dcg: 0.0400, neg_dcg: 0.9600, perc_dcg: 0.0359, oov: 120, #seed: 256
#
# seed_paper: pos_dcg: 0.0481, neg_dcg: 0.9519, perc_dcg: 0.0446, oov: 214, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0128, neg_dcg: 0.9872, perc_dcg: 0.0121, oov: 102, #seed: 157
#
#
#  k_value: 20
#
# seed_rel: pos_dcg: 0.0350, neg_dcg: 0.9650, perc_dcg: 0.0309, oov: 120, #seed: 256
#
# seed_paper: pos_dcg: 0.0390, neg_dcg: 0.9610, perc_dcg: 0.0335, oov: 214, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0098, neg_dcg: 0.9902, perc_dcg: 0.0083, oov: 102, #seed: 157
#
#
#  k_value: 30
#
# seed_rel: pos_dcg: 0.0332, neg_dcg: 0.9668, perc_dcg: 0.0296, oov: 120, #seed: 256
#
# seed_paper: pos_dcg: 0.0356, neg_dcg: 0.9644, perc_dcg: 0.0304, oov: 214, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0093, neg_dcg: 0.9907, perc_dcg: 0.0081, oov: 102, #seed: 157
#
#
#  k_value: 40
#
# seed_rel: pos_dcg: 0.0318, neg_dcg: 0.9682, perc_dcg: 0.0285, oov: 120, #seed: 256
#
# seed_paper: pos_dcg: 0.0323, neg_dcg: 0.9677, perc_dcg: 0.0268, oov: 214, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0085, neg_dcg: 0.9915, perc_dcg: 0.0072, oov: 102, #seed: 157
#
#
#
#  The name of embedding is: DeVine_etal_200
#
#
#  k_value: 5
#
# seed_rel: pos_dcg: 0.0436, neg_dcg: 0.9564, perc_dcg: 0.0406, oov: 136, #seed: 256
#
# seed_paper: pos_dcg: 0.0531, neg_dcg: 0.9469, perc_dcg: 0.0481, oov: 226, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0200, neg_dcg: 0.9800, perc_dcg: 0.0140, oov: 106, #seed: 157
#
#
#  k_value: 10
#
# seed_rel: pos_dcg: 0.0368, neg_dcg: 0.9632, perc_dcg: 0.0324, oov: 136, #seed: 256
#
# seed_paper: pos_dcg: 0.0400, neg_dcg: 0.9600, perc_dcg: 0.0321, oov: 226, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0157, neg_dcg: 0.9843, perc_dcg: 0.0108, oov: 106, #seed: 157
#
#
#  k_value: 20
#
# seed_rel: pos_dcg: 0.0342, neg_dcg: 0.9658, perc_dcg: 0.0309, oov: 136, #seed: 256
#
# seed_paper: pos_dcg: 0.0320, neg_dcg: 0.9680, perc_dcg: 0.0247, oov: 226, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0111, neg_dcg: 0.9889, perc_dcg: 0.0067, oov: 106, #seed: 157
#
#
#  k_value: 30
#
# seed_rel: pos_dcg: 0.0316, neg_dcg: 0.9684, perc_dcg: 0.0281, oov: 136, #seed: 256
#
# seed_paper: pos_dcg: 0.0280, neg_dcg: 0.9720, perc_dcg: 0.0215, oov: 226, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0094, neg_dcg: 0.9906, perc_dcg: 0.0057, oov: 106, #seed: 157
#
#
#  k_value: 40
#
# seed_rel: pos_dcg: 0.0295, neg_dcg: 0.9705, perc_dcg: 0.0260, oov: 136, #seed: 256
#
# seed_paper: pos_dcg: 0.0250, neg_dcg: 0.9750, perc_dcg: 0.0187, oov: 226, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0081, neg_dcg: 0.9919, perc_dcg: 0.0048, oov: 106, #seed: 157
#
#
#
#  The name of embedding is: PMC-w2v
#
#
#  k_value: 5
#
# 0:00:47
# seed_rel: pos_dcg: 0.1030, neg_dcg: 0.8970, perc_dcg: 0.0859, oov: 137, #seed: 256
#
# 0:02:02
# seed_paper: pos_dcg: 0.2755, neg_dcg: 0.7245, perc_dcg: 0.2446, oov: 47, #seed: 399
#
# 0:00:38
# seed_paper_lite: pos_dcg: 0.1948, neg_dcg: 0.8052, perc_dcg: 0.1669, oov: 18, #seed: 157
#
#
#  k_value: 10
#
# 0:00:44
# seed_rel: pos_dcg: 0.0844, neg_dcg: 0.9156, perc_dcg: 0.0695, oov: 137, #seed: 256
#
# 0:02:02
# seed_paper: pos_dcg: 0.2158, neg_dcg: 0.7842, perc_dcg: 0.1772, oov: 47, #seed: 399
#
# 0:00:38
# seed_paper_lite: pos_dcg: 0.1469, neg_dcg: 0.8531, perc_dcg: 0.1115, oov: 18, #seed: 157
#
#
#  k_value: 20
#
# 0:00:43
# seed_rel: pos_dcg: 0.0657, neg_dcg: 0.9343, perc_dcg: 0.0520, oov: 137, #seed: 256
#
# 0:02:03
# seed_paper: pos_dcg: 0.1691, neg_dcg: 0.8309, perc_dcg: 0.1322, oov: 47, #seed: 399
#
# 0:00:37
# seed_paper_lite: pos_dcg: 0.1176, neg_dcg: 0.8824, perc_dcg: 0.0876, oov: 18, #seed: 157
#
#
#  k_value: 30
#
# 0:00:44
# seed_rel: pos_dcg: 0.0556, neg_dcg: 0.9444, perc_dcg: 0.0427, oov: 137, #seed: 256
#
# 0:02:05
# seed_paper: pos_dcg: 0.1443, neg_dcg: 0.8557, perc_dcg: 0.1103, oov: 47, #seed: 399
#
# 0:00:38
# seed_paper_lite: pos_dcg: 0.0948, neg_dcg: 0.9052, perc_dcg: 0.0652, oov: 18, #seed: 157
#
#
#  k_value: 40
#
# 0:00:45
# seed_rel: pos_dcg: 0.0485, neg_dcg: 0.9515, perc_dcg: 0.0355, oov: 137, #seed: 256
#
# 0:02:03
# seed_paper: pos_dcg: 0.1295, neg_dcg: 0.8705, perc_dcg: 0.0984, oov: 47, #seed: 399
#
# 0:00:37
# seed_paper_lite: pos_dcg: 0.0815, neg_dcg: 0.9185, perc_dcg: 0.0535, oov: 18, #seed: 157
#
#
#
#  The name of embedding is: Health_2.5mreviews.s200.w10.n5.v15.cbow
#
#
#  k_value: 5
#
# 0:00:01
# seed_rel: pos_dcg: 0.0412, neg_dcg: 0.9588, perc_dcg: 0.0398, oov: 181, #seed: 256
#
# 0:00:02
# seed_paper: pos_dcg: 0.0894, neg_dcg: 0.9106, perc_dcg: 0.0832, oov: 207, #seed: 399
#
# 0:00:00
# seed_paper_lite: pos_dcg: 0.0584, neg_dcg: 0.9416, perc_dcg: 0.0497, oov: 91, #seed: 157
#
#
#  k_value: 10
#
# 0:00:01
# seed_rel: pos_dcg: 0.0321, neg_dcg: 0.9679, perc_dcg: 0.0277, oov: 181, #seed: 256
#
# 0:00:02
# seed_paper: pos_dcg: 0.0720, neg_dcg: 0.9280, perc_dcg: 0.0619, oov: 207, #seed: 399
#
# 0:00:01
# seed_paper_lite: pos_dcg: 0.0465, neg_dcg: 0.9535, perc_dcg: 0.0389, oov: 91, #seed: 157
#
#
#  k_value: 20
#
# 0:00:01
# seed_rel: pos_dcg: 0.0260, neg_dcg: 0.9740, perc_dcg: 0.0215, oov: 181, #seed: 256
#
# 0:00:02
# seed_paper: pos_dcg: 0.0568, neg_dcg: 0.9432, perc_dcg: 0.0465, oov: 207, #seed: 399
#
# 0:00:01
# seed_paper_lite: pos_dcg: 0.0352, neg_dcg: 0.9648, perc_dcg: 0.0271, oov: 91, #seed: 157
#
#
#  k_value: 30
#
# 0:00:01
# seed_rel: pos_dcg: 0.0226, neg_dcg: 0.9774, perc_dcg: 0.0182, oov: 181, #seed: 256
#
# 0:00:03
# seed_paper: pos_dcg: 0.0486, neg_dcg: 0.9514, perc_dcg: 0.0383, oov: 207, #seed: 399
#
# 0:00:00
# seed_paper_lite: pos_dcg: 0.0287, neg_dcg: 0.9713, perc_dcg: 0.0206, oov: 91, #seed: 157
#
#
#  k_value: 40
#
# 0:00:02
# seed_rel: pos_dcg: 0.0203, neg_dcg: 0.9797, perc_dcg: 0.0163, oov: 181, #seed: 256
#
# 0:00:03
# seed_paper: pos_dcg: 0.0428, neg_dcg: 0.9572, perc_dcg: 0.0328, oov: 207, #seed: 399
#
# 0:00:01
# seed_paper_lite: pos_dcg: 0.0251, neg_dcg: 0.9749, perc_dcg: 0.0175, oov: 91, #seed: 157
#
#
#
#  The name of embedding is: PubMed-and-PMC-w2v
#
#
#  k_value: 5
#
# 0:01:38
# seed_rel: pos_dcg: 0.1230, neg_dcg: 0.8770, perc_dcg: 0.1047, oov: 136, #seed: 256
#
# 0:03:47
# seed_paper: pos_dcg: 0.2919, neg_dcg: 0.7081, perc_dcg: 0.2536, oov: 46, #seed: 399
#
# 0:01:10
# seed_paper_lite: pos_dcg: 0.2050, neg_dcg: 0.7950, perc_dcg: 0.1720, oov: 18, #seed: 157
#
#
#  k_value: 10
#
# 0:01:30
# seed_rel: pos_dcg: 0.0936, neg_dcg: 0.9064, perc_dcg: 0.0742, oov: 136, #seed: 256
#
# 0:03:44
# seed_paper: pos_dcg: 0.2189, neg_dcg: 0.7811, perc_dcg: 0.1702, oov: 46, #seed: 399
#
# 0:01:10
# seed_paper_lite: pos_dcg: 0.1488, neg_dcg: 0.8512, perc_dcg: 0.1083, oov: 18, #seed: 157
#
#
#  k_value: 20
#
# 0:01:29
# seed_rel: pos_dcg: 0.0710, neg_dcg: 0.9290, perc_dcg: 0.0523, oov: 136, #seed: 256
#
# 0:03:45
# seed_paper: pos_dcg: 0.1660, neg_dcg: 0.8340, perc_dcg: 0.1213, oov: 46, #seed: 399
#
# 0:01:10
# seed_paper_lite: pos_dcg: 0.1131, neg_dcg: 0.8869, perc_dcg: 0.0787, oov: 18, #seed: 157
#
#
#  k_value: 30
#
# 0:01:30
# seed_rel: pos_dcg: 0.0594, neg_dcg: 0.9406, perc_dcg: 0.0421, oov: 136, #seed: 256
#
# 0:03:51
# seed_paper: pos_dcg: 0.1389, neg_dcg: 0.8611, perc_dcg: 0.0981, oov: 46, #seed: 399
#
# 0:01:12
# seed_paper_lite: pos_dcg: 0.0930, neg_dcg: 0.9070, perc_dcg: 0.0614, oov: 18, #seed: 157
#
#
#  k_value: 40
#
# 0:01:34
# seed_rel: pos_dcg: 0.0517, neg_dcg: 0.9483, perc_dcg: 0.0354, oov: 136, #seed: 256
#
# 0:03:49
# seed_paper: pos_dcg: 0.1219, neg_dcg: 0.8781, perc_dcg: 0.0844, oov: 46, #seed: 399
#
# 0:01:10
# seed_paper_lite: pos_dcg: 0.0793, neg_dcg: 0.9207, perc_dcg: 0.0495, oov: 18, #seed: 157
#
#
#
#  The name of embedding is: GoogleNews-vectors-negative300
#
#
#  k_value: 5
#
# 0:01:12
# seed_rel: pos_dcg: 0.0853, neg_dcg: 0.9147, perc_dcg: 0.0703, oov: 146, #seed: 256
#
# 0:03:26
# seed_paper: pos_dcg: 0.2814, neg_dcg: 0.7186, perc_dcg: 0.2416, oov: 62, #seed: 399
#
# 0:01:06
# seed_paper_lite: pos_dcg: 0.2227, neg_dcg: 0.7773, perc_dcg: 0.1911, oov: 20, #seed: 157
#
#
#  k_value: 10
#
# 0:01:05
# seed_rel: pos_dcg: 0.0637, neg_dcg: 0.9363, perc_dcg: 0.0465, oov: 146, #seed: 256
#
# 0:03:27
# seed_paper: pos_dcg: 0.2084, neg_dcg: 0.7916, perc_dcg: 0.1574, oov: 62, #seed: 399
#
# 0:01:07
# seed_paper_lite: pos_dcg: 0.1652, neg_dcg: 0.8348, perc_dcg: 0.1248, oov: 20, #seed: 157
#
#
#  k_value: 20
#
# 0:01:05
# seed_rel: pos_dcg: 0.0462, neg_dcg: 0.9538, perc_dcg: 0.0314, oov: 146, #seed: 256
# 0:03:25
# seed_paper: pos_dcg: 0.1509, neg_dcg: 0.8491, perc_dcg: 0.1031, oov: 62, #seed: 399
#
# 0:01:06
# seed_paper_lite: pos_dcg: 0.1143, neg_dcg: 0.8857, perc_dcg: 0.0742, oov: 20, #seed: 157
#
#
#  k_value: 30
#
# 0:01:05
# seed_rel: pos_dcg: 0.0378, neg_dcg: 0.9622, perc_dcg: 0.0242, oov: 146, #seed: 256
#
# 0:03:24
# seed_paper: pos_dcg: 0.1234, neg_dcg: 0.8766, perc_dcg: 0.0803, oov: 62, #seed: 399
#
# 0:01:05
# seed_paper_lite: pos_dcg: 0.0908, neg_dcg: 0.9092, perc_dcg: 0.0541, oov: 20, #seed: 157
#
#
#  k_value: 40
#
# 0:01:04
# seed_rel: pos_dcg: 0.0322, neg_dcg: 0.9678, perc_dcg: 0.0196, oov: 146, #seed: 256
#
# 0:03:25
# seed_paper: pos_dcg: 0.1072, neg_dcg: 0.8928, perc_dcg: 0.0680, oov: 62, #seed: 399
#
# 0:01:05
# seed_paper_lite: pos_dcg: 0.0767, neg_dcg: 0.9233, perc_dcg: 0.0433, oov: 20, #seed: 157
#
#
#
#  The name of embedding is: PubMed-w2v
#
#
#  k_value: 5
#
# 0:00:52
# seed_rel: pos_dcg: 0.1156, neg_dcg: 0.8844, perc_dcg: 0.0930, oov: 136, #seed: 256
#
# 0:02:05
# seed_paper: pos_dcg: 0.2924, neg_dcg: 0.7076, perc_dcg: 0.2561, oov: 46, #seed: 399
#
# 0:00:38
# seed_paper_lite: pos_dcg: 0.2472, neg_dcg: 0.7528, perc_dcg: 0.1975, oov: 18, #seed: 157
#
#
#  k_value: 10
#
# 0:00:47
# seed_rel: pos_dcg: 0.0889, neg_dcg: 0.9111, perc_dcg: 0.0684, oov: 136, #seed: 256
#
# 0:02:08
# seed_paper: pos_dcg: 0.2174, neg_dcg: 0.7826, perc_dcg: 0.1687, oov: 46, #seed: 399
#
# 0:00:40
# seed_paper_lite: pos_dcg: 0.1786, neg_dcg: 0.8214, perc_dcg: 0.1248, oov: 18, #seed: 157
#
#
#  k_value: 20
#
# 0:00:49
# seed_rel: pos_dcg: 0.0663, neg_dcg: 0.9337, perc_dcg: 0.0477, oov: 136, #seed: 256
#
# 0:02:11
# seed_paper: pos_dcg: 0.1637, neg_dcg: 0.8363, perc_dcg: 0.1189, oov: 46, #seed: 399
#
# 0:00:39
# seed_paper_lite: pos_dcg: 0.1293, neg_dcg: 0.8707, perc_dcg: 0.0818, oov: 18, #seed: 157
#
#
#  k_value: 30
#
# 0:00:48
# seed_rel: pos_dcg: 0.0546, neg_dcg: 0.9454, perc_dcg: 0.0371, oov: 136, #seed: 256
#
# 0:02:07
# seed_paper: pos_dcg: 0.1369, neg_dcg: 0.8631, perc_dcg: 0.0962, oov: 46, #seed: 399
#
# 0:00:38
# seed_paper_lite: pos_dcg: 0.1040, neg_dcg: 0.8960, perc_dcg: 0.0620, oov: 18, #seed: 157
#
#
#  k_value: 40
#
# 0:00:48
# seed_rel: pos_dcg: 0.0477, neg_dcg: 0.9523, perc_dcg: 0.0316, oov: 136, #seed: 256
#
# 0:02:08
# seed_paper: pos_dcg: 0.1205, neg_dcg: 0.8795, perc_dcg: 0.0828, oov: 46, #seed: 399
#
# 0:00:40
# seed_paper_lite: pos_dcg: 0.0901, neg_dcg: 0.9099, perc_dcg: 0.0525, oov: 18, #seed: 157
#
#
#
#  The name of embedding is: tweetsvec
#
#
#  k_value: 5
#
# 0:00:00
# seed_rel: pos_dcg: 0.0210, neg_dcg: 0.9790, perc_dcg: 0.0187, oov: 193, #seed: 256
#
# 0:00:01
# seed_paper: pos_dcg: 0.0351, neg_dcg: 0.9649, perc_dcg: 0.0301, oov: 231, #seed: 399
#
# 0:00:00
# seed_paper_lite: pos_dcg: 0.0138, neg_dcg: 0.9862, perc_dcg: 0.0127, oov: 98, #seed: 157
#
#
#  k_value: 10
#
# 0:00:00
# seed_rel: pos_dcg: 0.0185, neg_dcg: 0.9815, perc_dcg: 0.0164, oov: 193, #seed: 256
#
# 0:00:00
# seed_paper: pos_dcg: 0.0313, neg_dcg: 0.9687, perc_dcg: 0.0273, oov: 231, #seed: 399
#
# 0:00:01
# seed_paper_lite: pos_dcg: 0.0115, neg_dcg: 0.9885, perc_dcg: 0.0102, oov: 98, #seed: 157
#
#
#  k_value: 20
#
# 0:00:00
# seed_rel: pos_dcg: 0.0169, neg_dcg: 0.9831, perc_dcg: 0.0152, oov: 193, #seed: 256
#
# 0:00:01
# seed_paper: pos_dcg: 0.0255, neg_dcg: 0.9745, perc_dcg: 0.0213, oov: 231, #seed: 399
#
# 0:00:00
# seed_paper_lite: pos_dcg: 0.0094, neg_dcg: 0.9906, perc_dcg: 0.0083, oov: 98, #seed: 157
#
#
#  k_value: 30
#
# 0:00:00
# seed_rel: pos_dcg: 0.0150, neg_dcg: 0.9850, perc_dcg: 0.0130, oov: 193, #seed: 256
#
# 0:00:01
# seed_paper: pos_dcg: 0.0229, neg_dcg: 0.9771, perc_dcg: 0.0191, oov: 231, #seed: 399
#
# 0:00:00
# seed_paper_lite: pos_dcg: 0.0077, neg_dcg: 0.9923, perc_dcg: 0.0062, oov: 98, #seed: 157
#
#
#  k_value: 40
#
# 0:00:01
# seed_rel: pos_dcg: 0.0142, neg_dcg: 0.9858, perc_dcg: 0.0123, oov: 193, #seed: 256
#
# 0:00:01
# seed_paper: pos_dcg: 0.0212, neg_dcg: 0.9788, perc_dcg: 0.0175, oov: 231, #seed: 399
#
# 0:00:00
# seed_paper_lite: pos_dcg: 0.0075, neg_dcg: 0.9925, perc_dcg: 0.0062, oov: 98, #seed: 157
#
#
#
#  The name of embedding is: wikipedia-pubmed-and-PMC-w2v
#
#
#  k_value: 5
#
# 0:01:52
# seed_rel: pos_dcg: 0.1141, neg_dcg: 0.8859, perc_dcg: 0.0945, oov: 136, #seed: 256
#
# 0:04:21
# seed_paper: pos_dcg: 0.2750, neg_dcg: 0.7250, perc_dcg: 0.2311, oov: 46, #seed: 399
#
# 0:01:22
# seed_paper_lite: pos_dcg: 0.2082, neg_dcg: 0.7918, perc_dcg: 0.1745, oov: 18, #seed: 157
#
#
#  k_value: 10
#
# 0:01:43
# seed_rel: pos_dcg: 0.0885, neg_dcg: 0.9115, perc_dcg: 0.0695, oov: 136, #seed: 256
#
# 0:04:36
# seed_paper: pos_dcg: 0.2113, neg_dcg: 0.7887, perc_dcg: 0.1644, oov: 46, #seed: 399
#
# 0:01:23
# seed_paper_lite: pos_dcg: 0.1572, neg_dcg: 0.8428, perc_dcg: 0.1197, oov: 18, #seed: 157
#
#
#  k_value: 20
#
# 0:01:42
# seed_rel: pos_dcg: 0.0665, neg_dcg: 0.9335, perc_dcg: 0.0480, oov: 136, #seed: 256
#
# 0:04:28
# seed_paper: pos_dcg: 0.1605, neg_dcg: 0.8395, perc_dcg: 0.1179, oov: 46, #seed: 399
#
# 0:01:22
# seed_paper_lite: pos_dcg: 0.1117, neg_dcg: 0.8883, perc_dcg: 0.0745, oov: 18, #seed: 157
#
#
#  k_value: 30
#
# 0:01:40
# seed_rel: pos_dcg: 0.0558, neg_dcg: 0.9442, perc_dcg: 0.0391, oov: 136, #seed: 256
#
# 0:04:26
# seed_paper: pos_dcg: 0.1334, neg_dcg: 0.8666, perc_dcg: 0.0947, oov: 46, #seed: 399
#
# 0:01:28
# seed_paper_lite: pos_dcg: 0.0904, neg_dcg: 0.9096, perc_dcg: 0.0567, oov: 18, #seed: 157
#
#
#  k_value: 40
#
# 0:01:55
# seed_rel: pos_dcg: 0.0486, neg_dcg: 0.9514, perc_dcg: 0.0337, oov: 136, #seed: 256
#
# 0:04:32
# seed_paper: pos_dcg: 0.1184, neg_dcg: 0.8816, perc_dcg: 0.0833, oov: 46, #seed: 399
#
# 0:01:20
# seed_paper_lite: pos_dcg: 0.0766, neg_dcg: 0.9234, perc_dcg: 0.0454, oov: 18, #seed: 157
#
# 2:23:16

# %% [markdown]
# ### Saving the obtained dictionary of all the embeddings tested, over the seeds and k values.

# %%
a = datetime.datetime.now().replace(microsecond=0)
utils.inputs_save(big_g, 'Utilities/big_g')
print(datetime.datetime.now().replace(microsecond=0)-a)
# Out:
# 0:00:00

# %% [markdown]
# ### Tabling data of dictionary

# %%
def table(big_g):
    df_ks = []
    for k in ks:
        names = list(big_g.keys())
        seeds = list(big_g[name][k].keys())
        header = [np.array([k]*24),
                  np.array([seeds[0],seeds[0],seeds[0],seeds[0],seeds[0], seeds[0],
                            seeds[1],seeds[1],seeds[1],seeds[1],seeds[1], seeds[1],
                            seeds[2],seeds[2],seeds[2],seeds[2],seeds[2], seeds[2],
                            seeds[3],seeds[3],seeds[3],seeds[3],seeds[3], seeds[3]]), 
                  np.array(['pos_dcg', 'neg_dcg', 'perc_dcg', 'iov%', 'oov', '#seed',
                            'pos_dcg', 'neg_dcg', 'perc_dcg', 'iov%', 'oov', '#seed',
                            'pos_dcg', 'neg_dcg', 'perc_dcg', 'iov%', 'oov', '#seed',
                            'pos_dcg', 'neg_dcg', 'perc_dcg', 'iov%', 'oov', '#seed'])] 
        tmp = [ ['%.3f'%(big_g[name][k][seed][0]),
                 '%.3f'%(big_g[name][k][seed][1]),
                 '%.3f'%(big_g[name][k][seed][2]),
                 '%.2f'%(((big_g[name][k][seed][4] - big_g[name][k][seed][3])/(big_g[name][k][seed][4]))*100)+'%',
                 '%d'%(big_g[name][k][seed][3]),
                 '%d'%(big_g[name][k][seed][4])] for name in names for seed in seeds]
        df_ks.append(pd.DataFrame(np.reshape(tmp, (11, 24)), index=np.array(names), columns = header))
    return df_ks

# %%
df_ks = table(big_g)

# %%
df_ks[0]
# Out:
#                                                5                           \
#                                         seed_rel
#                                          pos_dcg neg_dcg perc_dcg    iov%
# claims_cuis_hs_300.txt                     0.019   0.981    0.016  18.36%
# stanford_cuis_svd_300.txt                  0.000   1.000    0.000   0.00%
# cui2vec_pretrained                         0.045   0.955    0.041  53.12%
# DeVine_etal_200                            0.044   0.956    0.041  46.88%
# PMC-w2v                                    0.103   0.897    0.086  46.48%
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.041   0.959    0.040  29.30%
# PubMed-and-PMC-w2v                         0.123   0.877    0.105  46.88%
# GoogleNews-vectors-negative300             0.085   0.915    0.070  42.97%
# PubMed-w2v                                 0.116   0.884    0.093  46.88%
# tweetsvec                                  0.021   0.979    0.019  24.61%
# wikipedia-pubmed-and-PMC-w2v               0.114   0.886    0.095  46.88%
#
#                                                                        \
#                                                    seed_paper
#                                          oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                   209   256      0.000   1.000
# stanford_cuis_svd_300.txt                256   256      0.000   1.000
# cui2vec_pretrained                       120   256      0.055   0.945
# DeVine_etal_200                          136   256      0.053   0.947
# PMC-w2v                                  137   256      0.275   0.725
# Health_2.5mreviews.s200.w10.n5.v15.cbow  181   256      0.089   0.911
# PubMed-and-PMC-w2v                       136   256      0.292   0.708
# GoogleNews-vectors-negative300           146   256      0.281   0.719
# PubMed-w2v                               136   256      0.292   0.708
# tweetsvec                                193   256      0.035   0.965
# wikipedia-pubmed-and-PMC-w2v             136   256      0.275   0.725
#
#                                                           ...                  \
#                                                           ... seed_paper_lite
#                                         perc_dcg    iov%  ...        perc_dcg
# claims_cuis_hs_300.txt                     0.000   2.51%  ...           0.001
# stanford_cuis_svd_300.txt                  0.000   0.00%  ...           0.000
# cui2vec_pretrained                         0.055  46.37%  ...           0.017
# DeVine_etal_200                            0.048  43.36%  ...           0.014
# PMC-w2v                                    0.245  88.22%  ...           0.167
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.083  48.12%  ...           0.050
# PubMed-and-PMC-w2v                         0.254  88.47%  ...           0.172
# GoogleNews-vectors-negative300             0.242  84.46%  ...           0.191
# PubMed-w2v                                 0.256  88.47%  ...           0.197
# tweetsvec                                  0.030  42.11%  ...           0.013
# wikipedia-pubmed-and-PMC-w2v               0.231  88.47%  ...           0.175
#
#                                                                                \
#                                                            seed_union
#                                            iov%  oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                    1.91%  154   157      0.009   0.991
# stanford_cuis_svd_300.txt                 0.00%  157   157      0.000   1.000
# cui2vec_pretrained                       35.03%  102   157      0.056   0.944
# DeVine_etal_200                          32.48%  106   157      0.052   0.948
# PMC-w2v                                  88.54%   18   157      0.218   0.782
# Health_2.5mreviews.s200.w10.n5.v15.cbow  42.04%   91   157      0.071   0.929
# PubMed-and-PMC-w2v                       88.54%   18   157      0.236   0.764
# GoogleNews-vectors-negative300           87.26%   20   157      0.211   0.789
# PubMed-w2v                               88.54%   18   157      0.230   0.770
# tweetsvec                                37.58%   98   157      0.033   0.967
# wikipedia-pubmed-and-PMC-w2v             88.54%   18   157      0.220   0.780
#
#
#
#                                         perc_dcg    iov%  oov #seed
# claims_cuis_hs_300.txt                     0.007   8.32%  584   637
# stanford_cuis_svd_300.txt                  0.000   0.00%  637   637
# cui2vec_pretrained                         0.055  48.51%  328   637
# DeVine_etal_200                            0.047  44.11%  356   637
# PMC-w2v                                    0.193  71.90%  179   637
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.068  40.19%  381   637
# PubMed-and-PMC-w2v                         0.203  72.21%  177   637
# GoogleNews-vectors-negative300             0.180  68.13%  203   637
# PubMed-w2v                                 0.198  72.21%  177   637
# tweetsvec                                  0.029  34.69%  416   637
# wikipedia-pubmed-and-PMC-w2v               0.184  72.21%  177   637
#
# [11 rows x 24 columns]

# %%
df_ks[1]
# Out:
#                                               10                           \
#                                         seed_rel
#                                          pos_dcg neg_dcg perc_dcg    iov%
# claims_cuis_hs_300.txt                     0.014   0.986    0.010  18.36%
# stanford_cuis_svd_300.txt                  0.000   1.000    0.000   0.00%
# cui2vec_pretrained                         0.040   0.960    0.036  53.12%
# DeVine_etal_200                            0.037   0.963    0.032  46.88%
# PMC-w2v                                    0.084   0.916    0.070  46.48%
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.032   0.968    0.028  29.30%
# PubMed-and-PMC-w2v                         0.094   0.906    0.074  46.88%
# GoogleNews-vectors-negative300             0.064   0.936    0.046  42.97%
# PubMed-w2v                                 0.089   0.911    0.068  46.88%
# tweetsvec                                  0.019   0.981    0.016  24.61%
# wikipedia-pubmed-and-PMC-w2v               0.089   0.911    0.070  46.88%
#
#                                                                        \
#                                                    seed_paper
#                                          oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                   209   256      0.000   1.000
# stanford_cuis_svd_300.txt                256   256      0.000   1.000
# cui2vec_pretrained                       120   256      0.048   0.952
# DeVine_etal_200                          136   256      0.040   0.960
# PMC-w2v                                  137   256      0.216   0.784
# Health_2.5mreviews.s200.w10.n5.v15.cbow  181   256      0.072   0.928
# PubMed-and-PMC-w2v                       136   256      0.219   0.781
# GoogleNews-vectors-negative300           146   256      0.208   0.792
# PubMed-w2v                               136   256      0.217   0.783
# tweetsvec                                193   256      0.031   0.969
# wikipedia-pubmed-and-PMC-w2v             136   256      0.211   0.789
#
#                                                           ...                  \
#                                                           ... seed_paper_lite
#                                         perc_dcg    iov%  ...        perc_dcg
# claims_cuis_hs_300.txt                     0.000   2.51%  ...           0.001
# stanford_cuis_svd_300.txt                  0.000   0.00%  ...           0.000
# cui2vec_pretrained                         0.045  46.37%  ...           0.012
# DeVine_etal_200                            0.032  43.36%  ...           0.011
# PMC-w2v                                    0.177  88.22%  ...           0.111
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.062  48.12%  ...           0.039
# PubMed-and-PMC-w2v                         0.170  88.47%  ...           0.108
# GoogleNews-vectors-negative300             0.157  84.46%  ...           0.125
# PubMed-w2v                                 0.169  88.47%  ...           0.125
# tweetsvec                                  0.027  42.11%  ...           0.010
# wikipedia-pubmed-and-PMC-w2v               0.164  88.47%  ...           0.120
#
#                                                                                \
#                                                            seed_union
#                                            iov%  oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                    1.91%  154   157      0.007   0.993
# stanford_cuis_svd_300.txt                 0.00%  157   157      0.000   1.000
# cui2vec_pretrained                       35.03%  102   157      0.049   0.951
# DeVine_etal_200                          32.48%  106   157      0.042   0.958
# PMC-w2v                                  88.54%   18   157      0.173   0.827
# Health_2.5mreviews.s200.w10.n5.v15.cbow  42.04%   91   157      0.058   0.942
# PubMed-and-PMC-w2v                       88.54%   18   157      0.178   0.822
# GoogleNews-vectors-negative300           87.26%   20   157      0.157   0.843
# PubMed-w2v                               88.54%   18   157      0.173   0.827
# tweetsvec                                37.58%   98   157      0.030   0.970
# wikipedia-pubmed-and-PMC-w2v             88.54%   18   157      0.170   0.830
#
#
#
#                                         perc_dcg    iov%  oov #seed
# claims_cuis_hs_300.txt                     0.005   8.32%  584   637
# stanford_cuis_svd_300.txt                  0.000   0.00%  637   637
# cui2vec_pretrained                         0.045  48.51%  328   637
# DeVine_etal_200                            0.035  44.11%  356   637
# PMC-w2v                                    0.143  71.90%  179   637
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.050  40.19%  381   637
# PubMed-and-PMC-w2v                         0.138  72.21%  177   637
# GoogleNews-vectors-negative300             0.118  68.13%  203   637
# PubMed-w2v                                 0.135  72.21%  177   637
# tweetsvec                                  0.026  34.69%  416   637
# wikipedia-pubmed-and-PMC-w2v               0.133  72.21%  177   637
#
# [11 rows x 24 columns]

# %%
df_ks[2]
# Out:
#                                               20                           \
#                                         seed_rel
#                                          pos_dcg neg_dcg perc_dcg    iov%
# claims_cuis_hs_300.txt                     0.011   0.989    0.008  18.36%
# stanford_cuis_svd_300.txt                  0.000   1.000    0.000   0.00%
# cui2vec_pretrained                         0.035   0.965    0.031  53.12%
# DeVine_etal_200                            0.034   0.966    0.031  46.88%
# PMC-w2v                                    0.066   0.934    0.052  46.48%
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.026   0.974    0.021  29.30%
# PubMed-and-PMC-w2v                         0.071   0.929    0.052  46.88%
# GoogleNews-vectors-negative300             0.046   0.954    0.031  42.97%
# PubMed-w2v                                 0.066   0.934    0.048  46.88%
# tweetsvec                                  0.017   0.983    0.015  24.61%
# wikipedia-pubmed-and-PMC-w2v               0.067   0.933    0.048  46.88%
#
#                                                                        \
#                                                    seed_paper
#                                          oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                   209   256      0.000   1.000
# stanford_cuis_svd_300.txt                256   256      0.000   1.000
# cui2vec_pretrained                       120   256      0.039   0.961
# DeVine_etal_200                          136   256      0.032   0.968
# PMC-w2v                                  137   256      0.169   0.831
# Health_2.5mreviews.s200.w10.n5.v15.cbow  181   256      0.057   0.943
# PubMed-and-PMC-w2v                       136   256      0.166   0.834
# GoogleNews-vectors-negative300           146   256      0.151   0.849
# PubMed-w2v                               136   256      0.164   0.836
# tweetsvec                                193   256      0.026   0.974
# wikipedia-pubmed-and-PMC-w2v             136   256      0.160   0.840
#
#                                                           ...                  \
#                                                           ... seed_paper_lite
#                                         perc_dcg    iov%  ...        perc_dcg
# claims_cuis_hs_300.txt                     0.000   2.51%  ...           0.000
# stanford_cuis_svd_300.txt                  0.000   0.00%  ...           0.000
# cui2vec_pretrained                         0.033  46.37%  ...           0.008
# DeVine_etal_200                            0.025  43.36%  ...           0.007
# PMC-w2v                                    0.132  88.22%  ...           0.088
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.046  48.12%  ...           0.027
# PubMed-and-PMC-w2v                         0.121  88.47%  ...           0.079
# GoogleNews-vectors-negative300             0.103  84.46%  ...           0.074
# PubMed-w2v                                 0.119  88.47%  ...           0.082
# tweetsvec                                  0.021  42.11%  ...           0.008
# wikipedia-pubmed-and-PMC-w2v               0.118  88.47%  ...           0.075
#
#                                                                                \
#                                                            seed_union
#                                            iov%  oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                    1.91%  154   157      0.006   0.994
# stanford_cuis_svd_300.txt                 0.00%  157   157      0.000   1.000
# cui2vec_pretrained                       35.03%  102   157      0.042   0.958
# DeVine_etal_200                          32.48%  106   157      0.036   0.964
# PMC-w2v                                  88.54%   18   157      0.137   0.863
# Health_2.5mreviews.s200.w10.n5.v15.cbow  42.04%   91   157      0.047   0.953
# PubMed-and-PMC-w2v                       88.54%   18   157      0.136   0.864
# GoogleNews-vectors-negative300           87.26%   20   157      0.114   0.886
# PubMed-w2v                               88.54%   18   157      0.131   0.869
# tweetsvec                                37.58%   98   157      0.026   0.974
# wikipedia-pubmed-and-PMC-w2v             88.54%   18   157      0.130   0.870
#
#
#
#                                         perc_dcg    iov%  oov #seed
# claims_cuis_hs_300.txt                     0.004   8.32%  584   637
# stanford_cuis_svd_300.txt                  0.000   0.00%  637   637
# cui2vec_pretrained                         0.037  48.51%  328   637
# DeVine_etal_200                            0.030  44.11%  356   637
# PMC-w2v                                    0.109  71.90%  179   637
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.040  40.19%  381   637
# PubMed-and-PMC-w2v                         0.101  72.21%  177   637
# GoogleNews-vectors-negative300             0.078  68.13%  203   637
# PubMed-w2v                                 0.095  72.21%  177   637
# tweetsvec                                  0.023  34.69%  416   637
# wikipedia-pubmed-and-PMC-w2v               0.095  72.21%  177   637
#
# [11 rows x 24 columns]

# %%
df_ks[3]
# Out:
#                                               30                           \
#                                         seed_rel
#                                          pos_dcg neg_dcg perc_dcg    iov%
# claims_cuis_hs_300.txt                     0.011   0.989    0.008  18.36%
# stanford_cuis_svd_300.txt                  0.000   1.000    0.000   0.00%
# cui2vec_pretrained                         0.033   0.967    0.030  53.12%
# DeVine_etal_200                            0.032   0.968    0.028  46.88%
# PMC-w2v                                    0.056   0.944    0.043  46.48%
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.023   0.977    0.018  29.30%
# PubMed-and-PMC-w2v                         0.059   0.941    0.042  46.88%
# GoogleNews-vectors-negative300             0.038   0.962    0.024  42.97%
# PubMed-w2v                                 0.055   0.945    0.037  46.88%
# tweetsvec                                  0.015   0.985    0.013  24.61%
# wikipedia-pubmed-and-PMC-w2v               0.056   0.944    0.039  46.88%
#
#                                                                        \
#                                                    seed_paper
#                                          oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                   209   256      0.000   1.000
# stanford_cuis_svd_300.txt                256   256      0.000   1.000
# cui2vec_pretrained                       120   256      0.036   0.964
# DeVine_etal_200                          136   256      0.028   0.972
# PMC-w2v                                  137   256      0.144   0.856
# Health_2.5mreviews.s200.w10.n5.v15.cbow  181   256      0.049   0.951
# PubMed-and-PMC-w2v                       136   256      0.139   0.861
# GoogleNews-vectors-negative300           146   256      0.123   0.877
# PubMed-w2v                               136   256      0.137   0.863
# tweetsvec                                193   256      0.023   0.977
# wikipedia-pubmed-and-PMC-w2v             136   256      0.133   0.867
#
#                                                           ...                  \
#                                                           ... seed_paper_lite
#                                         perc_dcg    iov%  ...        perc_dcg
# claims_cuis_hs_300.txt                     0.000   2.51%  ...           0.000
# stanford_cuis_svd_300.txt                  0.000   0.00%  ...           0.000
# cui2vec_pretrained                         0.030  46.37%  ...           0.008
# DeVine_etal_200                            0.021  43.36%  ...           0.006
# PMC-w2v                                    0.110  88.22%  ...           0.065
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.038  48.12%  ...           0.021
# PubMed-and-PMC-w2v                         0.098  88.47%  ...           0.061
# GoogleNews-vectors-negative300             0.080  84.46%  ...           0.054
# PubMed-w2v                                 0.096  88.47%  ...           0.062
# tweetsvec                                  0.019  42.11%  ...           0.006
# wikipedia-pubmed-and-PMC-w2v               0.095  88.47%  ...           0.057
#
#                                                                                \
#                                                            seed_union
#                                            iov%  oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                    1.91%  154   157      0.005   0.995
# stanford_cuis_svd_300.txt                 0.00%  157   157      0.000   1.000
# cui2vec_pretrained                       35.03%  102   157      0.039   0.961
# DeVine_etal_200                          32.48%  106   157      0.032   0.968
# PMC-w2v                                  88.54%   18   157      0.117   0.883
# Health_2.5mreviews.s200.w10.n5.v15.cbow  42.04%   91   157      0.041   0.959
# PubMed-and-PMC-w2v                       88.54%   18   157      0.114   0.886
# GoogleNews-vectors-negative300           87.26%   20   157      0.093   0.907
# PubMed-w2v                               88.54%   18   157      0.110   0.890
# tweetsvec                                37.58%   98   157      0.024   0.976
# wikipedia-pubmed-and-PMC-w2v             88.54%   18   157      0.109   0.891
#
#
#
#                                         perc_dcg    iov%  oov #seed
# claims_cuis_hs_300.txt                     0.004   8.32%  584   637
# stanford_cuis_svd_300.txt                  0.000   0.00%  637   637
# cui2vec_pretrained                         0.035  48.51%  328   637
# DeVine_etal_200                            0.027  44.11%  356   637
# PMC-w2v                                    0.092  71.90%  179   637
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.033  40.19%  381   637
# PubMed-and-PMC-w2v                         0.082  72.21%  177   637
# GoogleNews-vectors-negative300             0.061  68.13%  203   637
# PubMed-w2v                                 0.077  72.21%  177   637
# tweetsvec                                  0.021  34.69%  416   637
# wikipedia-pubmed-and-PMC-w2v               0.077  72.21%  177   637
#
# [11 rows x 24 columns]

# %%
df_ks[4]
# Out:
#                                               40                           \
#                                         seed_rel
#                                          pos_dcg neg_dcg perc_dcg    iov%
# claims_cuis_hs_300.txt                     0.010   0.990    0.008  18.36%
# stanford_cuis_svd_300.txt                  0.000   1.000    0.000   0.00%
# cui2vec_pretrained                         0.032   0.968    0.029  53.12%
# DeVine_etal_200                            0.029   0.971    0.026  46.88%
# PMC-w2v                                    0.048   0.952    0.036  46.48%
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.020   0.980    0.016  29.30%
# PubMed-and-PMC-w2v                         0.052   0.948    0.035  46.88%
# GoogleNews-vectors-negative300             0.032   0.968    0.020  42.97%
# PubMed-w2v                                 0.048   0.952    0.032  46.88%
# tweetsvec                                  0.014   0.986    0.012  24.61%
# wikipedia-pubmed-and-PMC-w2v               0.049   0.951    0.034  46.88%
#
#                                                                        \
#                                                    seed_paper
#                                          oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                   209   256      0.000   1.000
# stanford_cuis_svd_300.txt                256   256      0.000   1.000
# cui2vec_pretrained                       120   256      0.032   0.968
# DeVine_etal_200                          136   256      0.025   0.975
# PMC-w2v                                  137   256      0.130   0.870
# Health_2.5mreviews.s200.w10.n5.v15.cbow  181   256      0.043   0.957
# PubMed-and-PMC-w2v                       136   256      0.122   0.878
# GoogleNews-vectors-negative300           146   256      0.107   0.893
# PubMed-w2v                               136   256      0.120   0.880
# tweetsvec                                193   256      0.021   0.979
# wikipedia-pubmed-and-PMC-w2v             136   256      0.118   0.882
#
#                                                           ...                  \
#                                                           ... seed_paper_lite
#                                         perc_dcg    iov%  ...        perc_dcg
# claims_cuis_hs_300.txt                     0.000   2.51%  ...           0.000
# stanford_cuis_svd_300.txt                  0.000   0.00%  ...           0.000
# cui2vec_pretrained                         0.027  46.37%  ...           0.007
# DeVine_etal_200                            0.019  43.36%  ...           0.005
# PMC-w2v                                    0.098  88.22%  ...           0.054
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.033  48.12%  ...           0.018
# PubMed-and-PMC-w2v                         0.084  88.47%  ...           0.050
# GoogleNews-vectors-negative300             0.068  84.46%  ...           0.043
# PubMed-w2v                                 0.083  88.47%  ...           0.053
# tweetsvec                                  0.018  42.11%  ...           0.006
# wikipedia-pubmed-and-PMC-w2v               0.083  88.47%  ...           0.045
#
#                                                                                \
#                                                            seed_union
#                                            iov%  oov #seed    pos_dcg neg_dcg
# claims_cuis_hs_300.txt                    1.91%  154   157      0.005   0.995
# stanford_cuis_svd_300.txt                 0.00%  157   157      0.000   1.000
# cui2vec_pretrained                       35.03%  102   157      0.036   0.964
# DeVine_etal_200                          32.48%  106   157      0.029   0.971
# PMC-w2v                                  88.54%   18   157      0.105   0.895
# Health_2.5mreviews.s200.w10.n5.v15.cbow  42.04%   91   157      0.036   0.964
# PubMed-and-PMC-w2v                       88.54%   18   157      0.100   0.900
# GoogleNews-vectors-negative300           87.26%   20   157      0.081   0.919
# PubMed-w2v                               88.54%   18   157      0.097   0.903
# tweetsvec                                37.58%   98   157      0.022   0.978
# wikipedia-pubmed-and-PMC-w2v             88.54%   18   157      0.097   0.903
#
#
#
#                                         perc_dcg    iov%  oov #seed
# claims_cuis_hs_300.txt                     0.004   8.32%  584   637
# stanford_cuis_svd_300.txt                  0.000   0.00%  637   637
# cui2vec_pretrained                         0.032  48.51%  328   637
# DeVine_etal_200                            0.024  44.11%  356   637
# PMC-w2v                                    0.081  71.90%  179   637
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.029  40.19%  381   637
# PubMed-and-PMC-w2v                         0.070  72.21%  177   637
# GoogleNews-vectors-negative300             0.052  68.13%  203   637
# PubMed-w2v                                 0.067  72.21%  177   637
# tweetsvec                                  0.019  34.69%  416   637
# wikipedia-pubmed-and-PMC-w2v               0.069  72.21%  177   637
#
# [11 rows x 24 columns]

# %% [markdown]
# ### Creating a dictionary of all the embeddings tested, over the max k value, corresponding to the number of IoV elements.

# %%
a = datetime.datetime.now().replace(microsecond=0)
big_k = {}

for type_emb in embeddings:
    for emb in type_emb[1]:
        model = KeyedVectors.load_word2vec_format(PATH_EMBEDDINGS+type_emb[0]+emb, binary=emb.endswith('.bin'))
        name = os.path.splitext(emb)[0]
        big_k[name] = {}
        print('\n\n The name of embedding is: %s\n' % name)
        for seed in seeds:
            if type_emb[0]=='/cuis/':
                Vemb = utils.extract_w2v_vocab(model)
                k_iov = len(list(set(Vemb).intersection(set(seed[1].keys()))))
                if k_iov <=0:
                    k_iov = 1
                
                d = measures.occurred_concept(model, seed[1].keys(), k_most_similar=k_iov)
                big_k[name][seed[0]] = [measures.pos_dcg(d, normalization = True, norm_fact = measures.max_dcg(k_iov)),
                                        measures.neg_dcg(d, normalization = True, norm_fact = measures.max_dcg(k_iov)),
                                        measures.percentage_dcg(d, k=k_iov),
                                        k_iov,
                                        measures.oov(d),
                                        len(seed[1]), []]
            
            elif type_emb[0]=='/words/':
                Vemb = utils.extract_w2v_vocab(model)                
                processed_seed = umls_tables_processing.discarding_labels_oov(Vemb, seed[1])
                k_iov = sum([1 for k,v in processed_seed.items() if len(v)>0])
                if k_iov <= 0:
                    k_iov = 1
                
                d, _ = measures.occurred_labels(model, processed_seed, k_most_similar=k_iov)
                big_k[name][seed[0]] = [measures.pos_dcg(d, normalization = True, norm_fact = measures.max_dcg(k_iov)),
                                        measures.neg_dcg(d, normalization = True, norm_fact = measures.max_dcg(k_iov)),
                                        measures.percentage_dcg(d, k=k_iov),
                                        k_iov,
                                        measures.oov(d),
                                        len(seed[1]), []]
            print('{:s}: pos_dcg: {:.4f}, neg_dcg: {:.4f}, perc_dcg: {:.4f}, iov/k-NN: {:d}, oov: {:d}, #seed: {:d}\n'.
                  format(seed[0],
                         big_k[name][seed[0]][0],
                         big_k[name][seed[0]][1],
                         big_k[name][seed[0]][2],
                         big_k[name][seed[0]][3],
                         big_k[name][seed[0]][4],
                         big_k[name][seed[0]][5]))
print(datetime.datetime.now().replace(microsecond=0)-a)

del big_k['stanford_cuis_svd_300.txt']
# Out:
#  The name of embedding is: claims_cuis_hs_300.txt
#
# seed_rel: pos_dcg: 0.0097, neg_dcg: 0.9903, perc_dcg: 0.0078, iov/k-NN: 47, oov: 209, #seed: 256
#
# seed_paper: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, iov/k-NN: 10, oov: 389, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0015, neg_dcg: 0.9985, perc_dcg: 0.0021, iov/k-NN: 3, oov: 154, #seed: 157
#
#
#
#  The name of embedding is: stanford_cuis_svd_300.txt
#
# seed_rel: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, iov/k-NN: 1, oov: 256, #seed: 256
#
# seed_paper: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, iov/k-NN: 1, oov: 399, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, iov/k-NN: 1, oov: 157, #seed: 157
# /home/salvatore/venv/lib/python3.8/site-packages/gensim/models/keyedvectors.py:2389: RuntimeWarning: invalid value encountered in true_divide
#   return (m / dist).astype(REAL)
#  The name of embedding is: cui2vec_pretrained
#
# seed_rel: pos_dcg: 0.0229, neg_dcg: 0.9771, perc_dcg: 0.0198, iov/k-NN: 136, oov: 120, #seed: 256
#
# seed_paper: pos_dcg: 0.0192, neg_dcg: 0.9808, perc_dcg: 0.0155, iov/k-NN: 185, oov: 214, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0074, neg_dcg: 0.9926, perc_dcg: 0.0060, iov/k-NN: 55, oov: 102, #seed: 157
#
#
#
#  The name of embedding is: DeVine_etal_200
#
# seed_rel: pos_dcg: 0.0210, neg_dcg: 0.9790, perc_dcg: 0.0177, iov/k-NN: 120, oov: 136, #seed: 256
#
# seed_paper: pos_dcg: 0.0137, neg_dcg: 0.9863, perc_dcg: 0.0099, iov/k-NN: 173, oov: 226, #seed: 399
#
# seed_paper_lite: pos_dcg: 0.0072, neg_dcg: 0.9928, perc_dcg: 0.0042, iov/k-NN: 51, oov: 106, #seed: 157
#
#
#
#  The name of embedding is: PMC-w2v
#
# 0:00:02
# 0:01:29
# seed_rel: pos_dcg: 0.0294, neg_dcg: 0.9706, perc_dcg: 0.0205, iov/k-NN: 119, oov: 137, #seed: 256
#
# 0:00:02
# 0:04:02
# seed_paper: pos_dcg: 0.0565, neg_dcg: 0.9435, perc_dcg: 0.0452, iov/k-NN: 352, oov: 47, #seed: 399
#
# 0:00:01
# 0:01:15
# seed_paper_lite: pos_dcg: 0.0412, neg_dcg: 0.9588, perc_dcg: 0.0244, iov/k-NN: 139, oov: 18, #seed: 157
#
#
#
#  The name of embedding is: Health_2.5mreviews.s200.w10.n5.v15.cbow
#
# 0:00:00
# 0:00:01
# seed_rel: pos_dcg: 0.0156, neg_dcg: 0.9844, perc_dcg: 0.0119, iov/k-NN: 75, oov: 181, #seed: 256
#
# 0:00:00
# 0:00:04
# seed_paper: pos_dcg: 0.0242, neg_dcg: 0.9758, perc_dcg: 0.0193, iov/k-NN: 192, oov: 207, #seed: 399
#
# 0:00:00
# 0:00:01
# seed_paper_lite: pos_dcg: 0.0199, neg_dcg: 0.9801, perc_dcg: 0.0133, iov/k-NN: 66, oov: 91, #seed: 157
#
#
#
#  The name of embedding is: PubMed-and-PMC-w2v
#
# 0:00:05
# 0:03:53
# seed_rel: pos_dcg: 0.0295, neg_dcg: 0.9705, perc_dcg: 0.0189, iov/k-NN: 120, oov: 136, #seed: 256
#
# 0:00:07
# 0:11:42
# seed_paper: pos_dcg: 0.0450, neg_dcg: 0.9550, perc_dcg: 0.0323, iov/k-NN: 353, oov: 46, #seed: 399
#
# 0:00:22
# 0:01:52
# seed_paper_lite: pos_dcg: 0.0396, neg_dcg: 0.9604, perc_dcg: 0.0223, iov/k-NN: 139, oov: 18, #seed: 157
#
#
#
#  The name of embedding is: GoogleNews-vectors-negative300
#
# 0:00:07
# 0:02:03
# seed_rel: pos_dcg: 0.0194, neg_dcg: 0.9806, perc_dcg: 0.0118, iov/k-NN: 110, oov: 146, #seed: 256
#
# 0:00:07
# 0:05:09
# seed_paper: pos_dcg: 0.0326, neg_dcg: 0.9674, perc_dcg: 0.0189, iov/k-NN: 337, oov: 62, #seed: 399
#
# 0:00:08
# 0:01:42
# seed_paper_lite: pos_dcg: 0.0349, neg_dcg: 0.9651, perc_dcg: 0.0159, iov/k-NN: 137, oov: 20, #seed: 157
#
#
#
#  The name of embedding is: PubMed-w2v
#
# 0:00:08
# 0:01:53
# seed_rel: pos_dcg: 0.0276, neg_dcg: 0.9724, perc_dcg: 0.0175, iov/k-NN: 120, oov: 136, #seed: 256
#
# 0:00:06
# 0:04:07
# seed_paper: pos_dcg: 0.0417, neg_dcg: 0.9583, perc_dcg: 0.0284, iov/k-NN: 353, oov: 46, #seed: 399
#
# 0:00:06
# 0:01:19
# seed_paper_lite: pos_dcg: 0.0430, neg_dcg: 0.9570, perc_dcg: 0.0216, iov/k-NN: 139, oov: 18, #seed: 157
#
#
#
#  The name of embedding is: tweetsvec
#
# 0:00:00
# 0:00:01
# seed_rel: pos_dcg: 0.0132, neg_dcg: 0.9868, perc_dcg: 0.0117, iov/k-NN: 63, oov: 193, #seed: 256
#
# 0:00:00
# 0:00:01
# seed_paper: pos_dcg: 0.0133, neg_dcg: 0.9867, perc_dcg: 0.0109, iov/k-NN: 168, oov: 231, #seed: 399
#
# 0:00:01
# 0:00:00
# seed_paper_lite: pos_dcg: 0.0064, neg_dcg: 0.9936, perc_dcg: 0.0051, iov/k-NN: 59, oov: 98, #seed: 157
#
#
#
#  The name of embedding is: wikipedia-pubmed-and-PMC-w2v
#
# 0:00:09
# 0:03:53
# seed_rel: pos_dcg: 0.0280, neg_dcg: 0.9720, perc_dcg: 0.0185, iov/k-NN: 120, oov: 136, #seed: 256
#
# 0:00:06
# 0:12:22
# seed_paper: pos_dcg: 0.0417, neg_dcg: 0.9583, perc_dcg: 0.0294, iov/k-NN: 353, oov: 46, #seed: 399
#
# 0:00:07
# 0:02:44
# seed_paper_lite: pos_dcg: 0.0372, neg_dcg: 0.9628, perc_dcg: 0.0195, iov/k-NN: 139, oov: 18, #seed: 157
#
# 1:41:28

# %%
df_kmax = []
names = list(big_k.keys())
seeds = list(big_k[name].keys())
header = [np.array([seeds[0]+' #256',seeds[0]+' #256', seeds[0]+' #256', seeds[0]+' #256', seeds[0]+' #256',
                    seeds[1]+' #399',seeds[1]+' #399', seeds[1]+' #399', seeds[1]+' #399', seeds[1]+' #399',
                    seeds[2]+' #157',seeds[2]+' #157', seeds[2]+' #157', seeds[2]+' #157', seeds[2]+' #157',
                    seeds[3]+' #637',seeds[3]+' #637', seeds[3]+' #637', seeds[3]+' #637', seeds[3]+' #637']),
          np.array(['pos_dcg', 'neg_dcg', 'perc_dcg', 'iov/k-NN', 'oov',
                    'pos_dcg', 'neg_dcg', 'perc_dcg', 'iov/k-NN', 'oov',
                    'pos_dcg', 'neg_dcg', 'perc_dcg', 'iov/k-NN', 'oov',
                    'pos_dcg', 'neg_dcg', 'perc_dcg', 'iov/k-NN', 'oov'])] 

tmp = [ ['%.3f'%(big_k[name][seed][0]),
         '%.3f'%(big_k[name][seed][1]),
         '%.3f'%(big_k[name][seed][2]),
         '%d'%(big_k[name][seed][3]),
         '%d'%(big_k[name][seed][4])] for name in names for seed in seeds]
df_kmax.append(pd.DataFrame(np.reshape(tmp, (10, 20)), index=np.array(names), columns = header))

# %%
df_kmax[0]
# Out:
#                                         seed_rel #256                   \
#                                               pos_dcg neg_dcg perc_dcg
# claims_cuis_hs_300.txt                          0.010   0.990    0.008
# cui2vec_pretrained                              0.023   0.977    0.020
# DeVine_etal_200                                 0.021   0.979    0.018
# PMC-w2v                                         0.029   0.971    0.021
# Health_2.5mreviews.s200.w10.n5.v15.cbow         0.016   0.984    0.012
# PubMed-and-PMC-w2v                              0.029   0.971    0.019
# GoogleNews-vectors-negative300                  0.019   0.981    0.012
# PubMed-w2v                                      0.028   0.972    0.018
# tweetsvec                                       0.013   0.987    0.012
# wikipedia-pubmed-and-PMC-w2v                    0.028   0.972    0.019
#
#                                                       seed_paper #399          \
#                                         iov/k-NN  oov         pos_dcg neg_dcg
# claims_cuis_hs_300.txt                        47  209           0.000   1.000
# cui2vec_pretrained                           136  120           0.019   0.981
# DeVine_etal_200                              120  136           0.014   0.986
# PMC-w2v                                      119  137           0.056   0.944
# Health_2.5mreviews.s200.w10.n5.v15.cbow       75  181           0.024   0.976
# PubMed-and-PMC-w2v                           120  136           0.045   0.955
# GoogleNews-vectors-negative300               110  146           0.033   0.967
# PubMed-w2v                                   120  136           0.042   0.958
# tweetsvec                                     63  193           0.013   0.987
# wikipedia-pubmed-and-PMC-w2v                 120  136           0.042   0.958
#
#                                                                 \
#                                         perc_dcg iov/k-NN  oov
# claims_cuis_hs_300.txt                     0.000       10  389
# cui2vec_pretrained                         0.015      185  214
# DeVine_etal_200                            0.010      173  226
# PMC-w2v                                    0.045      352   47
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.019      192  207
# PubMed-and-PMC-w2v                         0.032      353   46
# GoogleNews-vectors-negative300             0.019      337   62
# PubMed-w2v                                 0.028      353   46
# tweetsvec                                  0.011      168  231
# wikipedia-pubmed-and-PMC-w2v               0.029      353   46
#
#                                         seed_paper_lite #157                   \
#                                                      pos_dcg neg_dcg perc_dcg
# claims_cuis_hs_300.txt                                 0.001   0.999    0.002
# cui2vec_pretrained                                     0.007   0.993    0.006
# DeVine_etal_200                                        0.007   0.993    0.004
# PMC-w2v                                                0.041   0.959    0.024
# Health_2.5mreviews.s200.w10.n5.v15.cbow                0.020   0.980    0.013
# PubMed-and-PMC-w2v                                     0.040   0.960    0.022
# GoogleNews-vectors-negative300                         0.035   0.965    0.016
# PubMed-w2v                                             0.043   0.957    0.022
# tweetsvec                                              0.006   0.994    0.005
# wikipedia-pubmed-and-PMC-w2v                           0.037   0.963    0.019
#
#                                                       seed_union #637          \
#                                         iov/k-NN  oov         pos_dcg neg_dcg
# claims_cuis_hs_300.txt                         3  154           0.005   0.995
# cui2vec_pretrained                            55  102           0.020   0.980
# DeVine_etal_200                               51  106           0.014   0.986
# PMC-w2v                                      139   18           0.042   0.958
# Health_2.5mreviews.s200.w10.n5.v15.cbow       66   91           0.019   0.981
# PubMed-and-PMC-w2v                           139   18           0.032   0.968
# GoogleNews-vectors-negative300               137   20           0.022   0.978
# PubMed-w2v                                   139   18           0.029   0.971
# tweetsvec                                     59   98           0.015   0.985
# wikipedia-pubmed-and-PMC-w2v                 139   18           0.030   0.970
#
#
#                                         perc_dcg iov/k-NN  oov
# claims_cuis_hs_300.txt                     0.004      584  637
# cui2vec_pretrained                         0.017      328  637
# DeVine_etal_200                            0.011      356  637
# PMC-w2v                                    0.034      179  637
# Health_2.5mreviews.s200.w10.n5.v15.cbow    0.016      381  637
# PubMed-and-PMC-w2v                         0.023      177  637
# GoogleNews-vectors-negative300             0.013      203  637
# PubMed-w2v                                 0.020      177  637
# tweetsvec                                  0.013      416  637
# wikipedia-pubmed-and-PMC-w2v               0.021      177  637

# %% [markdown]
# New experimentation with the union of `seed_paper` and `seed_rel` is proposed:

# %%
a = datetime.datetime.now().replace(microsecond=0)
big_g = utils.inputs_load('Utilities/big_g')

for type_emb in embeddings:
    for emb in type_emb[1]:
        model = KeyedVectors.load_word2vec_format(PATH_EMBEDDINGS+type_emb[0]+emb, binary=emb.endswith('.bin'))
        name = os.path.splitext(emb)[0]
        print('\n\n The name of embedding is: %s\n' % name)
        for k in ks:
            print('\n k_value: %s\n' % k)
            if type_emb[0]=='/cuis/':
                d = measures.occurred_concept(model, seed_union.keys(), k_most_similar=k)
                big_g[name][k]['seed_union'] = [measures.pos_dcg(d, normalization = True, norm_fact = measures.max_dcg(k)),
                                                measures.neg_dcg(d, normalization = True, norm_fact = measures.max_dcg(k)),
                                                measures.percentage_dcg(d, k=k),
                                                measures.oov(d),
                                                len(seed_union), []]
            elif type_emb[0]=='/words/':
                d, new_seed = measures.occurred_labels(model, seed_union, k_most_similar=k)
                big_g[name][k]['seed_union'] = [measures.pos_dcg(d, normalization = True, norm_fact = measures.max_dcg(k)),
                                                measures.neg_dcg(d, normalization = True, norm_fact = measures.max_dcg(k)),
                                                measures.percentage_dcg(d, k=k),
                                                measures.oov(d),
                                                len(seed_union),
                                                new_seed]
            print('{:s}: pos_dcg: {:.4f}, neg_dcg: {:.4f}, perc_dcg: {:.4f}, oov: {:d}, #seed: {:d}\n'.
                  format('seed_union',
                         big_g[name][k]['seed_union'][0],
                         big_g[name][k]['seed_union'][1],
                         big_g[name][k]['seed_union'][2],
                         big_g[name][k]['seed_union'][3],
                         big_g[name][k]['seed_union'][4]))
print(datetime.datetime.now().replace(microsecond=0)-a)
# Out:
#  The name of embedding is: claims_cuis_hs_300.txt
#
#
#  k_value: 5
#
# seed_union: pos_dcg: 0.0088, neg_dcg: 0.9912, perc_dcg: 0.0072, oov: 584, #seed: 637
#
#
#  k_value: 10
#
# seed_union: pos_dcg: 0.0067, neg_dcg: 0.9933, perc_dcg: 0.0050, oov: 584, #seed: 637
#
#
#  k_value: 20
#
# seed_union: pos_dcg: 0.0057, neg_dcg: 0.9943, perc_dcg: 0.0045, oov: 584, #seed: 637
#
#
#  k_value: 30
#
# seed_union: pos_dcg: 0.0054, neg_dcg: 0.9946, perc_dcg: 0.0044, oov: 584, #seed: 637
#
#
#  k_value: 40
#
# seed_union: pos_dcg: 0.0051, neg_dcg: 0.9949, perc_dcg: 0.0043, oov: 584, #seed: 637
#
#
#
#  The name of embedding is: stanford_cuis_svd_300.txt
#
#
#  k_value: 5
# /home/salvatore/venv/lib/python3.8/site-packages/gensim/models/keyedvectors.py:2389: RuntimeWarning: invalid value encountered in true_divide
#   return (m / dist).astype(REAL)
# seed_union: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 637, #seed: 637
#
#
#  k_value: 10
#
# seed_union: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 637, #seed: 637
#
#
#  k_value: 20
#
# seed_union: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 637, #seed: 637
#
#
#  k_value: 30
#
# seed_union: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 637, #seed: 637
#
#
#  k_value: 40
#
# seed_union: pos_dcg: 0.0000, neg_dcg: 1.0000, perc_dcg: 0.0000, oov: 637, #seed: 637
#
#
#
#  The name of embedding is: cui2vec_pretrained
#
#
#  k_value: 5
#
# seed_union: pos_dcg: 0.0561, neg_dcg: 0.9439, perc_dcg: 0.0546, oov: 328, #seed: 637
#
#
#  k_value: 10
#
# seed_union: pos_dcg: 0.0488, neg_dcg: 0.9512, perc_dcg: 0.0451, oov: 328, #seed: 637
#
#
#  k_value: 20
#
# seed_union: pos_dcg: 0.0417, neg_dcg: 0.9583, perc_dcg: 0.0367, oov: 328, #seed: 637
#
#
#  k_value: 30
#
# seed_union: pos_dcg: 0.0391, neg_dcg: 0.9609, perc_dcg: 0.0345, oov: 328, #seed: 637
#
#
#  k_value: 40
#
# seed_union: pos_dcg: 0.0365, neg_dcg: 0.9635, perc_dcg: 0.0319, oov: 328, #seed: 637
#
#
#
#  The name of embedding is: DeVine_etal_200
#
#
#  k_value: 5
#
# seed_union: pos_dcg: 0.0519, neg_dcg: 0.9481, perc_dcg: 0.0471, oov: 356, #seed: 637
#
#
#  k_value: 10
#
# seed_union: pos_dcg: 0.0419, neg_dcg: 0.9581, perc_dcg: 0.0353, oov: 356, #seed: 637
#
#
#  k_value: 20
#
# seed_union: pos_dcg: 0.0355, neg_dcg: 0.9645, perc_dcg: 0.0296, oov: 356, #seed: 637
#
#
#  k_value: 30
#
# seed_union: pos_dcg: 0.0320, neg_dcg: 0.9680, perc_dcg: 0.0265, oov: 356, #seed: 637
#
#
#  k_value: 40
#
# seed_union: pos_dcg: 0.0293, neg_dcg: 0.9707, perc_dcg: 0.0239, oov: 356, #seed: 637
#
#
#
#  The name of embedding is: PMC-w2v
#
#
#  k_value: 5
#
# 0:07:30
# seed_union: pos_dcg: 0.2178, neg_dcg: 0.7822, perc_dcg: 0.1928, oov: 179, #seed: 637
#
#
#  k_value: 10
#
# 0:04:32
# seed_union: pos_dcg: 0.1726, neg_dcg: 0.8274, perc_dcg: 0.1429, oov: 179, #seed: 637
#
#
#  k_value: 20
#
# 0:04:22
# seed_union: pos_dcg: 0.1368, neg_dcg: 0.8632, perc_dcg: 0.1091, oov: 179, #seed: 637
#
#
#  k_value: 30
#
# 0:04:21
# seed_union: pos_dcg: 0.1174, neg_dcg: 0.8826, perc_dcg: 0.0918, oov: 179, #seed: 637
#
#
#  k_value: 40
#
# 0:04:48
# seed_union: pos_dcg: 0.1054, neg_dcg: 0.8946, perc_dcg: 0.0814, oov: 179, #seed: 637
#
#
#
#  The name of embedding is: Health_2.5mreviews.s200.w10.n5.v15.cbow
#
#
#  k_value: 5
#
# 0:00:13
# seed_union: pos_dcg: 0.0714, neg_dcg: 0.9286, perc_dcg: 0.0675, oov: 381, #seed: 637
#
#
#  k_value: 10
#
# 0:00:08
# seed_union: pos_dcg: 0.0579, neg_dcg: 0.9421, perc_dcg: 0.0504, oov: 381, #seed: 637
#
#
#  k_value: 20
#
# 0:00:12
# seed_union: pos_dcg: 0.0471, neg_dcg: 0.9529, perc_dcg: 0.0396, oov: 381, #seed: 637
#
#
#  k_value: 30
#
# 0:00:12
# seed_union: pos_dcg: 0.0406, neg_dcg: 0.9594, perc_dcg: 0.0330, oov: 381, #seed: 637
#
#
#  k_value: 40
#
# 0:00:14
# seed_union: pos_dcg: 0.0362, neg_dcg: 0.9638, perc_dcg: 0.0289, oov: 381, #seed: 637
#
#
#
#  The name of embedding is: PubMed-and-PMC-w2v
#
#
#  k_value: 5
#
# 0:11:06
# seed_union: pos_dcg: 0.2362, neg_dcg: 0.7638, perc_dcg: 0.2035, oov: 177, #seed: 637
#
#
#  k_value: 10
#
# 0:07:13
# seed_union: pos_dcg: 0.1776, neg_dcg: 0.8224, perc_dcg: 0.1383, oov: 177, #seed: 637
#
#
#  k_value: 20
#
# 0:07:29
# seed_union: pos_dcg: 0.1360, neg_dcg: 0.8640, perc_dcg: 0.1006, oov: 177, #seed: 637
#
#
#  k_value: 30
#
# 0:07:27
# seed_union: pos_dcg: 0.1142, neg_dcg: 0.8858, perc_dcg: 0.0816, oov: 177, #seed: 637
#
#
#  k_value: 40
#
# 0:07:39
# seed_union: pos_dcg: 0.1003, neg_dcg: 0.8997, perc_dcg: 0.0702, oov: 177, #seed: 637
#
#
#
#  The name of embedding is: GoogleNews-vectors-negative300
#
#
#  k_value: 5
#
# 0:09:27
# seed_union: pos_dcg: 0.2113, neg_dcg: 0.7887, perc_dcg: 0.1802, oov: 203, #seed: 637
#
#
#  k_value: 10
#
# 0:05:54
# seed_union: pos_dcg: 0.1566, neg_dcg: 0.8434, perc_dcg: 0.1177, oov: 203, #seed: 637
#
#
#  k_value: 20
#
# 0:06:00
# seed_union: pos_dcg: 0.1136, neg_dcg: 0.8864, perc_dcg: 0.0777, oov: 203, #seed: 637
#
#
#  k_value: 30
#
# 0:06:11
# seed_union: pos_dcg: 0.0929, neg_dcg: 0.9071, perc_dcg: 0.0606, oov: 203, #seed: 637
#
#
#  k_value: 40
#
# 0:07:25
# seed_union: pos_dcg: 0.0807, neg_dcg: 0.9193, perc_dcg: 0.0515, oov: 203, #seed: 637
#
#
#
#  The name of embedding is: PubMed-w2v
#
#
#  k_value: 5
#
# 0:06:52
# seed_union: pos_dcg: 0.2304, neg_dcg: 0.7696, perc_dcg: 0.1984, oov: 177, #seed: 637
#
#
#  k_value: 10
#
# 0:04:18
# seed_union: pos_dcg: 0.1733, neg_dcg: 0.8267, perc_dcg: 0.1349, oov: 177, #seed: 637
#
#
#  k_value: 20
#
# 0:04:32
# seed_union: pos_dcg: 0.1308, neg_dcg: 0.8692, perc_dcg: 0.0954, oov: 177, #seed: 637
#
#
#  k_value: 30
#
# 0:04:41
# seed_union: pos_dcg: 0.1096, neg_dcg: 0.8904, perc_dcg: 0.0775, oov: 177, #seed: 637
#
#
#  k_value: 40
#
# 0:04:49
# seed_union: pos_dcg: 0.0966, neg_dcg: 0.9034, perc_dcg: 0.0669, oov: 177, #seed: 637
#
#
#
#  The name of embedding is: tweetsvec
#
#
#  k_value: 5
#
# 0:00:03
# seed_union: pos_dcg: 0.0333, neg_dcg: 0.9667, perc_dcg: 0.0292, oov: 416, #seed: 637
#
#
#  k_value: 10
#
# 0:00:03
# seed_union: pos_dcg: 0.0297, neg_dcg: 0.9703, perc_dcg: 0.0262, oov: 416, #seed: 637
#
#
#  k_value: 20
#
# 0:00:04
# seed_union: pos_dcg: 0.0261, neg_dcg: 0.9739, perc_dcg: 0.0230, oov: 416, #seed: 637
#
#
#  k_value: 30
#
# 0:00:05
# seed_union: pos_dcg: 0.0238, neg_dcg: 0.9762, perc_dcg: 0.0207, oov: 416, #seed: 637
#
#
#  k_value: 40
#
# 0:00:06
# seed_union: pos_dcg: 0.0221, neg_dcg: 0.9779, perc_dcg: 0.0191, oov: 416, #seed: 637
#
#
#
#  The name of embedding is: wikipedia-pubmed-and-PMC-w2v
#
#
#  k_value: 5
#
# 0:14:40
# seed_union: pos_dcg: 0.2200, neg_dcg: 0.7800, perc_dcg: 0.1840, oov: 177, #seed: 637
#
#
#  k_value: 10
#
# 0:09:32
# seed_union: pos_dcg: 0.1705, neg_dcg: 0.8295, perc_dcg: 0.1330, oov: 177, #seed: 637
#
#
#  k_value: 20
#
# 0:18:44
# seed_union: pos_dcg: 0.1298, neg_dcg: 0.8702, perc_dcg: 0.0954, oov: 177, #seed: 637
#
#
#  k_value: 30
#
# 0:09:53
# seed_union: pos_dcg: 0.1086, neg_dcg: 0.8914, perc_dcg: 0.0774, oov: 177, #seed: 637
#
#
#  k_value: 40
#
# 0:10:06
# seed_union: pos_dcg: 0.0966, neg_dcg: 0.9034, perc_dcg: 0.0688, oov: 177, #seed: 637
#
# 4:53:39

# %% [markdown]
# Refresh the old stored dictionary

# %%
a = datetime.datetime.now().replace(microsecond=0)
utils.inputs_save(big_g, 'Utilities/big_g')
print(datetime.datetime.now().replace(microsecond=0)-a)
# Out:
# 0:00:00

# %% [markdown]
# The experiment on k_most_similar = max k value is repeated on unified seed

# %%
a = datetime.datetime.now().replace(microsecond=0)
big_k = utils.inputs_load('Utilities/big_k')

for type_emb in embeddings:
    for emb in type_emb[1]:
        model = KeyedVectors.load_word2vec_format(PATH_EMBEDDINGS+type_emb[0]+emb, binary=emb.endswith('.bin'))
        name = os.path.splitext(emb)[0]
        print('\n\n The name of embedding is: %s\n' % name)
        if type_emb[0]=='/cuis/':
            if name != 'stanford_cuis_svd_300.txt':
                Vemb = utils.extract_w2v_vocab(model)
                k_iov = len(list(set(Vemb).intersection(set(seed_union.keys()))))
                if k_iov <=0:
                    k_iov = 1
                d = measures.occurred_concept(model, seed_union.keys(), k_most_similar=k_iov)
                big_k[name]['seed_union'] = [measures.pos_dcg(d, normalization = True, norm_fact = measures.max_dcg(k_iov)),
                                             measures.neg_dcg(d, normalization = True, norm_fact = measures.max_dcg(k_iov)),
                                             measures.percentage_dcg(d, k=k_iov),
                                             measures.oov(d),
                                             len(seed_union), []]
        elif type_emb[0]=='/words/':
            Vemb = utils.extract_w2v_vocab(model)                
            processed_seed = umls_tables_processing.discarding_labels_oov(Vemb, seed_union)
            k_iov = sum([1 for k,v in processed_seed.items() if len(v)>0])
            if k_iov <= 0:
                k_iov = 1
            d, new_seed = measures.occurred_labels(model, seed_union, k_most_similar=k_iov)
            big_k[name]['seed_union'] = [measures.pos_dcg(d, normalization = True, norm_fact = measures.max_dcg(k_iov)),
                                            measures.neg_dcg(d, normalization = True, norm_fact = measures.max_dcg(k_iov)),
                                            measures.percentage_dcg(d, k=k_iov),
                                            measures.oov(d),
                                            len(seed_union),
                                            new_seed]
        if name != 'stanford_cuis_svd_300.txt':
            print('{:s}: pos_dcg: {:.4f}, neg_dcg: {:.4f}, perc_dcg: {:.4f}, oov: {:d}, #seed: {:d}\n'.
                  format('seed_union',
                         big_k[name]['seed_union'][0],
                         big_k[name]['seed_union'][1],
                         big_k[name]['seed_union'][2],
                         big_k[name]['seed_union'][3],
                         big_k[name]['seed_union'][4]))
print(datetime.datetime.now().replace(microsecond=0)-a)
# Out:
# 0:00:00
#
#
#  The name of embedding is: claims_cuis_hs_300.txt
#
# seed_union: pos_dcg: 0.0048, neg_dcg: 0.9952, perc_dcg: 0.0041, oov: 584, #seed: 637
#
#
#
#  The name of embedding is: stanford_cuis_svd_300.txt
#
#
#
#  The name of embedding is: cui2vec_pretrained
#
# seed_union: pos_dcg: 0.0201, neg_dcg: 0.9799, perc_dcg: 0.0171, oov: 328, #seed: 637
#
#
#
#  The name of embedding is: DeVine_etal_200
#
# seed_union: pos_dcg: 0.0145, neg_dcg: 0.9855, perc_dcg: 0.0115, oov: 356, #seed: 637
#
#
#
#  The name of embedding is: PMC-w2v
#
# Time for discarding labels: 0:00:11
# 0:09:40
# seed_union: pos_dcg: 0.0416, neg_dcg: 0.9584, perc_dcg: 0.0336, oov: 179, #seed: 637
#
#
#
#  The name of embedding is: Health_2.5mreviews.s200.w10.n5.v15.cbow
#
# Time for discarding labels: 0:00:00
# 0:00:55
# seed_union: pos_dcg: 0.0191, neg_dcg: 0.9809, perc_dcg: 0.0155, oov: 381, #seed: 637
#
#
#
#  The name of embedding is: PubMed-and-PMC-w2v
#
# Time for discarding labels: 0:00:11
# 0:13:15
# seed_union: pos_dcg: 0.0324, neg_dcg: 0.9676, perc_dcg: 0.0233, oov: 177, #seed: 637
#
#
#
#  The name of embedding is: GoogleNews-vectors-negative300
#
# Time for discarding labels: 0:00:04
# 0:08:50
# seed_union: pos_dcg: 0.0218, neg_dcg: 0.9782, perc_dcg: 0.0131, oov: 203, #seed: 637
#
#
#
#  The name of embedding is: PubMed-w2v
#
# Time for discarding labels: 0:00:10
# 0:09:29
# seed_union: pos_dcg: 0.0292, neg_dcg: 0.9708, perc_dcg: 0.0201, oov: 177, #seed: 637
#
#
#
#  The name of embedding is: tweetsvec
#
# Time for discarding labels: 0:00:01
# 0:00:29
# seed_union: pos_dcg: 0.0145, neg_dcg: 0.9855, perc_dcg: 0.0127, oov: 416, #seed: 637
#
#
#
#  The name of embedding is: wikipedia-pubmed-and-PMC-w2v
#
# Time for discarding labels: 0:00:12
# 0:15:29
# seed_union: pos_dcg: 0.0299, neg_dcg: 0.9701, perc_dcg: 0.0213, oov: 177, #seed: 637
#
# 1:54:59

# %%
a = datetime.datetime.now().replace(microsecond=0)
utils.inputs_save(big_k, 'Utilities/big_k')
print(datetime.datetime.now().replace(microsecond=0)-a)
# Out:
# 0:00:00

# %% [markdown]
# ### Cardinality of the analyzed embeddings:

# %%
a = datetime.datetime.now().replace(microsecond=0)

cardinality_vemb = {}
for type_emb in embeddings:
    for emb in type_emb[1]:
        model = KeyedVectors.load_word2vec_format(PATH_EMBEDDINGS+type_emb[0]+emb, binary=emb.endswith('.bin'))
        name = os.path.splitext(emb)[0]
        vemb = utils.extract_w2v_vocab(model)
        cardinality_vemb[name] = (vemb, len(vemb))
        
utils.inputs_save(cardinality_vemb, 'Utilities/cardinality_vembs')
print(datetime.datetime.now().replace(microsecond=0)-a)

# %%
tmp = {k:v[1] for k, v in cardinality_vemb.items()}
tmp
# Out:
# {'claims_cuis_hs_300.txt': 14852,
#  'stanford_cuis_svd_300.txt': 22705,
#  'cui2vec_pretrained': 109053,
#  'DeVine_etal_200': 52102,
#  'PMC-w2v': 2515686,
#  'Health_2.5mreviews.s200.w10.n5.v15.cbow': 73644,
#  'PubMed-and-PMC-w2v': 4087446,
#  'GoogleNews-vectors-negative300': 3000000,
#  'PubMed-w2v': 2351706,
#  'tweetsvec': 26278,
#  'wikipedia-pubmed-and-PMC-w2v': 5443656}

# %%
utils.inputs_save(tmp, 'Utilities/cardinality_vembs')
